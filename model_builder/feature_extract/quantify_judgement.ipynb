# %%
import numpy as np
import re
import psycopg2
import pandas as pd
import jieba
import jieba.analyse

# %%
chs_arabic_map = {u'零':0, u'一':1, u'二':2, u'三':3, u'四':4,
        u'五':5, u'六':6, u'七':7, u'八':8, u'九':9,
        u'十':10, u'百':100, u'千':10 ** 3, u'万':10 ** 4,
        u'〇':0, u'壹':1, u'貳':2, u'參':3, u'肆':4,
        u'伍':5, u'陸':6, u'柒':7, u'捌':8, u'玖':9,
        u'拾':10, u'佰':100, u'仟':10 ** 3, u'萬':10 ** 4,
        u'亿':10 ** 8, u'億':10 ** 8, u'幺': 1,
        u'０':0, u'１':1, u'２':2, u'３':3, u'４':4,
        u'５':5, u'６':6, u'７':7, u'８':8, u'９':9,u'廿':20,u'卅':30}

def convertChineseDigitsToArabic(chinese_digits, encoding="utf-8"):
#     if isinstance (chinese_digits, str):
#         chinese_digits = chinese_digits.decode(encoding)

    result  = 0
    tmp     = 0
    hnd_mln = 0
    for count in range(len(chinese_digits)):
        curr_char  = chinese_digits[count]
        curr_digit = chs_arabic_map.get(curr_char, None)
        # meet 「亿」 or 「億」
        if curr_digit == 10 ** 8:
            result  = result + tmp
            result  = result * curr_digit
            # get result before 「亿」 and store it into hnd_mln
            # reset `result`
            hnd_mln = hnd_mln * 10 ** 8 + result
            result  = 0
            tmp     = 0
        # meet 「万」 or 「萬」
        elif curr_digit == 10 ** 4:
            result = result + tmp
            result = result * curr_digit
            tmp    = 0
        # meet 「十」, 「百」, 「千」 or their traditional version
        elif curr_digit >= 10:
            tmp    = 1 if tmp == 0 else tmp
            result = result + curr_digit * tmp
            tmp    = 0
        # meet single digit
        elif curr_digit is not None:
            tmp = tmp * 10 + curr_digit
        else:
            return result
    result = result + tmp
    result = result + hnd_mln
    return result

# %%
conn = psycopg2.connect(database="law1", user="datac1", password="datac15543", host="ci.lu.im.ntu.edu.tw", port="5432")
print ("Opened database successfully")

cur = conn.cursor()
# Out:
# Opened database successfully

# %%
cur.execute("""SELECT sqlid,judgement FROM law_judgement limit 57""")
rows = cur.fetchall()

# %%
sample_df = pd.DataFrame(rows)
sample_df.head(57)
# Out:
#           0                                                  1
# 0   3717436                                               緩刑貳年
# 1   3732010                                          處有期徒刑捌年拾月
# 2   3740348                                 應執行有期徒刑捌年壹月,均沒收銷燬之
# 3   3751750                                                 無罪
# 4   3751750                                                 無罪
# 5   3751805                                                不受理
# 6   3858107                                                不受理
# 7   3950302                                                 駁回
# 8   3950304                                                 駁回
# 9   3950305                                                 駁回
# 10  3801040                                      應執行有期徒刑參年,均沒收
# 11  3726330                          處有期徒刑伍月,如易科罰金,以新台幣壹仟元折算壹日
# 12  3815308                                               緩刑貳年
# 13  3815308                                                 無罪
# 14  3803476                                        應執行有期徒刑壹年月
# 15  3950307                                                 駁回
# 16  3950325                                                 駁回
# 17  3952456                                                 駁回
# 18  3952457                                                 駁回
# 19  3803476                                 處有期徒刑壹年肆月,減為有期徒刑捌月
# 20  3910661                                          應執行有期徒刑玖年
# 21  3717437  處有期徒刑肆月,如易科罰金,以銀元參佰元即新台幣玖佰元折算壹日,減為有期徒刑貳月,如易科罰金...
# 22  3717437                                               緩刑貳年
# 23  3717437                                                 無罪
# 24  3910661                                            處有期徒刑年
# 25  3717442                       處罰金新臺幣壹萬元,,如易服勞役,以新臺幣壹仟元折算壹日
# 26  3717442                           處拘役肆拾日,如易科罰金,以新臺幣壹仟元折算壹日
# 27  3717442                           處拘役參拾日,如易科罰金,以新臺幣壹仟元折算壹日
# 28  3717442                                               緩刑貳年
# 29  3717448  處拘役伍拾捌日,如易科罰金,以銀元佰元即新臺幣玖佰元折算壹日,減為拘役貳拾玖日,如易科罰金...
# 30  3910661                                                 無罪
# 31  3910662                                                 無罪
# 32  1891801                                                 駁回
# 33  1891795                                                 無罪
# 34  1891800                                                 無罪
# 35  1891838                                            處有期徒刑拾年
# 36  1891844                                            處有期徒刑陸月
# 37  1891864       處有期徒刑參月,併科罰金新台幣伍萬元,罰金如易服勞役,以銀元參佰元即新台幣玖佰元折算壹日
# 38  1891864  處有期徒刑參年,併科罰金新臺幣拾貳萬元,罰金如易服勞役,以銀元參佰元即新台幣玖佰元折算壹日,...
# 39  1891864  應執行有期徒刑參年貳月,併科罰金新臺幣拾伍萬元,罰金如易服勞役,以銀元參佰元即新台幣玖佰元折...
# 40  3952461                                                 駁回
# 41  3952462                                               緩刑肆年
# 42  1891917                                            處有期徒刑拾月
# 43  1891917                                               緩刑肆年
# 44  1891917                                            處有期徒刑柒月
# 45  1891917                                               緩刑參年
# 46  1891920  處有期徒刑肆月,併科罰金新臺幣肆萬元,有期徒刑如易科罰金,罰金如易服勞役,均以新臺幣玖佰元即...
# 47  1891944                             處有期徒刑貳月,如易科罰金,以參佰元折算壹日
# 48  1892005                                                 無罪
# 49  1892009                                                 駁回
# 50  1905559                                          處有期徒刑伍年貳月
# 51  1906281                                                 駁回
# 52  1907658   應給付原告新臺幣肆萬元,及自民國九十三年十二月二十一日起至清償日止,按週年利率百分之五計算之利息
# 53  1904182                                                 無罪
# 54  1904182                                                 無罪
# 55  1904191                                                 無罪
# 56  1904191                                                 無罪

# %%
test_str = sample_df[1][50]
print(test_str)
# Out:
# 處有期徒刑伍年貳月

# %%
num_judgements_words_pattern = "有期徒刑.{1,8}[年|月]"
est_judgements_words_pattern = "無期徒刑|死刑"
no_guilty_words_pattern = "無罪|駁回|撤銷|不受理|免訴"

# %%
nums = re.findall(num_judgements_words_pattern,test_str)
ests = re.findall(est_judgements_words_pattern,test_str)
no_guiltys = re.findall(no_guilty_words_pattern,test_str)

print(nums)
print(ests)
print(no_guiltys)
# Out:
# ['有期徒刑伍年貳月']
# []
# []

# %%
numbers = []
if (len(nums) > 0):
    num_str = nums[-1].replace("有期徒刑","")
    years = ""
    months = ""
    
    if (num_str.find("年") > 0):
        years = num_str.split("年")[0]
        num_str = num_str.split("年")[1]
    if (num_str.find("月") > 0):
        months = num_str.split("月")[0]
    
    res = convertChineseDigitsToArabic(years) * 12 + convertChineseDigitsToArabic(months)
    print(res)
    
    numbers.append(res)
# Out:
# 62

# %%
if (len(ests) > 0):
    for s in ests :
        if (s.find("無期徒刑")):
            numbers.append(50*12)
        if (s.find("死刑")):
            numbers.append(100*12)

# %%
for s in no_guiltys:
    numbers.append(0)

# %%
print(np.array(numbers).mean())
# Out:
# 62.0
