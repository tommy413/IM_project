# %%
import numpy as np
import psycopg2
import pandas as pd
import jieba
import jieba.analyse
import jieba.posseg as pseg

# %%
conn = psycopg2.connect(database="law1", user="datac1", password="datac15543", host="ci.lu.im.ntu.edu.tw", port="5432")
print ("Opened database successfully")

cur = conn.cursor()

cur.execute("""SELECT sqlid,main,reasonfact FROM jdata_features WHERE sqlid IN (SELECT sqlid FROM jdata_meta WHERE cat = 'M' and parser_done = '1') limit 100 """)
rows = cur.fetchall()
# Out:
# Opened database successfully

# %%
sample_df = pd.DataFrame(rows)
sample_df.head()
# Out:
#          0                                                  1  \
# 0  1226568  乙○○強盜故意殺人，處無期徒刑，褫奪公權終身。如附表二各編號所示附件之簽帳單特約商店存根聯上...
# 1  1325207  原判決撤銷。甲○○共同以廣告物散布足以引誘促使人為性交易之訊息，累犯，處有期徒刑捌月；扣案之...
# 2  1443815                甲○○從事業務之人，因業務上之過失致人於死，處有期徒刑捌月，緩刑貳年。
# 3  1548326  原判決關於甲○○部分撤銷。甲○○依據法令從事公務之人員，共同對於監督之事務，直接圖利，處有期...
# 4  1795396  乙○○幫助洗錢，處有期徒刑伍月。如易科罰金，以參佰元折算壹日。所得財物新台幣貳仟元沒收，如全...
#
#                                                    2
# 0  ####一、乙○○於民國○○○年○月○○○日生，華僑普通高級中學畢業，嗣服役於海軍陸戰隊士官...
# 1  ####一、甲○○於八十七年間因犯常業賭博罪，經台灣板橋地方法院八十七年度易字第一０一一號判...
# 2  ####一、甲○○係高沅冷涷空調設備有限公司司機，以駕駛貨車載運貨物為業，為從事駕駛業務之人...
# 3  ####一、緣高雄市政府工務局為防止建築工程於施工中產生之廢棄物任意傾倒而造成髒亂，妨礙公共...
# 4  ####一、緣甲○○（業經本院於民國九十二年六月二十五日以九十二年度訴字第六一八號確定）於九...

# %%
print(sample_df[2][0])
# Out:
# ####一、乙○○於民國○○○年○月○○○日生，華僑普通高級中學畢業，嗣服役於海軍陸戰隊士官班，退役後曾與軍中同袍庚○○等人往來，惟其於八十三年間向庚○○借款新臺幣（下同）十萬元未還後，庚○○等人即遍尋不著乙○○。####二、乙○○於民國八十八年間與亥○○離婚，同年底赴大陸地區經營皮革生意，其間因個人財務困難，陸續向胞妹丙○○借款四百餘萬元，向前配偶亥○○借款約十一萬二千元，且因個人信用欠佳，於八十八年十二月間尚以亥○○名義向中國信託商業銀行（下稱中國信託銀行）貸款十五萬元，所借得款項悉數攜往大陸地區投資。乙○○至大陸地區投資後，財務狀況未見好轉，而無力償還中國信託銀行之貸款，遂由丙○○每月代為向銀行清償三千四百九十一元，其從大陸地區返臺期間並經常向丙○○借款數千元不等或請丙○○代為繳納信用卡帳款。乙○○向亥○○借款後屢次承諾返臺時將返還借款，惟均未履行，亥○○因獨自扶養二名幼子需用款項，乃於八十九年三月二十日強烈要求乙○○一次將上開借款還清，乙○○無力清償，遂於同日簽發票號二三八七九○號、面額五萬七千元、到期日八十九年十月三十一日及票號二三八七八九號、面額五萬五千元、到期日九十年三月三十一日之本票各一紙，承諾於本票到期日時清償票面金額，另簽發票號二三八七八七號、面額十五萬元、到期日九十四年三月三十一日之本票一紙，擔保於到期日前將還清上述以亥○○名義向中國信託銀行之貸款。惟乙○○積欠亥○○之欠款於面額五萬七千元及五萬五千元二紙本票屆期時仍未清償，亥○○乃再次要求乙○○還款。另乙○○之胞妹丙○○所申請之公教人員低利貸款將於九十一年年底核准，遂告知乙○○需款以該低利貸款購屋，請乙○○返還先前支借之款項，乙○○便應允於九十年六月間還款。被告乙○○因不願對丙○○及亥○○食言，遂急需籌款還錢。####三、乙○○與亥○○離婚後，同年透過友人卯○○介紹而結識在臺北市大安區○○○路○段二五三巷三十二號二樓自家住處教授小班美語之未婚女子子○○（女、五十年六月二十日生、身分證統一編號Ｚ000000000號），子○○於九十年間擁有之資產其中美金定期存款約四十七萬美元、股票總市值約八百餘萬元、債券基金約四百七十八萬餘元，經濟狀況優渥。子○○前於七十七年至八十一年間曾提供其所有坐落臺北市○○區○○段一小段一六之一三地號暨其上建物門牌號碼臺北市○○路○段三十五巷七弄五十三號一樓先後向銀行設定抵押權，前後貸款共計一千餘萬元供前男友清償債務，然其前男友均未還款，子○○因此需自行負擔高額貸款，故對於男性友人提及金錢往來之事極為排斥，對與他人金錢往來亦十分計較、謹慎。####四、乙○○與子○○結識初時並未深入交往，惟乙○○自九十年五月十五日從大陸地區返臺後，於同年六月上旬開始積極與目前已有男友甲○○之子○○交往。乙○○因財務週轉困難，又須籌款清償欠款，急須資金挹注，乃於九十二年六月上旬邀約於「二春聯誼」認識之女子天○○投資一百萬元在其大陸之皮革生意，惟經天○○明確拒絕。乙○○因迫切需要資金挹注，遂分別於九十年六月十四日上午十一時七分三十秒及同日上午十一時十七分二十秒，二度以其使用之0000000000號行動電話（租用人為丙○○）撥打子○○使用之0000000000號行動電話（租用人為辛○○）與子○○聯絡（同日上午十時許，子○○甫與元大京華證券股份有限公司業務經理申○○以電話敲定美金存款三十五萬五千四百六十八點七五元之續約事宜，並於同日上午十時二十五分簽署到期通知書後傳真予申○○續約六個月），並隨即至臺北市大安區○○○路○段二五三巷三十二號二樓子○○住處，邀約子○○投資其在大陸地區之事業。惟子○○對於男性友人提及金錢往來之事均極為排斥，乃嚴拒乙○○之邀約。乙○○為籌得款項，見子○○經濟優渥，且單身獨居，四處無人，有機可趁，竟起強盜殺人之犯意，意圖為自己不法之所有，以不詳方法，對子○○施以強暴，致使不能抗拒後控制子○○行動自由，強取子○○所有之中國信託銀行忠孝分行帳號0000000000號存摺一本、該帳戶金融卡一張、中國信託銀行信用卡一張（卡號0000000000000000號）、支票一張（支票號碼AH0000000號、面額六萬元、發票人為辛○○、受款人為子○○、發票日為九十年六月十四日、付款人為中國信託銀行總行儲蓄部）等財物，並強迫子○○供出金融卡密碼，乙○○旋於同日下午四時十八分許，基於意圖為自己不法之所有，以不正方法由自動付款設備取得他人之物之概括犯意，先持上開金融卡至臺北市○○路○段一號萬通商業銀行儲蓄部提款機輸入密碼順利提領二萬元（如附表一編號一所示），確認密碼無誤後，再返回子○○住處，為湮滅事證，以不詳方式將子○○殺害後，將屍體抱至子○○臥房浴室內以不詳方式處理屍體，於處理過程中致子○○大量血液噴濺到浴室東方、南方牆面、地板、洗臉檯、浴缸、馬桶、浴缸上白色浴簾、盥洗沐浴用品瓶身、毛巾、浴室門板、浴室門口腳踏墊上等處及乙○○身體，乙○○乃將沾有子○○血液之浴簾拆下與沾有子○○血跡之盥洗沐浴用品及浴室門口之腳踏墊，以不詳材質之置物袋裝妥，又將子○○屍體裝入另一不詳材質之置物袋內。乙○○為掩飾犯行以逃避追緝，即以浴室內毛巾沾水擦去浴室東方、南方牆面血跡，並以水沖洗浴室地板、洗臉檯、浴缸、馬桶之血液，致血水從洗臉檯、浴缸邊緣流下，惟匆忙間未注意血液噴濺到浴室南方窗戶下方旁牆面、血水彈濺到浴室門板，且有多量濃度極高之血液殘留在浴缸與浴室南側牆緣間縫隙，及其在浴室與臥房出入時，身上沾染之子○○血液滴落在臥室床單上，且在臥房浴室門口留下其右手掌之掌紋及右腳掌掌紋。####五、乙○○為將子○○之屍體及沾有子○○血液之物品運至他處湮滅，乃於同日下午五時許，向不知情之丙○○商借丙○○所有車牌號碼Ｑ二─七一九三號銀色福特Festiva型自用小客車；同日下午七時許，在丙○○臺北縣永和市○○路一五一巷五弄五號住處前，取得該自用小客車後，即駕車返回子○○上址住處，將子○○屍體及沾有子○○血液之物品分別置於車後行李箱及汽車後座；於同日下午八時九分許駕車途經臺北市○○路○段時，以其上開行動電話撥打丙○○之0000000000號電話，並經由國道三號高速公路駛向臺北縣瑞芳鎮、金山鄉之北部海岸方向；其於翌日（即十五日）凌晨一時五分許途經臺北縣金山鄉時，並以其上開行動電話撥打000000000000號電話與在大陸地區之朋友聯繫，嗣在臺灣省北部某隱密處所，將子○○屍體及沾有子○○血液之上開物品湮滅。乙○○因在搬運子○○屍體及沾有子○○血液之物品之過程中，其自身背後腰部衣物已沾染子○○之血液，回程中發現駕駛座竹蓆及汽車後座竹蓆上均沾有子○○血跡，乃將表面血跡拭去；然乙○○未詳細查看子○○之血液已從竹蓆縫隙流下殘留在竹蓆背面及座椅表面，另在汽車後行李箱子○○之血液則從屍袋下滲出滴落在下方之遮陽片、紙張及接線用電線上，並逐漸向下滲透至遮陽片下方之黑色置物墊及置物墊下方之木板；而於同年月十五日凌晨三時許，將汽車駛回丙○○上址住處附近停放，將車交還丙○○。####六、乙○○劫得子○○之上開存摺、金融卡、信用卡及支票後，為能領取上開面額六萬元支票之款項，乃於九十年六月十五日上午十時許，至臺北市○○○路子○○住處附近某刻印店，利用不知情之店員偽刻子○○印章一枚，攜至臺北市○○○路○段二○三號中國信託銀行忠孝分行，在上開支票背面偽造子○○印文一枚以為背書而偽造私文書，並將該紙支票及子○○帳戶存摺交付銀行行員辦理支票存款而行使之；於同日上午十時三十分許至十一時許間，再返回子○○上址住處，將子○○上開存摺及偽刻之印章，放入子○○臥室衣櫃抽屜內旋即離去。乙○○又賡續前意圖為自己不法之所有，以不正方法由自動付款設備取得他人之物之概括犯意，持子○○上開金融卡，於如附表一編號二至三所示之時間、地點，由自動付款設備提領如附表一編號二至三所示之現金，合計共四萬元，擬在臺北縣新莊市一帶購買皮革樣品攜回大陸地區。乙○○於如附表一編號四所示之時間、地點，再持子○○之金融卡輸入密碼著手提款時，因上開面額六萬元支票交換未完成，款項尚未存入子○○帳戶，而未得逞。其並基於意圖為自己不法之所有及行使偽造私文書詐欺取財之概括犯意，連續於如附表二編號一至十所示時間、地點，假冒係子○○本人，行使該信用卡刷卡購買如附表二各編號所示價值之物，乙○○並先後以複寫方式，在如附件一至附件十所示之二聯式簽帳單上顧客存根聯及特約商店存根聯分別偽簽「子○○」中英文署押，作為以子○○名義購物消費，允諾付款予發卡銀行之意思表示，而偽造簽帳單私文書，再將簽帳單特約商店存根聯交付該特約商店而行使之，使各特約商店及中國信託銀行誤信其即為子○○本人，而陷於錯誤，交付其所購買如附表二各編號所示價值之物及代為墊款共三萬八千七百五十八元，均足生損害於子○○、各特約商店、財團法人聯合信用卡處理中心及中國信託銀行。乙○○並於九十年六月十七日下午一時四十一分許，向中華航空股份有限公司（下稱中華航空公司）預定同年月十九日上午七時二十分早班飛機機位經由香港轉赴大陸地區，以逃避警方之追緝。其於同日下午並以自子○○帳戶所領得之款項購買NOKIA廠牌八二三○型行動電話及配備，又於同年月十八日晚間向亥○○借款二萬元，並表示翌日即還款。####七、子○○之男友甲○○自九十年六月十四日中午十二時許之後，多次聯絡子○○未果，疑有不測；乃告知子○○之友人汪治華轉知子○○胞姊癸○○，於同年月十五日晚間十一時許，報警會同消防人員推窗進入子○○上址住處之際，發現大門未鎖，主臥房浴室相當整潔，然有部分物品遭異動，惟不見子○○，而子○○日常穿用之鞋子均在屋內，又發現臥房浴室之浴簾、沐浴用品等物均不翼而飛；詳細查看，在臥房浴室內發現有多處血 ...

# %%
jieba.load_userdict("../model_builder/dataset/dict.txt.big") 

words = pseg.cut(sample_df[2][0])
for word, flag in words:
    if (flag == 'x'):
        continue
    print('%s %s' % (word, flag))
# Out:
# 一 m
# 乙 n
# 於 nr
# 民國 n
# 年 m
# 月 m
# 日 m
# 生 n
# 華僑 n
# 普通 nz
# 高級中學 nt
# 畢業 n
# 嗣 ng
# 服役 n
# 於 nr
# 海軍陸戰隊 nt
# 士官 n
# 班 n
# 退役 v
# 後 nr
# 曾 d
# 與 p
# 軍中 s
# 同袍 n
# 庚 nr
# 等 u
# 人 n
# 往來 t
# 惟其 c
# 於 nr
# 八十三 m
# 年間 t
# 向庚 nr
# 借款 n
# 新臺幣 n
# 下同 v
# 十萬元 m
# 未 d
# 還 d
# 後 nr
# 庚 nr
# 等 u
# 人 n
# 即 v
# 遍尋 v
# 不著 v
# 乙 n
# 二 m
# 乙 n
# 於 nr
# 民國 n
# 八十八年 m
# 間與亥 nz
# 離婚 v
# 同 p
# 年底 t
# 赴 v
# 大陸 n
# 地區 n
# 經營 vn
# 皮革 n
# 生意 v
# 其間 r
# 因 p
# 個人 n
# 財務 n
# 困難 an
# 陸續 d
# 向 p
# 胞妹 n
# 丙 n
# 借款 n
# 四百餘萬 m
# 元 m
# 向前 t
# 配偶 v
# 亥 t
# 借款 n
# 約 d
# 十一萬 m
# 二千元 m
# 且 c
# 因 c
# 個人信用 n
# 欠佳 v
# 於 nr
# 八十八年 m
# 十二月 m
# 間 f
# 尚以 c
# 亥 t
# 名義 n
# 向 p
# 中國 ns
# 信託 n
# 商業銀行 nt
# 下稱 v
# 中國 ns
# 信託 n
# 銀行 n
# 貸款 n
# 十五萬元 m
# 所 c
# 借得 v
# 款項 n
# 悉數 d
# 攜往 v
# 大陸 n
# 地區 n
# 投資 vn
# 乙 n
# 至 p
# 大陸 n
# 地區 n
# 投資 vn
# 後 f
# 財務狀況 n
# 未見好轉 i
# 而 c
# 無力 n
# 償還 v
# 中國 ns
# 信託 n
# 銀行 n
# 之 u
# 貸款 n
# 遂 d
# 由 p
# 丙 n
# 每月 r
# 代為 v
# 向 p
# 銀行 n
# 清償 vn
# 三千 m
# 四百 m
# 九十一 m
# 元 m
# 其 r
# 從 p
# 大陸 n
# 地區 n
# 返臺 v
# 期間 f
# 並 c
# 經常 d
# 向 p
# 丙 n
# 借款 n
# 數千元 m
# 不等 a
# 或 c
# 請 v
# 丙 n
# 代為 v
# 繳納 v
# 信用卡 n
# 帳款 n
# 乙 n
# 向亥 nz
# 借款 n
# 後 f
# 屢次 d
# 承諾 v
# 返臺 v
# 時 ng
# 將 d
# 返還 v
# 借款 n
# 惟 d
# 均 d
# 未 d
# 履行 v
# 亥 t
# 因 p
# 獨自 d
# 扶養 v
# 二名 m
# 幼子 n
# 需用 v
# 款項 n
# 乃 v
# 於 nr
# 八十九年 m
# 三月 m
# 二十日 m
# 強烈要求 l
# 乙 n
# 一次 m
# 將 d
# 上開 v
# 借款 n
# 還清 v
# 乙 n
# 無力 n
# 清償 vn
# 遂 d
# 於 nr
# 同日 t
# 簽發 v
# 票號 n
# 二三 m
# 八七 m
# 九 m
# 號 m
# 面額 n
# 五萬 m
# 七千元 m
# 到期日 l
# 八十九年 m
# 十月 t
# 三十一日 m
# 及 c
# 票號 n
# 二三 m
# 八七 m
# 八九 m
# 號 m
# 面額 n
# 五萬五千 m
# 元 m
# 到期日 l
# 九十年 m
# 三月 m
# 三十一日 m
# 之 u
# 本票 n
# 各 r
# 一紙 m
# 承諾 v
# 於 nr
# 本票 n
# 到期日 l
# 時 zg
# 清償 vn
# 票面 n
# 金額 n
# 另 r
# 簽發 v
# 票號 n
# 二三 m
# 八七 m
# 八七 m
# 號 m
# 面額 n
# 十五萬元 m
# 到期日 l
# 九十四年 m
# 三月 m
# 三十一日 m
# 之 u
# 本票 n
# 一紙 m
# 擔保 v
# 於 nr
# 到期日 l
# 前 f
# 將 d
# 還清 v
# 上述 b
# 以亥 nz
# 名義 n
# 向 p
# 中國 ns
# 信託 n
# 銀行 n
# 之 u
# 貸款 n
# 惟 c
# 乙 n
# 積欠 v
# 亥 t
# 之 u
# 欠款 n
# 於 nr
# 面額 n
# 五萬 m
# 七千元 m
# 及 c
# 五萬五千 m
# 元 m
# 二紙 m
# 本票 n
# 屆期 d
# 時 zg
# 仍未 d
# 清償 vn
# 亥 t
# 乃 v
# 再次 d
# 要求 v
# 乙 n
# 還款 v
# 另 r
# 乙 n
# 之 u
# 胞妹 n
# 丙 n
# 所 c
# 申請 v
# 之 u
# 公教人員 n
# 低利 n
# 貸款 n
# 將 d
# 於九 nr
# 十一年 m
# 年底 t
# 核准 n
# 遂 d
# 告知 v
# 乙 n
# 需款 n
# 以 p
# 該 r
# 低利 n
# 貸款 n
# 購屋 n
# 請 v
# 乙 n
# 返還 v
# 先前 t
# 支借 v
# 之 u
# 款項 n
# 乙 n
# 便 d
# 應允 v
# 於 nr
# 九十年 m
# 六月 t
# 間 f
# 還款 v
# 被告 n
# 乙 n
# 因 p
# 不願 v
# 對 p
# 丙 n
# 及 c
# 亥 t
# 食言 n
# 遂 d
# 急需 n
# 籌款 n
# 還 d
# 錢 n
# 三 m
# 乙 n
# 與 p
# 亥 t
# 離婚 v
# 後 f
# 同年 t
# 透過 v
# 友人 n
# 卯 t
# 介紹 v
# 而 c
# 結識 n
# 在 p
# 臺北市 ns
# 大安區 ns
# 路 n
# 段 q
# 二五 m
# 三巷 nz
# 三十二 m
# 號 m
# 二樓 n
# 自家 r
# 住處 n
# 教授 n
# 小班 n
# 美語 nz
# 之 u
# 未婚 v
# 女子 n
# 子 ng
# 女 b
# 五十年 m
# 六月 t
# 二十日 m
# 生 vn
# 身分證 n
# 統一 vn
# 編號 n
# 000000000 m
# 號 m
# 子 ng
# 於 nr
# 九十 m
# 年間 t
# 擁有 v
# 之 u
# 資產 n
# 其中 r
# 美金 n
# 定期存款 l
# 約 d
# 四十七 m
# 萬美元 m
# 股票 n
# 總 zg
# 市值 n
# 約 d
# 八百餘 m
# 萬元 m
# 債券 n
# 基金 n
# 約 d
# 四百 m
# 七十八 m
# 萬餘元 m
# 經濟 n
# 狀況 n
# 優渥 a
# 子 ng
# 前 f
# 於七 nr
# 十七年 m
# 至 p
# 八十一 m
# 年間 t
# 曾 d
# 提供 v
# 其 r
# 所有 b
# 坐落 v
# 臺北市 ns
# 區 n
# 段 q
# 一小 d
# 段 q
# 一六 m
# 之一 r
# 三 m
# 地號 n
# 暨 c
# 其 r
# 上 v
# 建物 n
# 門牌號碼 n
# 臺北市 ns
# 路 n
# 段 q
# 三十五 m
# 巷 ng
# 七 m
# 弄 v
# 五十三 m
# 號 m
# 一樓 n
# 先後 t
# 向 p
# 銀行 n
# 設定 v
# 抵押權 n
# 前後 f
# 貸款 n
# 共計 v
# 一千餘萬元 m
# 供 v
# 前男友 n
# 清償債務 n
# 然其 c
# 前男友 n
# 均 d
# 未 d
# 還款 v
# 子 ng
# 因此 c
# 需 v
# 自行 r
# 負擔 v
# 高額 n
# 貸款 n
# 故 n
# 對於 i
# 男性 n
# 友人 n
# 提及 v
# 金錢 n
# 往來 t
# 之事 r
# 極 d
# 為 p
# 排斥 v
# 對 p
# 與 p
# 他人 r
# 金錢 n
# 往來 t
# 亦 d
# 十分 m
# 計較 v
# 謹慎 a
# 四 m
# 乙 n
# 與 p
# 子 ng
# 結識 n
# 初時 t
# 並未 d
# 深入 v
# 交往 v
# 惟 c
# 乙 n
# 自 p
# 九十年 m
# 五月 t
# 十五日 m
# 從 zg
# 大陸 n
# 地區 n
# 返臺 v
# 後 f
# 於 nr
# 同年 t
# 六月 t
# 上旬 t
# 開始 v
# 積極 ad
# 與 zg
# 目前 t
# 已有 v
# 男友 n
# 甲 n
# 之 u
# 子 ng
# 交往 v
# 乙 n
# 因 p
# 財務 n
# 週轉 nr
# 困難 an
# 又 d
# 須 d
# 籌款 n
# 清償 vn
# 欠款 n
# 急須 d
# 資金 n
# 挹注 v
# 乃 v
# 於九 nr
# 十二年 m
# 六月 t
# 上旬 t
# 邀約 v
# 於 nr
# 二 m
# 春 tg
# 聯誼 nz
# 認識 v
# 之 u
# 女子 n
# 天 q
# 投資 vn
# 一百萬元 m
# 在 p
# 其 r
# 大陸 n
# 之 u
# 皮革 n
# 生意 v
# 惟經 b
# 天 n
# 明確 ad
# 拒絕 v
# 乙 n
# 因 p
# 迫切需要 n
# 資金 n
# 挹注 v
# 遂 d
# 分別 d
# 於 nr
# 九十年 m
# 六月 t
# 十四日 m
# 上午 t
# 十一時 d
# 七分 m
# 三十秒 m
# 及 c
# 同日 t
# 上午 t
# 十一時 d
# 十七分 m
# 二十 m
# 秒 m
# 二度 n
# 以 p
# 其 r
# 使用 v
# 之 f
# 0000000000 m
# 號 m
# 行動 vn
# 電話 n
# 租用 v
# 人 n
# 為 p
# 丙 n
# 撥打 v
# 子 ng
# 使用 v
# 之 f
# 0000000000 m
# 號 m
# 行動 vn
# 電話 n
# 租用 v
# 人 n
# 為 p
# 辛 nr
# 與 p
# 子 ng
# 聯絡 n
# 同日 t
# 上午 t
# 十時 t
# 許 m
# 子 ng
# 甫 d
# 與 p
# 元 m
# 大 a
# 京華 nz
# 證券 n
# 股份 n
# 有限公司 n
# 業務經理 n
# 申 v
# 以 p
# 電話 n
# 敲定 v
# 美金 n
# 存款 n
# 三十五萬 m
# 五千 m
# 四百 m
# 六十 m
# 八點 m
# 七五 m
# 元 m
# 之 f
# 續約 n
# 事宜 n
# 並於 c
# 同日 t
# 上午 t
# 十時 t
# 二十五分 m
# 簽署 v
# 到期 d
# 通知書 nr
# 後 f
# 傳真 v
# 予申 v
# 續約 n
# 六個月 m
# 並 c
# 隨即 d
# 至 p
# 臺北市 ns
# 大安區 ns
# 路 n
# 段 q
# 二五 m
# 三巷 nz
# 三十二 m
# 號 m
# 二樓 n
# 子 ng
# 住處 n
# 邀約 v
# 子 ng
# 投資 vn
# 其 r
# 在 p
# 大陸 n
# 地區 n
# 之 u
# 事業 n
# 惟子 b
# 對於 i
# 男性 n
# 友人 n
# 提及 v
# 金錢 n
# 往來 t
# 之事 r
# 均 d
# 極 d
# 為 p
# 排斥 v
# 乃 v
# 嚴拒 v
# 乙 n
# 之 u
# 邀約 v
# 乙 n
# 為 p
# 籌得 v
# 款項 n
# 見子 n
# 經濟 n
# 優渥 a
# 且 zg
# 單身 n
# 獨居 v
# 四處 m
# 無人 n
# 有機 n
# 可 v
# 趁 v
# 竟 d
# 起 v
# 強盜 n
# 殺人 n
# 之 u
# 犯意 v
# 意圖 n
# 為 zg
# 自己 r
# 不法 n
# 之 u
# 所有 b
# 以 p
# 不詳 v
# 方法 n
# 對子 n
# 施以 v
# 強暴 a
# 致使 v
# 不能 v
# 抗拒 v
# 後 f
# 控制 v
# 子 ng
# 行動 vn
# 自由 a
# 強取 v
# 子 ng
# 所有 b
# 之 u
# 中國 ns
# 信託 n
# 銀行 n
# 忠孝 a
# 分行 v
# 帳號 n
# 0000000000 m
# 號 m
# 存摺 v
# 一本 m
# 該 r
# 帳戶 n
# 金融 n
# 卡 n
# 一張 m
# 中國 ns
# 信託 n
# 銀行 n
# 信用卡 n
# 一張 m
# 卡號 nz
# 0000000000000000 m
# 號 m
# 支票 n
# 一張 m
# 支票 n
# 號碼 n
# AH0000000 eng
# 號 m
# 面額 n
# 六萬元 m
# 發票 n
# 人 n
# 為 p
# 辛 nr
# 受款 v
# 人 n
# 為 p
# 子 ng
# 發票 n
# 日 m
# 為 p
# 九十年 m
# 六月 t
# 十四日 m
# 付款人 n
# 為 zg
# 中國 ns
# 信託 n
# 銀行 n
# 總行 n
# 儲蓄 n
# 部 n
# 等 u
# 財物 n
# 並 c
# 強迫 a
# 子 ng
# 供出 v
# 金融 n
# 卡 n
# 密碼 n
# 乙 n
# 旋 d
# 於 nr
# 同日 t
# 下午 t
# 四時 t
# 十八分 m
# 許 m
# 基於 p
# 意圖 n
# 為 zg
# 自己 r
# 不法 n
# 之 u
# 所有 b
# 以 p
# 不正 d
# 方法 n
# 由 p
# 自動 vn
# 付款 v
# 設備 vn
# 取得 v
# 他人 r
# 之 u
# 物 ng
# 之 u
# 概括 v
# 犯意 v
# 先持 v
# 上開 v
# 金融 n
# 卡至 nr
# 臺北市 ns
# 路 n
# 段 q
# 一號 m
# 萬通 nz
# 商業銀行 nt
# 儲蓄 n
# 部 n
# 提款機 n
# 輸入 v
# 密碼 n
# 順利 ad
# 提領 v
# 二 m
# 萬元 m
# 如 v
# 附表 n
# 一 m
# 編號 n
# 一所 m
# 示 v
# 確認 v
# 密碼 n
# 無誤 v
# 後 f
# 再 d
# 返回 v
# 子 ng
# 住處 n
# 為 zg
# 湮滅 v
# 事證 n
# 以 p
# 不詳 v
# 方式 n
# 將子 n
# 殺害 v
# 後 f
# 將 zg
# 屍體 n
# 抱 v
# 至 p
# 子 ng
# 臥房 n
# 浴室 n
# 內 f
# 以 p
# 不詳 v
# 方式 n
# 處理 v
# 屍體 n
# 於 nr
# 處理過程 l
# 中致子 n
# 大量 n
# 血液 n
# 噴濺 v
# 到 v
# 浴室 n
# 東方 s
# 南方 f
# 牆面 n
# 地板 n
# 洗臉 v
# 檯 zg
# 浴缸 n
# 馬桶 n
# 浴缸 n
# 上 f
# 白色 n
# 浴簾 n
# 盥洗 b
# 沐浴 v
# 用品 n
# 瓶身 n
# 毛巾 nr
# 浴室 n
# 門板 n
# 浴室 n
# 門口 s
# 腳踏 v
# 墊 v
# 上 f
# 等 u
# 處 n
# 及 c
# 乙 n
# 身體 n
# 乙 n
# 乃 v
# 將 d
# 沾有 v
# 子 ng
# 血液 n
# 之 u
# 浴簾 n
# 拆下 v
# 與 zg
# 沾有 v
# 子 ng
# 血跡 n
# 之 u
# 盥洗 b
# 沐浴 v
# 用品 n
# 及 c
# 浴室 n
# 門口 s
# 之 u
# 腳踏 v
# 墊 zg
# 以 p
# 不詳 v
# 材質 n
# 之 u
# 置物 n
# 袋裝 n
# 妥 a
# 又 d
# 將子 n
# 屍體 n
# 裝入 v
# 另 r
# 一 m
# 不詳 v
# 材質 n
# 之 u
# 置 v
# 物袋 n
# 內 f
# 乙 n
# 為 zg
# 掩飾 v
# 犯行 v
# 以 p
# 逃避 v
# 追緝 v
# 即以 c
# 浴室 n
# 內 n
# 毛巾 nr
# 沾水 v
# 擦 v
# 去 v
# 浴室 n
# 東方 s
# 南方 f
# 牆面 n
# 血跡 n
# 並以 c
# 水 n
# 沖洗 vn
# 浴室 n
# 地板 n
# 洗臉 v
# 檯 zg
# 浴缸 n
# 馬桶 n
# 之 u
# 血液 n
# 致 v
# 血水 n
# 從 zg
# 洗臉 v
# 檯 zg
# 浴缸 n
# 邊緣 n
# 流下 v
# 惟 b
# 匆忙 z
# 間 f
# 未 d
# 注意 v
# 血液 n
# 噴濺 v
# 到 v
# 浴室 n
# 南方 f
# 窗戶 n
# 下方 f
# 旁 f
# 牆面 n
# 血水 n
# 彈 v
# 濺 v
# 到 v
# 浴室 n
# 門板 n
# 且 c
# 有 v
# 多量 m
# 濃度 n
# 極高 a
# 之 u
# 血液 n
# 殘留 v
# 在 p
# 浴缸 n
# 與 zg
# 浴室 n
# 南側 f
# 牆緣 n
# 間 f
# 縫隙 n
# 及其 c
# 在 p
# 浴室 n
# 與 zg
# 臥房 n
# 出 v
# 入時 ns
# 身上 s
# 沾染 v
# 之 u
# 子 ng
# 血液 n
# 滴落 v
# 在 p
# 臥室 n
# 床單 n
# 上 f
# 且 c
# 在 p
# 臥房 n
# 浴室 n
# 門口 s
# 留下 v
# 其 r
# 右手掌 n
# 之 u
# 掌紋 n
# 及 c
# 右腳 n
# 掌 v
# 掌紋 n
# 五 m
# 乙 n
# 為 p
# 將子 n
# 之 u
# 屍體 n
# 及 c
# 沾有 v
# 子 ng
# 血液 n
# 之 u
# 物品 n
# 運至 v
# 他 r
# 處 v
# 湮滅 v
# 乃 v
# 於 nr
# 同日 t
# 下午 t
# 五時 t
# 許 m
# 向 p
# 不知情 i
# 之 u
# 丙 n
# 商借 v
# 丙 n
# 所有 b
# 車牌號碼 n
# 二 m
# 七 m
# 一九三 m
# 號 m
# 銀色 n
# 福特 ns
# Festiva eng
# 型 k
# 自用 v
# 小客車 n
# 同日 t
# 下午 t
# 七時 t
# 許 m
# 在 p
# 丙 n
# 臺北縣 ns
# 永和市 ns
# 路 n
# 一 m
# 五一 m
# 巷五 n
# 弄 v
# 五號 m
# 住處 n
# 前 f
# 取得 v
# 該 r
# 自用 v
# 小客車 n
# 後 f
# 即 v
# 駕車 n
# 返回 v
# 子 ng
# 上址 n
# 住處 n
# 將子 n
# 屍體 n
# 及 c
# 沾有 v
# 子 ng
# 血液 n
# 之 u
# 物品 n
# 分別 d
# 置於 v
# 車 n
# 後 nr
# 行李箱 n
# 及 c
# 汽車 n
# 後座 n
# 於 nr
# 同日 t
# 下午 t
# 八時 t
# 九分 m
# 許 m
# 駕車 n
# 途經 n
# 臺北市 ns
# 路 n
# 段 q
# 時 ng
# 以其 c
# 上開 v
# 行動 vn
# 電話 n
# 撥打 v
# 丙 n
# 之 f
# 0000000000 m
# 號 m
# 電話 n
# 並 c
# 經由 p
# 國道 n
# 三號 m
# 高速公路 n
# 駛向 v
# 臺北縣 ns
# 瑞芳 nr
# 鎮 zg
# 金山鄉 ns
# 之 u
# 北部 f
# 海岸 s
# 方向 n
# 其 r
# 於 nr
# 翌日 t
# 即 v
# 十五日 m
# 凌晨 t
# 一時 d
# 五分 m
# 許 m
# 途經 n
# 臺北縣 ns
# 金山鄉 ns
# 時 zg
# 並以 c
# 其 r
# 上開 v
# 行動 vn
# 電話 n
# 撥打 v
# 000000000000 m
# 號 m
# 電話 n
# 與 p
# 在 p
# 大陸 n
# 地區 n
# 之 u
# 朋友 n
# 聯繫 n
# 嗣在 t
# 臺灣省 ns
# 北部 f
# 某 r
# 隱密 a
# 處所 v
# 將子 n
# 屍體 n
# 及 c
# 沾有 v
# 子 ng
# 血液 n
# 之上 f
# 開 v
# 物品 n
# 湮滅 v
# 乙 n
# 因 p
# 在 p
# 搬運 v
# 子 ng
# 屍體 n
# 及 c
# 沾有 v
# 子 ng
# 血液 n
# 之 u
# 物品 n
# 之 u
# 過程 n
# 中 f
# 其 r
# 自身 r
# 背後 f
# 腰部 n
# 衣物 n
# 已 d
# 沾染 v
# 子 ng
# 之 u
# 血液 n
# 回程 n
# 中 f
# 發現 v
# 駕駛座 nz
# 竹蓆 n
# 及 c
# 汽車 n
# 後座 n
# 竹蓆 n
# 上均 j
# 沾有 v
# 子 ng
# 血跡 n
# 乃 v
# 將 d
# 表面 n
# 血跡 n
# 拭去 v
# 然 r
# 乙 n
# 未 d
# 詳細 ad
# 查看 v
# 子 ng
# 之 u
# 血液 n
# 已 d
# 從 p
# 竹蓆 n
# 縫隙 n
# 流下 v
# 殘留 v
# 在 p
# 竹蓆 n
# 背面 f
# 及 c
# 座椅 n
# 表面 n
# 另 r
# 在 p
# 汽車 n
# 後 f
# 行李 n
# 箱子 n
# 之 u
# 血液 n
# 則 d
# 從 p
# 屍袋 n
# 下 f
# 滲出 v
# 滴落 v
# 在 p
# 下方 f
# 之 u
# 遮陽 ns
# 片 q
# 紙張 n
# 及 c
# 接線 n
# 用 p
# 電線 n
# 上 f
# 並 c
# 逐漸 d
# 向下 v
# 滲透 v
# 至 p
# 遮陽 ns
# 片 q
# 下方 f
# 之 u
# 黑色 n
# 置 v
# 物墊 n
# 及 c
# 置物 n
# 墊下 v
# 方之 nr
# 木板 n
# 而於 c
# 同年 t
# 月 m
# 十五日 m
# 凌晨 t
# 三時 t
# 許 m
# 將 zg
# 汽車 n
# 駛回 v
# 丙 n
# 上址 n
# 住處 n
# 附近 f
# 停放 v
# 將車 n
# 交還 v
# 丙 n
# 六 m
# 乙 n
# 劫得 v
# 子 ng
# 之上 f
# 開 v
# 存摺 v
# 金融 n
# 卡 n
# 信用卡 n
# 及 c
# 支票 n
# 後 f
# 為 p
# 能 n
# 領取 v
# 上開 v
# 面額 n
# 六萬元 m
# 支票 n
# 之 u
# 款項 n
# 乃 v
# 於 nr
# 九十年 m
# 六月 t
# 十五日 m
# 上午 t
# 十時 t
# 許 m
# 至 p
# 臺北市 ns
# 路子 n
# 住處 n
# 附近 f
# 某 r
# 刻印 v
# 店 n
# 利用 n
# 不知情 i
# 之 u
# 店員 n
# 偽刻子 n
# 印章 n
# 一枚 m
# 攜至 v
# 臺北市 ns
# 路 n
# 段二 nr
# 三號 m
# 中國 ns
# 信託 n
# 銀行 n
# 忠孝 a
# 分行 v
# 在 p
# 上 f
# 開支票 n
# 背面 f
# 偽造子 n
# 印文 nz
# 一枚 m
# 以為 c
# 背書 n
# 而 c
# 偽造 v
# 私 n
# 文書 n
# 並 c
# 將 d
# 該 r
# 紙 n
# 支票 n
# 及 c
# 子 n
# 帳戶 n
# 存摺 v
# 交付 v
# 銀行 n
# 行員 n
# 辦理 n
# 支票 n
# 存款 n
# 而 c
# 行使 n
# 之 u
# 於 nr
# 同日 t
# 上午 t
# 十時 t
# 三十分 m
# 許 m
# 至 p
# 十一時 d
# 許間 m
# 再 d
# 返回 v
# 子 ng
# 上址 n
# 住處 n
# 將子 n
# 上開 v
# 存摺 v
# 及 c
# 偽刻 n
# 之 u
# 印章 n
# 放入 v
# 子 ng
# 臥室 n
# 衣櫃 n
# 抽屜 n
# 內 n
# 旋即 d
# 離去 v
# 乙 n
# 又 d
# 賡 nr
# 續 v
# 前 f
# 意圖 n
# 為 zg
# 自己 r
# 不法 n
# 之 u
# 所有 b
# 以 p
# 不正 d
# 方法 n
# 由 p
# 自動 vn
# 付款 v
# 設備 vn
# 取得 v
# 他人 r
# 之 u
# 物 ng
# 之 u
# 概括 v
# 犯意 v
# 持子 n
# 上開 v
# 金融 n
# 卡 n
# 於 nr
# 如 v
# 附表 n
# 一 m
# 編號 n
# 二 m
# 至 p
# 三 m
# 所示 v
# 之 u
# 時間 n
# 地點 n
# 由 p
# 自動 vn
# 付款 v
# 設備 vn
# 提領 v
# 如 v
# 附表 n
# 一 m
# 編號 n
# 二 m
# 至 p
# 三 m
# 所示 v
# 之 u
# 現金 n
# 合計 vn
# 共 d
# 四萬元 m
# 擬 v
# 在 p
# 臺北縣 ns
# 新莊市 ns
# 一帶 n
# 購買 v
# 皮革 n
# 樣品 n
# 攜 v
# 回大陸 nz
# 地區 n
# 乙 n
# 於 nr
# 如 v
# 附表 n
# 一 m
# 編號 n
# 四 m
# 所示 v
# 之 u
# 時間 n
# 地點 n
# 再持 v
# 子 ng
# 之 u
# 金融 n
# 卡 n
# 輸入 v
# 密碼 n
# 著手 v
# 提款 v
# 時 zg
# 因 p
# 上 f
# 開 v
# 面額 n
# 六萬元 m
# 支票 n
# 交換 v
# 未 d
# 完成 v
# 款項 n
# 尚未 d
# 存入 v
# 子 ng
# 帳戶 n
# 而 c
# 未 d
# 得逞 v
# 其 r
# 並 c
# 基於 p
# 意圖 n
# 為 zg
# 自己 r
# 不法 n
# 之 u
# 所有 b
# 及 c
# 行使 n
# 偽造 v
# 私 n
# 文書 n
# 詐欺 v
# 取財 v
# 之 u
# 概括 v
# 犯意 v
# 連續 a
# 於 nr
# 如 v
# 附表 n
# 二 m
# 編號 n
# 一至 d
# 十 m
# 所示 v
# 時間 n
# 地點 n
# 假冒 v
# 係 yg
# 子 ng
# 本人 r
# 行使 n
# 該 r
# 信用卡 n
# 刷卡 n
# 購買 v
# 如 v
# 附表 n
# 二 m
# 各 r
# 編號 n
# 所示 v
# 價值 n
# 之物 r
# 乙 n
# 並 c
# 先後 t
# 以 p
# 複寫 v
# 方式 n
# 在 p
# 如 r
# 附件 n
# 一至 d
# 附件 n
# 十 m
# 所示 v
# 之 u
# 二聯式 n
# 簽 zg
# 帳單 n
# 上 f
# 顧客 nr
# 存根聯 nz
# 及 c
# 特約商店 nt
# 存根聯 nz
# 分別 d
# 偽 j
# 簽 v
# 子 ng
# 中英文 nz
# 署押 v
# 作為 v
# 以 p
# 子 ng
# 名義 n
# 購物 n
# 消費 vn
# 允諾 v
# 付款 v
# 予發 v
# 卡 nr
# 銀行 n
# 之 u
# 意思 n
# 表示 v
# 而 c
# 偽造 v
# 簽 v
# 帳單 n
# 私 ag
# 文書 n
# 再 d
# 將 d
# 簽 v
# 帳單 n
# 特約商店 nt
# 存根聯 nz
# 交付 v
# 該 r
# 特約商店 nt
# 而 c
# 行使 n
# 之 u
# 使 v
# 各 r
# 特約商店 nt
# 及 c
# 中國 ns
# 信託 n
# 銀行 n
# 誤信 v
# 其 r
# 即 v
# 為 p
# 子 ng
# 本人 r
# 而 c
# 陷於 v
# 錯誤 n
# 交付 v
# 其 r
# 所 u
# 購買 v
# 如 v
# 附表 n
# 二 m
# 各 r
# 編號 n
# 所示 v
# 價值 n
# 之 u
# 物 ng
# 及 c
# 代為 v
# 墊款 n
# 共 d
# 三萬八千 m
# 七百 m
# 五十八 m
# 元 m
# 均足 a
# 生 vn
# 損害 v
# 於子 nr
# 各 r
# 特約商店 nt
# 財團法人 n
# 聯合 v
# 信用卡 n
# 處理 v
# 中心 n
# 及 c
# 中國 ns
# 信託 n
# 銀行 n
# 乙 n
# 並於 c
# 九十年 m
# 六月 t
# 十七日 m
# 下午 t
# 一時 d
# 四十一 m
# 分許 d
# 向 p
# 中華 nz
# 航空 n
# 股份 n
# 有限公司 n
# 下稱 v
# 中華 nz
# 航空公司 n
# 預定 v
# 同年 t
# 月 m
# 十九日 m
# 上午 t
# 七時 t
# 二十分 m
# 早班 n
# 飛機 n
# 機位 n
# 經由 p
# 香港 ns
# 轉赴 v
# 大陸 n
# 地區 n
# 以 p
# 逃避 v
# 警方 n
# 之 u
# 追緝 v
# 其 r
# 於 nr
# 同日 t
# 下午 t
# 並以 c
# 自子 n
# 帳戶 n
# 所 u
# 領 v
# 得 ud
# 之 u
# 款項 n
# 購買 v
# NOKIA eng
# 廠牌 n
# 八二三 m
# 型 k
# 行動 vn
# 電話 n
# 及 c
# 配備 v
# 又 d
# 於 nr
# 同年 t
# 月 m
# 十八日 m
# 晚間 t
# 向亥 nz
# 借款 n
# 二 m
# 萬元 m
# 並 c
# 表示 v
# 翌日 t
# 即 v
# 還款 v
# 七 m
# 子 ng
# 之 u
# 男友 n
# 甲 n
# 自 p
# 九十年 m
# 六月 t
# 十四日 m
# 中午 t
# 十二時 t
# 許 m
# 之後 f
# 多次 m
# 聯絡 n
# 子 ng
# 未果 n
# 疑有 v
# 不測 v
# 乃 v
# 告知 v
# 子 ng
# 之 u
# 友人 n
# 汪治華 nr
# 轉知 v
# 子 ng
# 胞姊 n
# 癸 zg
# 於 nr
# 同年 t
# 月 m
# 十五日 m
# 晚間 t
# 十一時 d
# 許 m
# 報警 n
# 會同 n
# 消防人員 n
# 推窗 v
# 進入 v
# 子 ng
# 上址 n
# 住處 n
# 之際 f
# 發現 v
# 大門 n
# 未 d
# 鎖 v
# 主 b
# 臥房 n
# 浴室 n
# 相當 d
# 整潔 a
# 然有 c
# 部分 n
# 物品 n
# 遭 v
# 異動 a
# 惟 b
# 不見 v
# 子 ng
# 而 c
# 子 n
# 日常 d
# 穿用 v
# 之 u
# 鞋子 n
# 均 d
# 在 p
# 屋內 s
# 又 d
# 發現 v
# 臥房 n
# 浴室 n
# 之 u
# 浴簾 n
# 沐浴 v
# 用品 n
# 等物 n
# 均 d
# 不翼而飛 i
# 詳細 ad
# 查看 v
# 在 p
# 臥房 n
# 浴室 n
# 內 n
# 發現 v
# 有 v
# 多處 m
# 血點 n
# 及 c
# 疑似 v
# 血跡 n
# 殘留 v
# 跡象 n
# 臥房 n
# 內 n
# 物品 n
# 陳設 nr
# 亦 d
# 遭 v
# 人 n
# 移動 vn
# 電話 n
# 答錄機 n
# 更 d
# 有 v
# 數十 m
# 通 v
# 留言 v
# 未 d
# 接聽 v
# 認為 v
# 可疑 v
# 乃 v
# 報 n
# 由 p
# 臺北市 ns
# 政府 n
# 警察局 n
# 指派 n
# 刑事 b
# 鑑識 v
# 人員 n
# 於 nr
# 同年 t
# 月 m
# 十六日 m
# 下午 t
# 一時 d
# 三十分 m
# 許 m
# 至 p
# 子 ng
# 上址 n
# 住處 n
# 進行 v
# 勘驗 vn
# 採證 v
# 結果 n
# 發現 v
# 子 ng
# 之 u
# 主臥室 n
# 床單 n
# 主臥室 n
# 浴室 n
# 內 f
# 之 u
# 浴缸 n
# 洗臉 v
# 檯 zg
# 馬桶 n
# 牆壁 s
# 地板 n
# 及 c
# 浴室 n
# 門板 n
# 等 u
# 多處 m
# 均 d
# 有 v
# 大量 n
# 血跡 n
# 反應 vn
# 且 c
# 有 v
# 擦抹 v
# 及 c
# 清洗 v
# 痕跡 n
# 經 zg
# 清查 vn
# 子 ng
# 平時 t
# 往來 t
# 之 u
# 友人 n
# 除 p
# 乙 n
# 外 f
# 其餘 r
# 均 d
# 已 d
# 出面 n
# 協助 v
# 調查 vn
# 經警 n
# 認為 v
# 可疑 v
# 遂 d
# 於 nr
# 同年 t
# 六月 t
# 十八日 m
# 通知 v
# 乙 n
# 出面 n
# 說明 v
# 乙 n
# 接獲 v
# 通知 v
# 後 f
# 於 nr
# 當日 t
# 晚間 t
# 十一時 d
# 許 m
# 在 p
# 丙 n
# 上址 n
# 住處 n
# 將 d
# 盜得 v
# 之 u
# 子 ng
# 金融 n
# 卡 n
# 交予 v
# 不知情 i
# 之 u
# 丙 n
# 並 c
# 告知 v
# 密碼 n
# 囑託 v
# 其代 t
# 為 p
# 提領 v
# 前 f
# 揭 v
# 存入 v
# 之 u
# 支票 n
# 款項 n
# 六萬元 m
# 其中 r
# 二 m
# 萬元 m
# 為 p
# 其 r
# 繳交 v
# 銀行 n
# 信用卡 n
# 費用 n
# 另 r
# 二 m
# 萬元 m
# 交付 v
# 不知情 i
# 之亥 ns
# 以 p
# 還 d
# 借款 n
# 剩餘 v
# 二 m
# 萬元 m
# 則 d
# 供 v
# 丙 n
# 家用 n
# 旋 d
# 於 nr
# 翌日 t
# 即 v
# 同年 t
# 月 m
# 十九日 m
# 搭乘 v
# 中華 nz
# 航空公司 n
# 上午 t
# 七時 t
# 二十分 m
# 之 u
# 早班 n
# 飛機 n
# 經由 p
# 香港 ns
# 轉赴 v
# 大陸 n
# 逃匿 v
# 丙 n
# 乃 v
# 於 nr
# 如 v
# 附表 n
# 一 m
# 編號 n
# 五 m
# 所示 v
# 之 u
# 時間 n
# 地點 n
# 依照 p
# 乙 n
# 指示 v
# 持子 n
# 上開 v
# 金融 n
# 卡分 n
# 三次 m
# 各 r
# 提領 v
# 二 m
# 萬元 m
# 合計 vn
# 共 d
# 提領 v
# 六萬元 m
# 嗣 ng
# 警方 n
# 自 p
# 銀行 n
# 提供 v
# 之 u
# 監視 v
# 錄影帶 n
# 查覺 v
# 係 y
# 丙 mg
# 提 v
# 領子 n
# 之 u
# 存款 n
# 乃 v
# 於 nr
# 同年 t
# 七月 t
# 二十七日 m
# 聲 q
# 請 v
# 搜索 v
# 票 n
# 前往 t
# 丙 n
# 住所 n
# 搜索 v
# 當場 s
# 扣得 v
# 丙 n
# 以 p
# 子 ng
# 上開 v
# 金融 n
# 卡 n
# 提領 v
# 之二 r
# 萬元 m
# 同時 c
# 對 p
# 丙 n
# 所有 b
# 車牌號碼 n
# 二 m
# 七 m
# 一九三 m
# 號 m
# 銀色 n
# 福特 ns
# Festiva eng
# 型 k
# 自用 v
# 小客車 n
# 進行 v
# 採證 v
# 結果 n
# 於 nr
# 該車 r
# 後 f
# 車廂 n
# 駕駛座 nz
# 及 c
# 後座 n
# 之 u
# 座椅 n
# 竹蓆 n
# 等 u
# 多處 m
# 均 d
# 採得 v
# 不明 v
# 血跡 n
# 經 p
# 將子 n
# 住處 n
# 及 c
# 丙 n
# 之 u
# 汽車 n
# 所 c
# 採得 v
# 之 u
# 血跡 n
# 送驗 v
# 結果 n
# 確認 v
# 均 d
# 與 p
# 子 ng
# DN eng
# A型 n
# 別 zg
# 相符 v
# 至此 d
# 確定 v
# 子 ng
# 已 d
# 遭 v
# 殺害 v
# 丙 n
# 於 nr
# 同年 t
# 七月 t
# 二十七日 m
# 至 p
# 大安 nz
# 分局 n
# 說明 v
# 時 ng
# 並以 c
# 電話 n
# 勸說 v
# 乙 n
# 返臺 v
# 乙 n
# 為 zg
# 避免 v
# 不知情 i
# 之 u
# 丙 n
# 因 p
# 提款 v
# 及 c
# 丙 n
# 所有 b
# 二 m
# 七 m
# 一九三 m
# 號 m
# 自小 d
# 客車 n
# 內 f
# 被 p
# 採驗 vn
# 到 v
# 多處 m
# 子 ng
# 血跡 n
# 之 u
# 事 n
# 無法解釋 n
# 而 c
# 受 v
# 牽連 v
# 遂 d
# 於 nr
# 同年 t
# 九月 t
# 十一日 m
# 返臺 v
# 接受 v
# 調查 vn
# 八 m
# 案經 n
# 臺北市 ns
# 政府 n
# 警察局 n
# 大安 nz
# 分局 n
# 報告 n
# 臺灣 ns
# 臺北 ns
# 地方法院 nt
# 檢察署 n
# 檢察官 n
# 偵查 v
# 起訴 v
# 理由 n
# 壹 zg
# 乙 n
# 部分 n
# 一 m
# 訊 ng
# 據 p
# 被告 n
# 乙 n
# 於 nr
# 本院 n
# 審理 vn
# 時對其 nr
# 係 zg
# 普通高中 ns
# 華僑 n
# 中學畢業 n
# 嗣 ng
# 服役 n
# 於 nr
# 海軍陸戰隊 nt
# 士官 n
# 班 n
# 退役 v
# 後 nr
# 曾 d
# 與 p
# 軍中 s
# 同袍 n
# 庚 nr
# 等 u
# 人 n
# 往來 t
# 其 r
# 於 nr
# 八十三 m
# 年間 t
# 向庚 nr
# 借款 n
# 新臺幣 n
# 十萬元 m
# 未 d
# 還 d
# 後 nr
# 即未 d
# 與 p
# 庚 nr
# 等 u
# 人 n
# 聯絡 n
# 其 r
# 於 nr
# 八十八年 m
# 間與亥 nz
# 離婚 v
# 嗣 ng
# 赴 v
# 大陸 n
# 地區 n
# 經營 vn
# 皮革 n
# 生意 v
# 其間 r
# 陸續 d
# 向 p
# 丙 n
# 借款 n
# 四百餘萬 m
# 元 m
# 並 c
# 曾 d
# 以 p
# 亥 t
# 名義 n
# 向 p
# 中國 ns
# 信託 n
# 銀行貸款 n
# 十五萬元 m
# 所 c
# 借得 v
# 款項 n
# 悉數 d
# 攜往 v
# 大陸 n
# 地區 n
# 投資 vn
# 每月 r
# 由 p
# 丙 n
# 代向 n
# 中國 ns
# 信託 n
# 銀行 n
# 清償 vn
# 三千 m
# 四百 m
# 九十一 m
# 元 m
# 亥 t
# 於 nr
# 八十九年 m
# 三月 m
# 二十日 m
# 要求 v
# 乙 n
# 一次 m
# 清償 vn
# 上開 v
# 借款 n
# 其 r
# 因 c
# 無力 n
# 還款 v
# 乃 v
# 簽發 v
# 本票 n
# 擔保 v
# 並 c
# 承諾 v
# 於 nr
# 到期日 l
# 前 f
# 還款 v
# 並於 c
# 同日 t
# 簽發 v
# 票號 n
# 二三 m
# 八七 m
# 九 m
# 號 m
# 面額 n
# 五萬 m
# 七千元 m
# 到期日 l
# 八十九年 m
# 十月 t
# 三十一日 m
# 票號 n
# 二三 m
# 八七 m
# 八九 m
# 號 m
# 面額 n
# 五萬五千 m
# 元 m
# 到期日 l
# 九十年 m
# 三月 m
# 三十一日 m
# 及 c
# 票號 n
# 二三 m
# 八七 m
# 八七 m
# 號 m
# 面額 n
# 十五萬元 m
# 到期日 l
# 九十四年 m
# 三月 m
# 三十一日 m
# 之 u
# 本票 n
# 各 r
# 一紙 m
# 承諾 v
# 於 nr
# 本票 n
# 到期日 l
# 時 zg
# 清償 vn
# 票面 n
# 金額 n
# 又 d
# 被告 n
# 丙 n
# 所 c
# 申請 v
# 之 u
# 公教人員 n
# 低利 n
# 貸款 n
# 將 d
# 於 nr
# 九十一 m
# 年底 t
# 核准 n
# 遂 d
# 告知 v
# 被告 n
# 乙 n
# 需款 n
# 以 p
# 該 r
# 低利 n
# 貸款 n
# 購屋 n
# 請 zg
# 被告 n
# 乙 n
# 返還 v
# 先前 t
# 支借 v
# 之 u
# 款項 n
# 被告 n
# 乙 n
# 於 nr
# 九十年 m
# 五月 t
# 十五日 m
# 自 p
# 大陸 n
# 地區 n
# 返臺 v
# 後 nr
# 遂 d
# 承諾 v
# 於 nr
# 九十年 m
# 六月 t
# 間會 n
# 將 d
# 先前 t
# 之 u
# 借款 n
# 返還 v
# 其 r
# 於 nr
# 八十八年 m
# 年底 t
# 透過 v
# 卯 t
# 介紹 v
# 而 c
# 結識 n
# 經濟 n
# 狀況 n
# 優渥 a
# 之 u
# 被害人 n
# 子 ng
# 女 b
# 五十年 m
# 六月 t
# 二十日 m
# 生 vn
# 身分證 n
# 統一 vn
# 編號 n
# 000000000 m
# 號 m
# 初時 t
# 並未 d
# 深入 v
# 交往 v
# 自 p
# 九十年 m
# 五月 t
# 十五日 m
# 其 r
# 從 p
# 大陸 n
# 地區 n
# 返臺 v
# 後 nr
# 於 nr
# 同年 t
# 六月 t
# 上旬 t
# 開始 v
# 與 zg
# 被害人 n
# 子 ng
# 展開 v
# 密切聯繫 l
# 其 r
# 於 nr
# 九十年 m
# 六月 t
# 間 f
# 並 c
# 曾 d
# 邀約 v
# 於 nr
# 二 m
# 春 tg
# 聯誼 nz
# 認識 v
# 之 u
# 女子 n
# 天 q
# 投資 vn
# 一百萬元 m
# 在 p
# 其 r
# 大陸 n
# 地區 n
# 之 u
# 皮革 n
# 生意 v
# 惟 b
# 未經 d
# 天 q
# 應允 v
# 其為 c
# 能 v
# 領取 v
# 上開 v
# 面額 n
# 六萬元 m
# 支票 n
# 之 u
# 款項 n
# 乃 v
# 於 nr
# 九十年 m
# 六月 t
# 十五日 m
# 上午 t
# 十時 t
# 許 m
# 至 p
# 臺北市 ns
# 路 n
# 被害人 n
# 子 ng
# 住處 n
# 附近 f
# 某 r
# 刻印 v
# 店 n
# 請 v
# 店員 n
# 刻子 n
# 印章 n
# 一枚 m
# 攜至 v
# 臺北市 ns
# 路 n
# 段二 nr
# 三號 m
# 中國 ns
# 信託 n
# 銀行 n
# 忠孝 a
# 分行 v
# 在 p
# 支票 n
# 號碼 n
# AH0000000 eng
# 號 m
# 面額 n
# 六萬元 m
# 發票 n
# 人 n
# 為 p
# 辛 nr
# 受款 v
# 人 n
# 為 p
# 子 ng
# 發票 n
# 日 m
# 為 p
# 九十年 m
# 六月 t
# 十四日 m
# 付款人 n
# 為 zg
# 中國 ns
# 信託 n
# 銀行 n
# 總行 n
# 儲蓄 n
# 部 q
# 之 f
# 支票 n
# 背面 f
# 蓋 v
# 印子 n
# 印文 nz
# 一枚 m
# 以為 c
# 背書 n
# 並 c
# 將 d
# 該 r
# 紙 n
# 支票 n
# 及 c
# 子 n
# 帳戶 n
# 存摺 v
# 交付 v
# 銀行 n
# 行員 n
# 辦理 n
# 支票 n
# 存款 n
# 並 c
# 持子 n
# 所有 b
# 之 u
# 中國 ns
# 信託 n
# 銀行 n
# 忠孝 a
# 分行 v
# 帳號 n
# 0000000000 m
# 號 m
# 帳戶 n
# 金融 n
# 卡 n
# 於 nr
# 如 v
# 附表 n
# 一 m
# 編號 n
# 二 m
# 至 p
# 三 m
# 所示 v
# 之 u
# 時間 n
# 地點 n
# 由 p
# 自動 vn
# 付款 v
# 設備 vn
# 提領 v
# 如 v
# 附表 n
# 一 m
# 編號 n
# 二 m
# 至 p
# 三 m
# 所示 v
# 之 u
# 現金 n
# 合計 vn
# 共 d
# 四萬元 m
# 擬 v
# 在 p
# 臺北縣 ns
# 新莊市 ns
# 一帶 n
# 購買 v
# 皮革 n
# 樣品 n
# 攜 v
# 回大陸 nz
# 地區 n
# 其 r
# 於 nr
# 附表 n
# 一 m
# 編號 n
# 四 m
# 所示 v
# 之 u
# 時間 n
# 地點 n
# 再持 v
# 子 ng
# 上開 v
# 金融 n
# 卡 n
# 輸入 v
# 密碼 n
# 著手 v
# 提款 v
# 時 zg
# 因 p
# 上 f
# 開 v
# 面額 n
# 六萬元 m
# 支票 n
# 交換 v
# 未 d
# 完成 v
# 尚未 d
# 存入 v
# 子 ng
# 帳戶 n
# 而 c
# 未領 v
# 得 ud
# 款項 n
# 其 r
# 並於 c
# 九十年 m
# 六月 t
# 十八日 m
# 下午 t
# 十一時 d
# 許 m
# 在 p
# 丙 n
# 上址 n
# 住處 n
# 將子 n
# 上開 v
# 金融 n
# 卡 n
# 交予 v
# 丙 n
# 囑託 v
# 丙 n
# 代為 v
# 提領 v
# 前 f
# 揭 v
# 存入 v
# 之 u
# 支票 n
# 款項 n
# 六萬元 m
# 指示 v
# 其中 r
# 二 m
# 萬元 m
# 為 p
# 其 r
# 繳交 v
# 銀行 n
# 信用卡 n
# 費用 n
# 另 r
# 二 m
# 萬元 m
# 交付 v
# 亥 t
# 以 p
# 還 d
# 借款 n
# 剩餘 v
# 二 m
# 萬元 m
# 則 d
# 供 v
# 丙 n
# 家用 n
# 而於 c
# 同年 t
# 月 m
# 十九日 m
# 搭乘 v
# 中華 nz
# 航空公司 n
# 上午 t
# 七時 t
# 二十分 m
# 之 u
# 早班 n
# 飛機 n
# 經由 p
# 香港 ns
# 轉赴 v
# 大陸 n
# 地區 n
# 之 u
# 事實 n
# 均 d
# 坦承 v
# 不諱 v
# 並經 d
# 證人 n
# 庚 nr
# 於 nr
# 本院 n
# 調查 vn
# 時 zg
# 到庭 d
# 證述 v
# 詳確 ad
# 詳 ag
# 後述 b
# 惟 b
# 矢口否認 i
# 有 v
# 右 f
# 揭 v
# 強盜 n
# 殺人 n
# 行使 n
# 偽造 v
# 私 n
# 文書 n
# 詐欺 v
# 取財 v
# 及以 c
# 不正 d
# 方法 n
# 由 p
# 自動 vn
# 付款 v
# 設備 vn
# 取得 v
# 他人 r
# 之 u
# 物 ng
# 之 u
# 犯行 v
# 辯稱 v
# 其 r
# 在 p
# 大陸 n
# 的 uj
# 事業 n
# 是 v
# 與 p
# 妹妹 n
# 丙 n
# 一起 m
# 做 v
# 的 uj
# 丙 n
# 陸陸續續 n
# 給 p
# 伊 ns
# 四百餘萬 m
# 元 m
# 名義 n
# 上 f
# 她 r
# 沒有 v
# 股份 n
# 其 r
# 向 p
# 亥 t
# 借 v
# 的 uj
# 錢 n
# 有 v
# 陸續 d
# 在 p
# 還 d
# 其 r
# 於 nr
# 九十年 m
# 五月 t
# 中旬 t
# 自 p
# 大陸 n
# 地區 n
# 返臺 v
# 才 d
# 與 p
# 子 ng
# 談及 v
# 感情 n
# 子 ng
# 說 v
# 她 r
# 與 p
# 前男友 n
# 已 d
# 分手 v
# 其 r
# 二人 nrt
# 後來 t
# 就 d
# 一直 d
# 交往 v
# 從 zg
# 同年 t
# 六月 t
# 初 f
# 直到 v
# 其 r
# 返回 v
# 大陸 n
# 一直 d
# 有 v
# 密集 n
# 的 uj
# 約會 n
# 其 r
# 於 nr
# 九十年 m
# 六月 t
# 十一日 m
# 晚間 t
# 八時 t
# 許 m
# 第一次 m
# 也 d
# 是 v
# 最後 f
# 一次 m
# 到 v
# 子 ng
# 位於 v
# 臺北市 ns
# 大安區 ns
# 路 n
# 段 q
# 二五 m
# 三巷 nz
# 三十二 m
# 號 m
# 二樓 n
# 住處 n
# 當時 t
# 與 p
# 子 ng
# 談到 v
# 投資 vn
# 之 u
# 事 n
# 子 ng
# 請 v
# 伊 j
# 從 p
# 大陸 n
# 地區 n
# 帶 v
# 羽 nr
# 繡 v
# 回臺 v
# 送 v
# 養父母 nr
# 作 v
# 聖誕節 t
# 禮物 n
# 羽 nr
# 繡 v
# 價格 n
# 很 d
# 高 a
# 伊 ns
# 預估 vn
# 一張 m
# 價格 n
# 在 p
# 六萬元 m
# 到 v
# 八萬元 m
# 之間 f
# 其 r
# 將 d
# 公司 n
# 週轉 nr
# 準備金 n
# 閒錢 n
# 都 d
# 集中 v
# 在 p
# 大陸 n
# 地區 n
# 成都 ns
# 作 v
# 換匯 nz
# 投資 vn
# 就 d
# 建議 n
# 子 ng
# 可 v
# 拿 v
# 人民幣 n
# 三萬元 m
# 約 d
# 新臺幣 n
# 十二 m
# 萬元 m
# 從事 v
# 換匯 nz
# 投資 vn
# 半年 m
# 獲利 v
# 可 v
# 累積到 l
# 新臺幣 n
# 六 m
# 至 p
# 八萬元 m
# 以 p
# 獲利 v
# 就 d
# 可 v
# 購買 v
# 羽 nr
# 繡 v
# 子 ng
# 說 zg
# 可以 c
# 其 r
# 於 nr
# 九十年 m
# 六月 t
# 十一日 m
# 在 p
# 子 ng
# 住處 n
# 當晚 t
# 其 r
# 二人 nrt
# 有 v
# 親密 a
# 動作 n
# 其 r
# 取笑 v
# 子 ng
# 大概 d
# 有 v
# 四十四 m
# 四十五 m
# 公斤 q
# 以上 f
# 子 ng
# 說 v
# 她 r
# 只有 c
# 四十公斤 m
# 就 d
# 從 p
# 浴室 n
# 拿 v
# 磅秤 n
# 出來 v
# 放在 v
# 浴室 n
# 門口 s
# 量體重 l
# 當時 t
# 其 r
# 手扶 b
# 在 p
# 浴室 n
# 門口 s
# 地面 n
# 看 v
# 體重 n
# 機 n
# 那時 r
# 房間 n
# 燈 n
# 沒有 v
# 開 v
# 只有 c
# 浴室 n
# 的 uj
# 燈 n
# 看完 v
# 磅秤 n
# 後 nr
# 伊 j
# 就 d
# 馬上 d
# 退 v
# 出來 v
# 九十年 m
# 六月 t
# 十三日 m
# 中午 t
# 其 r
# 與 p
# 子 ng
# 至 p
# 臺北市 ns
# 路 n
# 太平洋百貨 nz
# 左側 f
# 巷內 s
# 福果 n
# 巴西 ns
# 窯 n
# 烤 v
# 餐廳 n
# 用餐 n
# 當時 t
# 子 ng
# 說 v
# 其 r
# 等 u
# 被 p
# 人 n
# 跟蹤 v
# 因此 c
# 在 p
# 餐廳 n
# 留 v
# 到 v
# 下午 t
# 三 m
# 四時 t
# 許由 n
# 其以 c
# 荷蘭銀行 nt
# 信用卡 n
# 買單 n
# 後 f
# 離開 v
# 伊 j
# 去 v
# 買單 n
# 時 zg
# 子 ng
# 在 p
# 餐廳 n
# 門口 s
# 等 u
# 伊 j
# 買單 n
# 後 nr
# 子 ng
# 在 p
# 餐廳 n
# 門口 s
# 交給 v
# 伊 ns
# 中國 ns
# 信託 n
# 銀行 n
# 金融 n
# 卡 n
# 一本 m
# 存摺 v
# 內 f
# 夾有 v
# 一張 m
# 受款 v
# 人 n
# 是 v
# 子 ng
# 面額 n
# 六萬元 m
# 的 uj
# 支票 n
# 她 r
# 說 v
# 戶頭 n
# 裡 f
# 有 v
# 六萬元 m
# 本來 t
# 要 v
# 去 v
# 存 v
# 支票 n
# 但 c
# 時間 n
# 可能 v
# 來不及 v
# 伊 ns
# 可以 c
# 提領 v
# 戶頭 n
# 內 n
# 六萬元 m
# 連同 a
# 支票 n
# 六萬元 m
# 共 d
# 十二 m
# 萬元 m
# 當 t
# 投資 vn
# 款 m
# 並 c
# 告訴 v
# 伊 ns
# 金融 n
# 卡 n
# 密碼 n
# 九十年 m
# 六月 t
# 十二日 m
# 下午 t
# 伊與子 nr
# 為了 p
# 感情 n
# 的 uj
# 事 n
# 有點 n
# 僵持 v
# 同年 t
# 月 m
# 十四日 m
# 是 v
# 其 r
# 與 p
# 子 ng
# 最後 f
# 一次 m
# 聯絡 n
# 當天 t
# 上午 t
# 十一時 d
# 左右 m
# 其 r
# 到 v
# 子 ng
# 上址 n
# 住處 n
# 按 p
# 門鈴 n
# 沒有 v
# 人 n
# 回應 v
# 伊 ns
# 離開 v
# 一百 m
# 公尺 q
# 左右 m
# 打電話 l
# 給 p
# 子 ng
# 有 v
# 接通 v
# 伊 j
# 問子 n
# 可否 v
# 一起 m
# 吃 v
# 午飯 n
# 子 ng
# 說 zg
# 不行 v
# 她 r
# 要 v
# 馬上 d
# 出去 v
# 其 r
# 於 nr
# 同年 t
# 月 m
# 十四日 m
# 下午 t
# 又 d
# 去 v
# 子 ng
# 住處 n
# 按 p
# 電鈴 n
# 沒有 v
# 回應 v
# 也 d
# 沒有 v
# 再 d
# 打電話 l
# 給 p
# 子 ng
# 就 d
# 去 v
# 提款機 n
# 領出 v
# 二 m
# 萬元 m
# 當時 t
# 沒有 v
# 刻意 v
# 要領 v
# 錢 n
# 只是 c
# 要 v
# 試 v
# 密碼 n
# 對 p
# 不對 d
# 輸入 v
# 密碼 n
# 後 f
# 跳出 v
# 提款 v
# 金額 n
# 原本 n
# 沒有 v
# 要領 v
# 錢 n
# 但 c
# 因 p
# 跳出 v
# 提款 v
# 金額 n
# 的 uj
# 螢幕 n
# 伊 j
# 就 d
# 按了 p
# 二 m
# 萬元 m
# 因為 c
# 跨行 v
# 最 d
# 多 m
# 只能 v
# 領 v
# 二 m
# 萬元 m
# 其 r
# 於 nr
# 同日 t
# 下午 t
# 五時 t
# 許 m
# 向 p
# 丙 n
# 商借 v
# 丙 n
# 所有 b
# 車牌號碼 n
# 二 m
# 七 m
# 一九三 m
# 號 m
# 銀色 n
# 福特 ns
# Festiva eng
# 型 k
# 自用 v
# 小客車 n
# 於 nr
# 同日 t
# 下午 t
# 七時 t
# 許 m
# 在 p
# 丙 n
# 臺北縣 ns
# 永和市 ns
# 路 n
# 一 m
# 五一 m
# 巷五 n
# 弄 v
# 五號 m
# 住處 n
# 前 f
# 取得 v
# 該 r
# 自用 v
# 小客車 n
# 後 f
# 即 v
# 駛往 v
# 瑞芳 nr
# 找 v
# 朋友 n
# 天 q
# 及 c
# 往 p
# 金山 nr
# 找 v
# 多年不見 l
# 之 u
# 友人 n
# 庚 nr
# 但 c
# 都 d
# 沒有 v
# 找到 v
# 伊從 nr
# 金山 nr
# 離 v
# 開時 v
# 已 d
# 接近 v
# 凌晨 t
# 回到 v
# 自己 r
# 住處 n
# 已經 d
# 翌日 t
# 即 v
# 十五日 m
# 凌晨 t
# 三時 t
# 許 m
# 其 r
# 於 nr
# 同年 t
# 月 m
# 十四日 m
# 之後 f
# 就 d
# 沒有 v
# 主動 b
# 聯絡 n
# 子 ng
# 同年 t
# 月 m
# 十九日 m
# 出境 n
# 前 f
# 沒有 v
# 再 d
# 找 v
# 過子 n
# 九十年 m
# 六月 t
# 十五日 m
# 上午 t
# 十時 t
# 許 m
# 其 r
# 將 d
# 上開 v
# 面額 n
# 六萬元 m
# 支票 n
# 存入 v
# 子 ng
# 帳戶 n
# 銀行 n
# 行員 n
# 要求 v
# 應有 v
# 子 ng
# 之 u
# 背書 n
# 伊就子 nr
# 住處 n
# 按 p
# 門鈴 n
# 沒有 v
# 人 n
# 應門 v
# 其 r
# 就 d
# 在 p
# 子 ng
# 住處 n
# 附近 f
# 刻印 v
# 店刻子 n
# 印章 n
# 一枚 m
# 蓋 v
# 在 p
# 支票 n
# 背面 f
# 又 d
# 去 v
# 存 v
# 支票 n
# 再 d
# 把子 n
# 之 u
# 存摺 v
# 印章 n
# 放在 v
# 子 ng
# 住處 n
# 之 u
# 信箱 n
# 內 n
# 就 d
# 直接 ad
# 回家 n
# 對於 i
# 丙 n
# 上開 v
# 汽車 n
# 上 f
# 有 v
# 子 ng
# 血跡 n
# 之 u
# 事 n
# 伊 ns
# 無法解釋 n
# 子 ng
# 沒有 v
# 坐過 v
# 這輛 mq
# 汽車 n
# 也 d
# 不 d
# 認識 v
# 丙 n
# 伊 j
# 認為 v
# 血跡 n
# 是 v
# 真正 d
# 殺害 v
# 子 ng
# 的 uj
# 人 n
# 栽贓 vn
# 給 p
# 伊 ns
# 將 zg
# 血跡 n
# 直接 ad
# 滴落 v
# 在 p
# 丙 n
# 汽車 n
# 上 f
# 伊 ns
# 原本 n
# 即 v
# 預定 v
# 九十年 m
# 六月 t
# 十九日 m
# 前往 t
# 大陸 n
# 地區 n
# 中華 nz
# 航空公司 n
# 機位 n
# 三天 m
# 前 f
# 預定 v
# 就 d
# 會 v
# 有機 n
# 位 q
# 其 r
# 機票 n
# 是 v
# 在 p
# 大陸 n
# 地區 n
# 買 v
# 的 uj
# 並 c
# 沒有 v
# 畏罪潛逃 i
# 云云 nr
# 選任 v
# 辯護人 n
# 為 zg
# 被告 n
# 辯護 v
# 稱 zg
# 子 ng
# 於 nr
# 九十年 m
# 六月 t
# 十三日 m
# 與 zg
# 被告 n
# 共進午餐 n
# 後 f
# 將 d
# 其 r
# 存摺 v
# 金融 n
# 卡及 ns
# 六萬元 m
# 之 u
# 客票 n
# 交予 v
# 被告 n
# 係 yg
# 作 v
# 為 p
# 購買 v
# 成都 ns
# 羽繡 n
# 而 c
# 投資 vn
# 十二 m
# 萬元 m
# 在 p
# 大陸 n
# 被告 n
# 生意 v
# 之用 r
# 並 c
# 告知 v
# 被告 n
# 乙 n
# 金融 n
# 卡 n
# 密碼 n
# 亦 d
# 告知 v
# 被告 n
# 於 nr
# 支票 n
# 存入 v
# 後 nr
# 將 d
# 存摺 v
# 放回 v
# 其 r
# 信箱 n
# 被告 n
# 於 nr
# 九十年 m
# 六月 t
# 十四日 m
# 並未 d
# 與 p
# 子 ng
# 見面 n
# 更 d
# 遑論 n
# 有 v
# 進入 v
# 子 ng
# 房間 n
# 而 c
# 將 d
# 其 r
# 殺害 v
# 被告 n
# 在 p
# 九十年 m
# 六月 t
# 十四日 m
# 上午 t
# 十點 m
# 多 m
# 出門 v
# 在 p
# 十一時 d
# 許 m
# 至 p
# 復興 a
# 南路 ns
# 之 u
# 子 ng
# 家 m
# 按 p
# 門鈴 n
# 因子 n
# 未 d
# 開門 v
# 故在 d
# 離 v
# 其家 r
# 不遠處 s
# 打 v
# 其 r
# 行動 vn
# 電話 n
# 問 v
# 其 r
# 可不可以 c
# 一起 m
# 吃 v
# 午飯 n
# 因子 n
# 表示 v
# 有事 r
# 外出 v
# 被告 n
# 乙 n
# 僅 d
# 在 p
# 附近 f
# 單獨 d
# 用餐 n
# 並 c
# 在 p
# 下午 t
# 四時 t
# 十八分 m
# 利用 n
# 附近 f
# 之 u
# 仁愛路 nr
# 四段 m
# 一號 m
# 萬 m
# 通商 n
# 銀 ng
# 儲蓄 n
# 部 n
# 提款機 n
# 以上 f
# 揭子 n
# 所 c
# 交付 v
# 之 u
# 金融 n
# 卡及依 nr
# 之前 f
# 所 c
# 告知 v
# 密碼 n
# 先 d
# 提款 v
# 二 m
# 萬元 m
# 以 p
# 瞭解 v
# 子 ng
# 所 c
# 告知 v
# 之 u
# 密碼 n
# 有無 v
# 錯誤 n
# 被告 n
# 因 p
# 即將 d
# 出國 v
# 打算 v
# 至 p
# 瑞芳 nr
# 金山 nr
# 等 u
# 處 n
# 尋友 nr
# 故於 c
# 備 v
# 妥 a
# 晚餐 n
# 並 c
# 陪 v
# 小孩 n
# 吃完飯 l
# 後 nr
# 之 u
# 約 d
# 晚間 t
# 七時 t
# 許 m
# 即至 c
# 丙 n
# 住處 n
# 借 v
# 其 r
# 所有 b
# 自小 d
# 客車 n
# 使用 v
# 且 c
# 先至 d
# 瑞芳 nr
# 找 v
# 以前 f
# 在 p
# 聯誼會 nt
# 所 c
# 認識 v
# 並 c
# 擔任 v
# 插花 n
# 老師 n
# 天 q
# 因此 c
# 車經 n
# 福和 ns
# 橋 n
# 高架橋 ns
# 基隆 nz
# 路 n
# 辛亥 m
# 路下 s
# 右轉 n
# 後 f
# 即 v
# 上北 ns
# 二高 nrt
# 中山 ns
# 高 a
# 並 c
# 下來 t
# 走 v
# 瑞 j
# 八 n
# 公路 n
# 並 c
# 在 p
# 瑞芳 nr
# 下車 v
# 找 v
# 天 q
# 之 u
# 住家 n
# 惟天 b
# 並未 d
# 在家 r
# 且 zg
# 被告 n
# 行經 n
# 基隆 nz
# 路 n
# 時 ng
# 因 p
# 車上 s
# 霧氣 n
# 未除 v
# 亦 d
# 有 v
# 於 nr
# 晚間 t
# 八時 t
# 九分 m
# 許 m
# 在 p
# 基隆 nz
# 路 n
# 電 n
# 請 v
# 其 r
# 妹 n
# 解決 v
# 被告 n
# 再 d
# 前往 t
# 金山 nr
# 尋找 v
# 其 r
# 在 p
# 軍中 s
# 友人 n
# 庚 nr
# 蓋庚 nr
# 之前 f
# 曾 d
# 借錢 v
# 給 p
# 被告 n
# 對 p
# 被告 n
# 有 v
# 恩 nr
# 惟 b
# 被告 n
# 祇 yg
# 知 v
# 其 r
# 在 p
# 臺電 j
# 老梅 nr
# 分駐 v
# 所 u
# 上班 v
# 且 zg
# 被告 n
# 與其 c
# 亦 d
# 有 v
# 五 m
# 六年 m
# 時間 n
# 沒 v
# 聯繫 n
# 故 n
# 想要 v
# 去 v
# 看看 v
# 伊 ns
# 並 c
# 將 d
# 之前 f
# 借錢 v
# 還給 v
# 伊 ns
# 且 zg
# 被告 n
# 以前 f
# 亦 d
# 曾 d
# 在 p
# 該 r
# 友人 n
# 上班 v
# 地點 n
# 找 v
# 過 ug
# 庚 m
# 該 r
# 友人 n
# 亦 d
# 因 p
# 正在 t
# 值班 v
# 而 c
# 碰巧 d
# 遇上 v
# 故 n
# 被告 n
# 再 d
# 駕車 n
# 走 v
# 濱海 ns
# 之 u
# 瑞 j
# 八 n
# 公路 n
# 之 u
# 金山 nr
# 惟未 d
# 找著 v
# 又 d
# 該 r
# 日 m
# 雨 n
# 下得 v
# 很大 a
# 因此 c
# 被告 n
# 祇 y
# 得 ud
# 在 p
# 金山 nr
# 核電廠 n
# 附近 f
# 停車場 n
# 休息 v
# 且 zg
# 被告 n
# 於 nr
# 六月 t
# 十五日 m
# 凌晨 t
# 一時 d
# 十三分 m
# 與 zg
# 大陸 n
# 四川 ns
# 友人 n
# 張 zg
# 瓊花 nz
# 電話 n
# 聯繫 n
# 大陸 n
# 生意 v
# 之 u
# 事 n
# 且 zg
# 被告 n
# 亦 d
# 經常 d
# 利用 n
# 半夜 m
# 與 p
# 該 r
# 友人 n
# 聯繫 n
# 事情 n
# 祇 yg
# 因 p
# 其時 r
# 電話費 n
# 折半 v
# 其後 c
# 被告 n
# 亦 d
# 將 d
# 該車 r
# 駛回 v
# 丙 n
# 住處 n
# 之 u
# 門口 s
# 附近 f
# 停靠 v
# 並 c
# 將 d
# 鑰匙 n
# 放進 v
# 其 r
# 妹 n
# 住處 n
# 之 u
# 信箱 n
# 內 n
# 其時 r
# 已 d
# 係 yg
# 六月 t
# 十五日 m
# 凌晨 t
# 二點 m
# 多 m
# 被告 n
# 即 v
# 返回 v
# 其 r
# 住處 n
# 就寢 v
# 故 n
# 被告 n
# 於 nr
# 九十年 m
# 六月 t
# 十四日 m
# 並未 d
# 遇到 v
# 子 ng
# 又 d
# 豈 d
# 可能 v
# 於 e
# 該 r
# 日 m
# 殺害 v
# 子 ng
# 之 u
# 理 n
# 本件 n
# 被告 n
# 雖有 c
# 於 nr
# 九十年 m
# 六月 t
# 十五日 m
# 為 p
# 子 ng
# 代刻 n
# 一枚 m
# 印章 n
# 並 c
# 將 d
# 該 r
# 紙 n
# 客票 n
# 存入 v
# 子 ng
# 在 p
# 銀行 n
# 之 u
# 戶頭 n
# 內 n
# 並 c
# 無 v
# 違背 v
# 常理 n
# 因子 n
# 委託 n
# 被告 n
# 提款 v
# 投資 vn
# 被告 n
# 為 p
# 不 d
# 使 v
# 子 ng
# 失望 v
# 即 v
# 在 p
# 子 ng
# 附近 f
# 刻印 v
# 店委 n
# 其代 t
# 刻子 n
# 之 u
# 印章 n
# 再 d
# 蓋 v
# 該 r
# 紙 n
# 客票 n
# 背面 f
# 並至 c
# 該 r
# 銀行 n
# 提示 v
# 又 d
# 被告 n
# 於 nr
# 辦妥 v
# 後 f
# 亦 d
# 持有 v
# 上 f
# 揭 v
# 存摺 v
# 及 c
# 印章 n
# 置於 v
# 信封 v
# 並 c
# 放入 v
# 子 ng
# 住處 n
# 樓下 s
# 之 u
# 信箱 n
# 內 n
# 並 c
# 無 v
# 違背 v
# 常理 n
# 依 d
# 案發後 n
# 搜索 v
# 子 ng
# 住處 n
# 亦 d
# 有 v
# 發現 v
# 上 f
# 揭 v
# 存摺 v
# 在 p
# 其 r
# 抽屜 n
# 內 n
# 並 c
# 與其 c
# 他 r
# 存摺 v
# 放在 v
# 一起 m
# 且 zg
# 印章 n
# 亦 d
# 應 v
# 放在 v
# 其內 f
# 顯 v
# 係 zg
# 有人 r
# 在 p
# 九十年 m
# 六月 t
# 十五日 m
# 已將 d
# 上 f
# 揭 v
# 存摺 v
# 及 c
# 印章 n
# 自 p
# 樓下 s
# 之 u
# 信箱 n
# 取出 v
# 並 c
# 放回 v
# 被害人 n
# 住處 n
# 之 u
# 抽屜 n
# 內 n
# 且 zg
# 被告 n
# 若 c
# 有 v
# 盜取 v
# 子 ng
# 之 u
# 財物 n
# 又 d
# 豈 d
# 可能 v
# 將 d
# 上 f
# 揭 v
# 存摺 v
# 及 c
# 印章 n
# 放回 v
# 子 ng
# 樓下 s
# 之 u
# 信箱 n
# 內 n
# 若 c
# 被告 n
# 既有 c
# 將 zg
# 上將 n
# 存摺 v
# 及 c
# 印章 n
# 放回 v
# 子 ng
# 住處 n
# 之 u
# 抽屜 n
# 內 n
# 又 d
# 豈 d
# 有 v
# 不 d
# 將 d
# 抽屜 n
# 內 f
# 之 u
# 其他 r
# 存摺 v
# 亦 d
# 一併 d
# 拿 v
# 去 v
# 盜領 v
# 尤其 d
# 上 f
# 揭 v
# 抽屜 n
# 內 f
# 亦 d
# 應有 v
# 子 ng
# 其他 r
# 之 u
# 印章 n
# 被告 n
# 亦 d
# 無須再 i
# 代刻子 n
# 之 u
# 印章 n
# 蓋 v
# 在 p
# 該 r
# 紙 n
# 支票 n
# 背面 f
# 之 u
# 必要 d
# 益見子 nr
# 若 c
# 有 v
# 遇害 v
# 應 v
# 係 zg
# 他人 r
# 所為 c
# 並非 c
# 被告 n
# 被告 n
# 持有 v
# 子 ng
# 之 u
# 存摺 v
# 金融 n
# 卡及 ns
# 一紙 m
# 六萬元 m
# 之 u
# 支票 n
# 係 yg
# 子 ng
# 因要 c
# 購買 v
# 成都 ns
# 羽 nr
# 繡 v
# 而 c
# 投資 vn
# 被告 n
# 之 u
# 大陸 n
# 生意 v
# 經 p
# 其 r
# 同意 d
# 所 c
# 支付 v
# 並非 c
# 盜領 v
# 被告 n
# 於 nr
# 九十年 m
# 六月 t
# 十六日 m
# 及 c
# 十七日 m
# 之 u
# 兩日 m
# 行蹤 v
# 被告 n
# 應 v
# 不 d
# 可能 v
# 至 p
# 尚智 nr
# 運動 vn
# 世界 n
# 等 u
# 處 n
# 購物 n
# 亦 d
# 未至 d
# 中國 ns
# 信託 n
# 商銀 n
# 忠孝 a
# 分行 v
# 以 p
# 子 ng
# 信用卡 n
# 預借 v
# 現金 n
# 查 v
# 九十年 m
# 六月 t
# 十六日 m
# 係 zg
# 星期六 t
# 之 u
# 例假日 i
# 小孩 n
# 皆 d
# 在家 r
# 惟其 c
# 前妻 n
# 於 e
# 該 r
# 日須 d
# 在 p
# 百貨公司 n
# 值班 v
# 故 n
# 被告 n
# 即 v
# 全日 m
# 待 v
# 在 p
# 家中 s
# 陪伴 n
# 其 r
# 小孩 n
# 並 c
# 準備 v
# 三餐 m
# 給 p
# 小孩 n
# 吃 v
# 且 zg
# 被告 n
# 因 p
# 即將 d
# 出國 v
# 需 v
# 使用 v
# 拉桿 n
# 式 k
# 之 u
# 行李箱 n
# 故於 c
# 晚餐 n
# 及 c
# 看完 v
# 晚間 t
# 七時 t
# 之 u
# 新聞報導 n
# 後 f
# 即 v
# 出門 v
# 至愛 v
# 買 v
# 之 u
# 賣場 n
# 並 c
# 以 p
# 現金 n
# 購買 v
# 上 f
# 揭 v
# 行李箱 n
# 九十年 m
# 六月 t
# 十七日 m
# 上午 t
# 被告 n
# 向 p
# 丙 n
# 借 v
# 車載 n
# 其二 r
# 名 q
# 小孩 n
# 至 p
# 木柵 n
# 理髮 v
# 嗣 ng
# 因 p
# 丙 n
# 要 v
# 用車 n
# 即 v
# 電 n
# 請 v
# 被告 n
# 將車 n
# 開回 v
# 並 c
# 再至 d
# 大潤發 nz
# 賣場 n
# 購買 v
# 物品 n
# 並 c
# 再 d
# 購買 v
# 午餐 n
# 之 u
# 食物 n
# 且至 c
# 下午 t
# 一時 d
# 許始 nr
# 返回 v
# 住處 n
# 食用 n
# 且 c
# 因 p
# 該 r
# 日其 d
# 前妻 n
# 並未 d
# 值班 v
# 故於 c
# 下午 t
# 四時 t
# 許 m
# 出門 v
# 至 p
# 新生北路 nt
# 之 u
# 玩具 n
# 反斗 vn
# 城 n
# 為 p
# 其 r
# 小孩 n
# 選購 v
# 立體 n
# 電動玩具 n
# 惟 d
# 因 p
# 價值 n
# 太貴 nr
# 而 c
# 未 d
# 購買 v
# 嗣 ng
# 再至 d
# 中和市 ns
# 路 n
# 在 p
# 一家 m
# 小 a
# 火鍋店 n
# 旁之 i
# 傳 v
# 十 m
# 手機店 n
# 購買 v
# 手機 n
# 且 c
# 在 p
# 上 f
# 揭 v
# 期間 f
# 被告 n
# 亦 d
# 在 p
# 下午 t
# 五時 t
# 三十 m
# 三分 m
# 與 p
# 卯 t
# 有 v
# 通話 n
# 十分鐘 m
# 之 u
# 久 a
# 其後 c
# 再 d
# 返回 v
# 住處 n
# 巳 mg
# 丁 nr
# 於 nr
# 警訊 n
# 及 c
# 本院 n
# 之 u
# 指認 v
# 皆 d
# 不足 a
# 證明 n
# 被告 n
# 有 v
# 於 nr
# 九十年 m
# 六月 t
# 十六日 m
# 下午 t
# 五時 t
# 二十二 m
# 分 v
# 至 p
# 臺北市 ns
# 街 n
# 段 q
# 一四 m
# 之一 r
# 號 q
# 之 u
# 尚智 nr
# 運動 vn
# 世界 n
# 刷卡 n
# 購物 n
# 且 zg
# 被告 n
# 亦 d
# 未 d
# 於 nr
# 九十年 m
# 六月 t
# 十七日 m
# 下午 t
# 三 m
# 時 ng
# 十五分 m
# 至 p
# 臺北市 ns
# 路 n
# 長安 ns
# 東路 ns
# 口 q
# 之 f
# 中興 ns
# 百貨 n
# 刷卡 n
# 購物 n
# 尚智 nr
# 運動 vn
# 世界 n
# 之 u
# 店長 n
# 巳 mg
# 及 c
# 店員 n
# 丁 nr
# 在 p
# 本院 n
# 皆 d
# 證稱 v
# 警方 n
# 於 nr
# 九十年 m
# 六月 t
# 二十日 m
# 至 p
# 該店 r
# 並 c
# 拿 v
# 被告 n
# 之 u
# 口 q
# 卡 n
# 要 v
# 渠 n
# 等 u
# 指認 v
# 時 zg
# 皆 d
# 稱 v
# 不 d
# 認識 v
# 嗣 ng
# 警方 n
# 拿出 v
# 子 ng
# 信用卡 n
# 簽 zg
# 帳單 n
# 渠 n
# 等 u
# 依該 v
# 簽 v
# 帳單 n
# 自 p
# 電腦 n
# 中 f
# 調出 v
# 貨品 n
# 之 u
# 名稱 n
# 及 c
# 型號 n
# 始 d
# 回憶 v
# 其時 r
# 顧客 nr
# 之 u
# 情形 n
# 且 c
# 鈞院 n
# 亦 d
# 請 v
# 渠 n
# 等 u
# 辨認 v
# 被告 n
# 當庭 n
# 證述 n
# 之 u
# 聲音 n
# 是否 v
# 為 zg
# 當日 t
# 刷卡 n
# 購物 n
# 之人 r
# 的 uj
# 聲音 n
# 而 c
# 渠 n
# 等 u
# 皆 d
# 證稱 v
# 因 c
# 時間 n
# 過久 t
# 而 c
# 無法 n
# 辨認 v
# 惟 d
# 渠 n
# 等 u
# 亦 d
# 證稱 v
# 當日 t
# 刷卡 n
# 購物 n
# 之人 r
# 有 v
# 稱 v
# 要 v
# 買 v
# 淑女 n
# 鞋 n
# 送 v
# 人 n
# 並 c
# 尺寸 n
# 挑選 v
# 很久 m
# 翌日 t
# 回來 v
# 表示 v
# 要 v
# 換鞋 nz
# 口氣 n
# 很 zg
# 不好 d
# 故渠 n
# 等 u
# 對 p
# 當日 t
# 刷卡 n
# 購物者 n
# 之 u
# 聲音 n
# 應 v
# 很 d
# 有 v
# 印象 n
# 而 c
# 渠 n
# 等 u
# 確稱 v
# 時間 n
# 過久 t
# 而 c
# 無法 n
# 辨認 v
# 顯 v
# 不可思議 i
# 故渠 n
# 等 u
# 應有 v
# 誤認 v
# 之 u
# 可能 v
# 尤其 d
# 巳 mg
# 在 p
# 鈞院 n
# 現場 n
# 指認 v
# 時 zg
# 被告 n
# 是否 v
# 於 e
# 該 r
# 日 m
# 至 p
# 其 r
# 店 n
# 中 f
# 消費 vn
# 亦 d
# 已 d
# 無法 n
# 辨認 v
# 本件 n
# 證人 n
# 係 zg
# 依 v
# 警方 n
# 所 u
# 提 v
# 被告 n
# 之 u
# 口卡 n
# 及 c
# 有 v
# 戴 v
# 運動帽 n
# 之人 r
# 在 p
# 提款機 n
# 預借 v
# 之 u
# 模糊 a
# 影像 vn
# 並 c
# 在 p
# 警方 n
# 不斷 d
# 暗示 v
# 下 f
# 亦 d
# 應有 v
# 可能 v
# 出差錯 i
# 故 c
# 巳 mg
# 丁 nr
# 事隔 n
# 三日 t
# 後 nr
# 再 d
# 由 p
# 警方 n
# 提示 v
# 被告 n
# 口卡 n
# 及 c
# 監視器 n
# 所 c
# 錄下 v
# 有 v
# 運動帽 n
# 之 u
# 人 n
# 模糊 a
# 影像 vn
# 相片 n
# 等 u
# 暗示 v
# 應有 v
# 使 v
# 渠 n
# 等 u
# 記憶 n
# 已 d
# 有所 n
# 扭曲 v
# 故渠 n
# 等 u
# 證述 v
# 應 v
# 不可 v
# 採 v
# 被告 n
# 雖 c
# 於 nr
# 九十年 m
# 六月 t
# 十九日 m
# 出境 n
# 惟 u
# 係 yg
# 因 p
# 大陸 n
# 業務 n
# 須 d
# 由 p
# 其 r
# 親自 d
# 處理 v
# 且 zg
# 預定 v
# 於 e
# 該 r
# 日至 d
# 大陸 n
# 並非 c
# 畏罪潛逃 i
# 被告 n
# 於 nr
# 九十年 m
# 六月 t
# 十五日 m
# 在 p
# 中國 ns
# 信託 n
# 商銀 n
# 忠孝 a
# 分行 v
# 所 c
# 提示 v
# 該 r
# 支票 n
# 因 p
# 須經 n
# 臺北市 ns
# 票據交換 v
# 所 c
# 交換 v
# 三日 t
# 惟 d
# 因 p
# 被告 n
# 係 yg
# 搭 v
# 六月 t
# 十九日 m
# 上午 t
# 七時 t
# 之 u
# 飛機 n
# 出國 v
# 故於 c
# 前 f
# 一日 m
# 即 v
# 六月 t
# 十八日 m
# 晚間 t
# 十一時 d
# 許 m
# 將 zg
# 金融 n
# 卡 n
# 交予 v
# 其 r
# 妹代 n
# 為 p
# 提領 v
# 及 c
# 告知 v
# 密碼 n
# 並 c
# 委託 n
# 其 r
# 妹 n
# 提領 v
# 又 d
# 被告 n
# 於 nr
# 六月 t
# 十九日 m
# 上午 t
# 搭機 n
# 至 p
# 香港 ns
# 且 c
# 再 d
# 轉機 n
# 至 p
# 大陸 n
# 廣州 ns
# 且至 c
# 下午 t
# 在 p
# 大陸 n
# 廣州 ns
# 撥電話 v
# 與 p
# 丙 n
# 問 v
# 其 r
# 是否 v
# 已有 v
# 領錢 n
# 丙 n
# 稱 v
# 其 r
# 已 d
# 領 v
# 六萬元 m
# 並 c
# 問及 v
# 該 r
# 金融 n
# 卡 n
# 是否 v
# 於 nr
# 被告 n
# 下次 t
# 回 v
# 來時 t
# 交給 v
# 被告 n
# 惟 b
# 被告 n
# 在 p
# 出國前 l
# 因有 c
# 與 p
# 卯 t
# 聯繫 n
# 而 c
# 卯 t
# 有 v
# 提及 v
# 子 ng
# 已 d
# 失蹤 v
# 被告 n
# 始 d
# 意識 n
# 到 v
# 子 ng
# 應 v
# 已 d
# 真正 d
# 失蹤 v
# 為 zg
# 避免 v
# 與 p
# 子 ng
# 有所 n
# 牽扯 v
# 告知 v
# 丙 n
# 該 r
# 金融 n
# 卡 n
# 是 v
# 人頭 n
# 戶 q
# 請 v
# 其 r
# 將 d
# 卡 n
# 剪掉 v
# 是 v
# 被告 n
# 雖 c
# 於 nr
# 六月 t
# 十九日 m
# 出國 v
# 祇 yg
# 因 p
# 大陸 n
# 業務 n
# 須 d
# 由 p
# 被告 n
# 處理 v
# 而 c
# 預定 v
# 六月 t
# 十九日 m
# 至 p
# 大陸 n
# 尤其 d
# 被告 n
# 每次 r
# 在 p
# 大陸 n
# 皆 d
# 停留 v
# 約 d
# 半年 m
# 後 f
# 返臺 v
# 返臺 v
# 後 nr
# 皆 d
# 停留 v
# 三十日 m
# 至 p
# 四 m
# 十五日 m
# 之 u
# 久 a
# 即再 d
# 前往 t
# 大陸 n
# 足見 v
# 被告 n
# 絕非 d
# 係 zg
# 畏罪潛逃 i
# 且 zg
# 被告 n
# 指示 v
# 其 r
# 妹 n
# 將 d
# 金融 n
# 卡 n
# 丟棄 v
# 實因 n
# 避免 v
# 與 p
# 子 ng
# 失蹤 v
# 有所 n
# 牽扯 v
# 亦 d
# 屬 v
# 人之常情 l
# 被告 n
# 與 p
# 子 ng
# 交往 v
# 期間 f
# 從未 d
# 以 p
# 丙 n
# 所有 b
# 之 u
# 自小 d
# 客車 n
# 載 v
# 過子 n
# 且 zg
# 被告 n
# 更未 d
# 殺害 v
# 子 ng
# 並 c
# 以 p
# 該車 r
# 載運 n
# 其 r
# 屍體 n
# 棄 vg
# 屍 ng
# 故 n
# 該車 r
# 應無 v
# 可能 v
# 留下 v
# 子 ng
# 之 u
# 血跡 n
# 及 c
# 毛髮 nr
# 該車 r
# 平日 t
# 係 y
# 丙 mg
# 搭載 v
# 其 r
# 姊 n
# 李素 nr
# 月 m
# 及 c
# 陽明醫院 nt
# 同事 n
# 李 nr
# 菁菁 nz
# 李 nr
# 謙 vg
# 嬅 zg
# 上下班 v
# 之 u
# 交通工具 l
# 且 zg
# 被告 n
# 曾 d
# 分別 d
# 在 p
# 六月 t
# 十四日 m
# 晚上 t
# 十九時 m
# 六月 t
# 十七日 m
# 上午 t
# 及 c
# 六月 t
# 十八日 m
# 上午 t
# 向 p
# 丙 n
# 借 v
# 該車 r
# 使用 v
# 且 c
# 在 p
# 六月 t
# 十七日 m
# 上午 t
# 係 zg
# 被告 n
# 借 v
# 車載 n
# 其二 r
# 子 ng
# 至 p
# 木柵 n
# 理髮 v
# 惟 c
# 丙 n
# 告知 v
# 其 r
# 將 d
# 用車 n
# 並至 c
# 大潤發 nz
# 賣場 n
# 購物 n
# 故 n
# 被告 n
# 於 nr
# 剪 v
# 完 v
# 後 nr
# 即將 d
# 該車 r
# 交給 v
# 丙 n
# 並 c
# 由 p
# 丙 n
# 載 v
# 被告 n
# 及其 c
# 二子 n
# 李 nr
# 謙 vg
# 嬅 y
# 之 u
# 妹 n
# 李 nr
# 純如 v
# 等 u
# 人 n
# 至 p
# 該 r
# 賣場 n
# 購物 n
# 因 p
# 購物 n
# 甚 zg
# 多 m
# 亦 d
# 有 v
# 將 d
# 後置 n
# 物廂 n
# 打開 v
# 使用 v
# 其時 r
# 亦 d
# 未 d
# 發現 v
# 異狀 n
# 又 d
# 該車 r
# 在 p
# 七月 t
# 中旬 t
# 丙 n
# 曾 d
# 載 v
# 李素 nr
# 月 m
# 李 nr
# 菁菁 nz
# 及 c
# 李 nr
# 謙 vg
# 嬅 y
# 等 u
# 三 m
# 人 n
# 上班 v
# 途中 s
# 因 p
# 輪胎 n
# 被 p
# 刺破 v
# 而 c
# 無法 n
# 行駛 v
# 丙 n
# 及 c
# 其他人 rr
# 亦 d
# 皆 d
# 下車 v
# 察看 v
# 並 c
# 打開 v
# 後 f
# 車廂 n
# 看看 v
# 備用 v
# 車胎 n
# 可否 v
# 使用 v
# 亦 d
# 有 v
# 翻動 v
# 上 f
# 揭 v
# 地毯 n
# 且 zg
# 該車 r
# 送至 v
# 修車 v
# 廠 zg
# 而 c
# 修車 v
# 師傅 nr
# 亦 d
# 有 v
# 自 r
# 後置 n
# 物廂 n
# 拿取 v
# 該 r
# 備用 v
# 車胎 n
# 發見 v
# 該車 r
# 胎 q
# 之 f
# 鋼圈 n
# 與其 c
# 他 r
# 輪胎 n
# 不符 v
# 而 c
# 無法 n
# 更換 v
# 且 c
# 渠 n
# 等 u
# 亦 d
# 從未 d
# 發件 n
# 上 f
# 揭 v
# 地毯 n
# 上有 v
# 該 r
# 血跡 n
# 存在 v
# 若 c
# 上 f
# 揭 v
# 地毯 n
# 早 a
# 有 v
# 該 r
# 血跡 n
# 豈 d
# 有 v
# 不 d
# 被 p
# 渠 n
# 等 u
# 發見 v
# 之 u
# 理 n
# 且 zg
# 證人 n
# 寅 mg
# 於九 nr
# 十一年 m
# 十月 t
# 二十五日 m
# 在 p
# 本院 n
# 證稱 n
# 第二張 m
# 是 v
# 後置 n
# 物廂 n
# 打開 v
# 物品 n
# 的 uj
# 擺設 v
# 狀況 n
# 物品 n
# 取 v
# 出來 v
# 後 f
# 發現 v
# 車廂 n
# 底步 n
# 有 v
# 一層 m
# 黑色 n
# 材質 n
# 類似 v
# 地毯 n
# 的 uj
# 布墊 n
# 經過 p
# 用 p
# 多 m
# 波域 n
# 光源 n
# 去 v
# 看 v
# 發現 v
# 箭頭 n
# 標示 v
# 的 uj
# 範圍 n
# 有 v
# 可疑 v
# 的 uj
# 痕跡 n
# 經過 p
# 現場 n
# 試劑 n
# 測試 vn
# 證實 n
# 是 v
# 血跡 n
# 將 d
# 此 r
# 黑色 n
# 墊子 n
# 掀開 v
# 下面 f
# 一塊 m
# 木板 n
# 是 v
# 在 p
# 最 a
# 底下 f
# 箭頭 n
# 所借 v
# 的 uj
# 部位 n
# 有 v
# 一處 m
# 明顯 a
# 血跡 n
# 此 zg
# 位置 v
# 的 uj
# 相對 d
# 位置 v
# 與 zg
# 黑色 n
# 車廂 n
# 布墊 n
# 上 f
# 測出 v
# 血跡 n
# 的 uj
# 相對 d
# 位置 v
# 是 v
# 一致 d
# 的 uj
# 木板 n
# 上 f
# 血跡 n
# 範圍 n
# 寬度 n
# 約 d
# 達 v
# 十公分 m
# 在 p
# 駕駛座 nz
# 部份 n
# 原始 v
# 狀況 n
# 是 v
# 在 p
# 座椅 n
# 上有 v
# 放 v
# 竹製 n
# 坐墊 n
# 把 p
# 座墊 n
# 移開 v
# 經由 p
# 多 m
# 波域 n
# 光源 n
# 去 v
# 看 v
# 看到 v
# 靠近 v
# 人 n
# 坐下 v
# 去 v
# 右腰 n
# 至 p
# 右臂 n
# 部位 n
# 有 v
# 可疑 v
# 痕跡 n
# 現場 n
# 用 p
# 試劑 n
# 試 v
# 發現 v
# 是 v
# 血跡 n
# 把 p
# 座墊 n
# 移開 v
# 把 p
# 它 r
# 放置 v
# 在 p
# 地面 n
# 上 f
# 表面 n
# 看不出 v
# 有 v
# 血跡 n
# 將 zg
# 竹製 n
# 座墊 n
# 翻 v
# 到 v
# 背面 f
# 發現 v
# 背面 f
# 有 v
# 大片 n
# 血跡 n
# 這塊 r
# 血跡 n
# 的 uj
# 相對 d
# 位置 v
# 與 zg
# 駕駛座 nz
# 黑色 n
# 座墊 n
# 所 c
# 看到 v
# 的 uj
# 可疑 v
# 痕跡 n
# 位置 v
# 一致 d
# 其次 r
# 再 d
# 將 d
# 乘客 n
# 座 q
# 打開 v
# 顯示 v
# 出 v
# 乘客 n
# 座 q
# 的 uj
# 原始 v
# 狀況 n
# 以 p
# 肉眼 n
# 看 v
# 也 d
# 看不出 v
# 可疑 v
# 痕跡 n
# 後來 t
# 將 zg
# 後座 n
# 兩塊 m
# 竹製 n
# 坐墊 n
# 取 v
# 下 f
# 以 p
# 多 m
# 波域 n
# 光源 n
# 檢視 v
# 發現 v
# 座墊 n
# 背面 f
# 都 d
# 有 v
# 血跡 n
# 存在 v
# 在 p
# 後座 n
# 汽車 n
# 皮椅 n
# 相對 d
# 位置 v
# 也 d
# 都 d
# 有 v
# 血跡 n
# 存在 v
# 這兩塊 n
# 座墊 n
# 正面 ad
# 用 p
# 肉眼 n
# 看 v
# 完全 ad
# 看不出 v
# 有 v
# 血跡 n
# 存在 v
# 等 u
# 語 ng
# 顯見 v
# 駕駛座 nz
# 及 c
# 後座 n
# 上 f
# 之 u
# 竹製 n
# 座墊 n
# 正面 ad
# 完全 ad
# 看不出 v
# 有 v
# 血跡 n
# 之 u
# 存在 v
# 惟其 c
# 背面 f
# 卻 d
# 都 d
# 有 v
# 血跡 n
# 且 c
# 上 f
# 揭 v
# 血跡 n
# 相對 d
# 位置 v
# 之 u
# 黑色 n
# 座墊 n
# 亦 d
# 有 v
# 可疑 v
# 痕跡 n
# 故應 n
# 有人 r
# 將 zg
# 竹製 n
# 座墊 n
# 先 d
# 掀起 v
# 再 d
# 將 d
# 所 u
# 搜集 v
# 被害人 n
# 之 u
# 血跡 n
# 滴入 v
# 黑色 n
# 座墊 n
# 上 f
# 然後 c
# 再 d
# 將 d
# 竹製 n
# 座墊 n
# 放下 v
# 否則 c
# 豈 d
# 可能 v
# 出現 v
# 上 f
# 揭 v
# 現象 n
# 其 r
# 目的 n
# 在於 v
# 避免 v
# 駕駛 v
# 人 n
# 及 c
# 丙 n
# 等 u
# 人 n
# 發現 v
# 有 v
# 血跡 n
# 故實 d
# 令人 nrt
# 懷疑 v
# 有人 r
# 趁 v
# 警方 n
# 未 d
# 作 v
# 勘驗 vn
# 前 f
# 之 u
# 期間 f
# 故意 d
# 將 d
# 所 u
# 搜集 v
# 被害人 n
# 之 u
# 血液 n
# 之 u
# 容器 n
# 倒 v
# 在 p
# 地毯 n
# 以為 c
# 被告 n
# 涉案 v
# 最 d
# 有利 a
# 之 u
# 罪證 n
# 故上 d
# 揭 v
# 血跡 n
# 應為 v
# 事後 t
# 為 p
# 人 n
# 所 u
# 栽贓 vn
# 依 d
# 案發現場 n
# 之 u
# 血跡 n
# 亦 d
# 無從 v
# 認定 v
# 子 ng
# 業已 d
# 遇害 v
# 查 v
# 本案 r
# 殺人罪 i
# 係 yg
# 為 p
# 結果 n
# 犯 v
# 須 d
# 被害人 n
# 發生 v
# 死亡 v
# 之 u
# 結果 n
# 始 d
# 構成 v
# 該 r
# 罪 n
# 惟 b
# 目前 t
# 子 ng
# 並未 d
# 尋獲 v
# 屍體 n
# 如何 r
# 認定 v
# 子 ng
# 業已 d
# 死亡 v
# 且 zg
# 鑑定人 n
# 寅 mg
# 陳稱 nr
# 因為 c
# 現場 n
# 已 d
# 被 p
# 清洗 v
# 過 ug
# 因為 c
# 血跡 n
# 分布 v
# 地方 n
# 很多 m
# 連 nr
# 排水 v
# 孔 n
# 都 d
# 有 v
# 所以 c
# 我們 r
# 認為 v
# 是 v
# 大量 n
# 見 v
# 九 m
# 十一年 m
# 四月 m
# 九日 t
# 筆錄 n
# 第十九 m
# 頁 m
# 且 c
# 尤啟忠 nr
# 亦 d
# 證稱 v
# 無法 n
# 判斷 v
# 血跡 n
# 同一時間 d
# 噴 zg
# 還是 c
# 不同 a
# 時間 n
# 況且 c
# 一般 a
# 人因 n
# 刷牙 v
# 過於 v
# 用力 n
# 或 c
# 剔牙 v
# 刮 v
# 腿毛 n
# 不慎 a
# 致 v
# 出血 v
# 或 c
# 女性 n
# 月 m
# 事 n
# 來臨 v
# 而 c
# 溢出 v
# 經血 n
# 皆 d
# 有 v
# 可能 v
# 造成 v
# 上 f
# 揭 v
# 血跡 n
# 故 n
# 以上 f
# 揭 zg
# 血跡 n
# 之 u
# 分布 v
# 即 v
# 已 d
# 證明 n
# 子 ng
# 已 d
# 遇害 v
# 實有 v
# 疑義 n
# 被告 n
# 乙 n
# 在 p
# 偵訊 n
# 及 c
# 鈞院 n
# 第一次 m
# 開庭 n
# 亦 d
# 皆 d
# 有 v
# 提 v
# 及其 c
# 在 p
# 九十年 m
# 六月 t
# 十三日 m
# 與 p
# 子 ng
# 共進午餐 n
# 時 zg
# 子 ng
# 亦 d
# 曾 d
# 告知 v
# 有人 r
# 在 p
# 跟蹤 v
# 渠 n
# 等 u
# 假若 c
# 果真 d
# 有 v
# 跟蹤 v
# 之 u
# 人 n
# 亦 d
# 不難 d
# 知悉 v
# 被告 n
# 向其妹 nr
# 所 u
# 借 v
# 之 u
# 該車 r
# 係 zg
# 停放在 v
# 其 r
# 妹 n
# 住處 n
# 前面 f
# 之 u
# 巷道 n
# 內 n
# 且 zg
# 乘機 n
# 開啟 v
# 該車 r
# 前門 n
# 後門 n
# 及 c
# 後置 n
# 物廂 n
# 倒入 v
# 子 ng
# 血液 n
# 亦非 v
# 難事 n
# 故 n
# 本院 n
# 亦不得 v
# 僅 d
# 以 p
# 被告 n
# 向其妹 nr
# 所 u
# 借 v
# 該車 r
# 在 p
# 駕駛座 nz
# 後座 n
# 及 c
# 後置 n
# 物廂 n
# 皆 d
# 有 v
# 遺留 vn
# 子 ng
# 之 u
# 血跡 n
# 即 v
# 認定 v
# 子 ng
# 已 d
# 遇害 v
# 且 c
# 認 v
# 該車 r
# 為 p
# 運屍 n
# 之 u
# 工具 n
# 因而 c
# 推定 v
# 被告 n
# 為 zg
# 本件 n
# 之 u
# 加害人 n
# 被告 n
# 乙 n
# 只 m
# 於 nr
# 九十年 m
# 六月 t
# 十一日 m
# 到 v
# 過子 n
# 住家 n
# 一次 m
# 對子 n
# 住處 n
# 之週 f
# 遭 v
# 環境 n
# 並 c
# 不 d
# 熟悉 v
# 被告 n
# 如何 r
# 將丙 n
# 之 u
# 座車 n
# 停 v
# 在 p
# 子 ng
# 住處 n
# 附近 f
# 又 d
# 如何 r
# 搬運 v
# 屍體 n
# 至 p
# 該車 r
# 上 f
# 且 zg
# 搬運 v
# 過程 n
# 中 f
# 如何 r
# 避免 v
# 為 zg
# 鄰居 v
# 或 c
# 路人 n
# 所 c
# 發現 v
# 顯見 v
# 該車 r
# 並未 d
# 載運 n
# 子 ng
# 屍體 n
# 至於 p
# 該車 r
# 之 u
# 駕駛座 nz
# 後座 n
# 及 c
# 後置 n
# 物廂 n
# 之 u
# 血跡 n
# 應為 v
# 他人 r
# 於 nr
# 事後 t
# 所 c
# 栽贓 vn
# 亦 d
# 至 p
# 明確 ad
# 被告 n
# 於 nr
# 九十年 m
# 六月 t
# 十一日 m
# 晚 tg
# 僅 d
# 與 p
# 子 ng
# 於 nr
# 客廳 n
# 沙發 nz
# 上 f
# 發生 v
# 親密關係 n
# 並 c
# 有 v
# 短暫 a
# 時間 n
# 進入 v
# 臥房 n
# 看子 n
# 再 d
# 磅秤 n
# 上 f
# 所量 n
# 之 u
# 體重 n
# 惟 b
# 被告 n
# 並未 d
# 進入 v
# 浴室 n
# 查 v
# 被告 n
# 雖 c
# 於 nr
# 九十年 m
# 六月 t
# 十一日 m
# 晚 tg
# 應子 n
# 之 u
# 邀請 v
# 而 c
# 有 v
# 進入 v
# 子 ng
# 住處 n
# 並 c
# 與 p
# 之 u
# 在 p
# 客廳 n
# 沙發 nz
# 上 f
# 聊天 nz
# 被告 n
# 乙 n
# 開玩笑 v
# 對子 n
# 稱 zg
# 其 r
# 應有 v
# 四十五 m
# 公斤 q
# 而 c
# 以前 f
# 所稱 v
# 四十公斤 m
# 在 p
# 騙人 n
# 子 ng
# 即 v
# 走入 v
# 其 r
# 臥室 n
# 不久 a
# 被告 n
# 即 v
# 聽到 v
# 子 ng
# 叫 v
# 被告 n
# 至 p
# 其 r
# 臥房 n
# 內 f
# 看 v
# 其 r
# 體重 n
# 祇 yg
# 見 v
# 子 ng
# 在 p
# 浴室 n
# 門外 s
# 右側 f
# 處在 v
# 量體重 l
# 被告 n
# 乃以 c
# 右手 n
# 扶 v
# 在 p
# 地面 n
# 彎腰 v
# 低頭 n
# 來看 u
# 且 zg
# 看完 v
# 磅秤 n
# 上 f
# 所指 n
# 之 u
# 體重 n
# 後 f
# 即再 d
# 回到 v
# 客廳 n
# 沙發 nz
# 上 f
# 子 ng
# 走出 v
# 臥房 n
# 至 p
# 書房 n
# 拿出 v
# 相簿 n
# 至 p
# 客廳 n
# 沙發 nz
# 上 f
# 與 p
# 被告 n
# 一齊 d
# 翻閱 v
# 並 c
# 談 vn
# 及其 c
# 在 p
# 英國 ns
# 留學 v
# 之 u
# 生活 vn
# 點滴 n
# 及其 c
# 前任 n
# 男友 n
# 如何 r
# 向 p
# 其 r
# 騙錢 n
# 致 v
# 其 r
# 房屋 n
# 被 p
# 拍賣 v
# 等 u
# 經過 p
# 且 zg
# 由於 c
# 彼此 r
# 相談甚歡 l
# 即 v
# 在 p
# 沙發 nz
# 上 f
# 發生 v
# 親密關係 n
# 且 c
# 因 c
# 其時 r
# 時值 n
# 夏季 t
# 故 n
# 被告 n
# 當晚 t
# 係 yg
# 穿 v
# 涼鞋 n
# 前往 t
# 其 r
# 住處 n
# 故未 d
# 著 v
# 襪子 n
# 故 n
# 被告 n
# 走進 v
# 臥房 n
# 看子 n
# 體重 n
# 而 c
# 在 p
# 浴室 n
# 外面 f
# 門旁 s
# 地面 n
# 上 f
# 留下 v
# 被告 n
# 右手 n
# 掌紋 n
# 及 c
# 右腳 n
# 掌紋 n
# 至於 p
# 被告 n
# 雖有 c
# 在 p
# 本院 n
# 開庭 n
# 及 c
# 現場 n
# 屢 d
# 勘 vg
# 時 ng
# 有 v
# 二次 m
# 稱 v
# 其 r
# 未 d
# 進入 v
# 子 ng
# 臥室 n
# 應 v
# 係 zg
# 時經 d
# 一年 m
# 多 m
# 致 v
# 其 r
# 記憶 n
# 有所 n
# 疏漏 v
# 且 zg
# 被告 n
# 因有 c
# 看到 v
# 上 f
# 揭 v
# 指紋 n
# 跡證 n
# 鑑驗 vn
# 書 n
# 中 f
# 有 v
# 出現 v
# 被告 n
# 右指 n
# 掌紋 n
# 右腳 n
# 掌紋 n
# 相符 v
# 經 p
# 其 r
# 一再 d
# 回想 v
# 才 d
# 憶起 v
# 上 f
# 揭 v
# 經過 p
# 且 zg
# 記憶 n
# 係 zg
# 過去 t
# 零碎 a
# 片段 m
# 之 u
# 訊息 n
# 重新組合 j
# 後 nr
# 之 u
# 產物 n
# 難免 d
# 有所 n
# 錯誤 n
# 故 n
# 被告 n
# 之前 f
# 雖 zg
# 有 v
# 錯誤 n
# 之 u
# 陳述 nr
# 亦 d
# 符 v
# 一般 a
# 經驗 n
# 法則 n
# 是 v
# 浴室 n
# 門口 s
# 之 u
# 外面 f
# 地面 n
# 唯有 b
# 發現 v
# 被告 n
# 之 u
# 右指 n
# 掌紋 n
# 及 c
# 右腳 n
# 掌紋 n
# 亦 d
# 無從 v
# 證明 n
# 被告 n
# 有 v
# 進入 v
# 浴室 n
# 且 c
# 有 v
# 將子 n
# 殺害 v
# 之 u
# 事實 n
# 依 d
# 鑑定人 n
# 即 v
# 臺北市 ns
# 政府 n
# 警察局 n
# 刑事 b
# 鑑驗 vn
# 中心 n
# 主任 b
# 戌 t
# 於九 nr
# 十二年 m
# 二月 m
# 十二日 m
# 在 p
# 鈞院 n
# 陳述 nr
# 之 u
# 內容 n
# 亦 d
# 即 v
# 子 ng
# 住處 n
# 浴室 n
# 之 u
# 血跡 n
# 雖 zg
# 分佈 v
# 很 d
# 廣 a
# 惟 b
# 遺留 vn
# 皆 d
# 僅 d
# 係 yg
# 一點點 m
# 且 zg
# 無法 n
# 判斷 v
# 同一時間 d
# 所 c
# 遺留 vn
# 且 c
# 依上 d
# 揭 v
# 血跡 n
# 及其 c
# 數量 n
# 亦 d
# 無法 n
# 推算 v
# 子 ng
# 業已 d
# 死亡 v
# 且 c
# 既 c
# 無法 n
# 認定 v
# 子 ng
# 確 d
# 已 d
# 死亡 v
# 即 v
# 與 p
# 殺人罪 i
# 須 d
# 被害人 n
# 發生 v
# 死亡 v
# 之 u
# 結果 n
# 之 u
# 構成 v
# 要件 n
# 不符 v
# 且縱認子 l
# 業已 d
# 死亡 v
# 亦 d
# 無從 v
# 認定 v
# 其 r
# 係 y
# 如何 r
# 死亡 v
# 且 c
# 與 p
# 被告 n
# 間 f
# 有何 r
# 關連 v
# 二 m
# 經查 vn
# 被告 n
# 乙 n
# 強盜 n
# 殺人 n
# 動機 n
# 部分 n
# 有 v
# 下列 v
# 事證 n
# 足佐 v
# 被告 n
# 乙 n
# 財務 n
# 困難 an
# 需款 n
# 恐急 a
# 被告 n
# 乙 n
# 於 nr
# 八十年 m
# 間 f
# 曾 d
# 有 v
# 多次 m
# 退票 v
# 紀錄 n
# 而於 c
# 同年 t
# 十一月 m
# 八 m
# 日經 d
# 列為 v
# 拒絕往來 l
# 戶 q
# 此 r
# 有 v
# 臺北市 ns
# 票據交換 v
# 所 u
# 九 m
# 十二年 m
# 一月 m
# 三十日 m
# 九二 m
# 臺 yg
# 票 n
# 總 b
# 字 n
# 第 m
# 五七 m
# 號 m
# 函 n
# 附 f
# 退票 v
# 明細表 n
# 一件 m
# 在 p
# 卷 m
# 可 v
# 參 v
# 參 zg
# 本院 n
# 卷 m
# 被告 n
# 乙 n
# 於 nr
# 八十三 m
# 年間 t
# 曾向庚 nr
# 借款 n
# 十萬元 m
# 未 d
# 還 d
# 後 nr
# 即未 d
# 與 p
# 庚 nr
# 人 n
# 聯絡 n
# 此為 c
# 被告 n
# 乙 n
# 所是 c
# 認 v
# 且 c
# 據 p
# 證人 n
# 庚 nr
# 於 nr
# 本院 n
# 調查 vn
# 時 ng
# 結證 v
# 在 p
# 卷 m
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十二年 m
# 四月 m
# 九日 t
# 訊問 n
# 筆錄 n
# 被告 n
# 乙 n
# 於 nr
# 八十八年 m
# 間與亥 nz
# 離婚 v
# 其 r
# 赴 v
# 大陸 n
# 地區 n
# 經營 vn
# 皮革 n
# 生意 v
# 期間 f
# 陸續 d
# 向 p
# 胞妹 n
# 即 v
# 被告 n
# 丙 n
# 借款 n
# 四百餘萬 m
# 元 m
# 亦 d
# 陸續 d
# 向亥 nz
# 借款 n
# 約 d
# 十一萬 m
# 二千元 m
# 因其 c
# 前有 v
# 拒絕往來 l
# 紀錄 n
# 個人信用 n
# 欠佳 v
# 於 nr
# 八十九 m
# 間 f
# 尚以 c
# 亥 t
# 名義 n
# 向 p
# 中國 ns
# 信託 n
# 銀行貸款 n
# 十五萬元 m
# 所 c
# 借得 v
# 款項 n
# 悉數 d
# 攜往 v
# 大陸 n
# 地區 n
# 投資 vn
# 又 d
# 於 nr
# 九十年 m
# 六月 t
# 十八日 m
# 晚間 t
# 向亥 nz
# 借款 n
# 二 m
# 萬元 m
# 並 c
# 表示 v
# 翌日 t
# 即 v
# 還款 v
# 被告 n
# 乙 n
# 因 p
# 經濟 n
# 狀況不佳 n
# 無力 n
# 償還 v
# 中國 ns
# 信託 n
# 銀行 n
# 之 u
# 貸款 n
# 每月 r
# 遂 d
# 由 p
# 被告 n
# 丙 n
# 代為 v
# 向 p
# 銀行 n
# 清償 vn
# 三千 m
# 四百 m
# 九十一 m
# 元 m
# 返臺 v
# 期間 f
# 並 c
# 經常 d
# 向 p
# 被告 n
# 丙 n
# 借款 n
# 數千元 m
# 不等 a
# 或 c
# 請 v
# 被告 n
# 丙 n
# 代為 v
# 繳納 v
# 信用卡 n
# 帳款 n
# 被告 n
# 乙 n
# 向亥 nz
# 借款 n
# 後 f
# 屢次 d
# 承諾 v
# 返臺 v
# 時 ng
# 將 d
# 返還 v
# 借款 n
# 惟 d
# 均 d
# 未 d
# 履行 v
# 亥 t
# 因 p
# 獨自 d
# 扶養 v
# 二名 m
# 幼子 n
# 需用 v
# 款項 n
# 乃 v
# 於 nr
# 八十九年 m
# 三月 m
# 二十日 m
# 強烈要求 l
# 被告 n
# 乙 n
# 一次 m
# 將 d
# 上開 v
# 借款 n
# 還清 v
# 惟 b
# 被告 n
# 乙 n
# 無力 n
# 清償 vn
# 乃 v
# 於 nr
# 同日 t
# 簽發 v
# 票號 n
# 二三 m
# 八七 m
# 九 m
# 號 m
# 面額 n
# 五萬 m
# 七千元 m
# 到期日 l
# 八十九年 m
# 十月 t
# 三十一日 m
# 及 c
# 票號 n
# 二三 m
# 八七 m
# 八九 m
# 號 m
# 面額 n
# 五萬五千 m
# 元 m
# 到期日 l
# 九十年 m
# 三月 m
# 三十一日 m
# 之 u
# 本票 n
# 各 r
# 一紙 m
# 承諾 v
# 於 nr
# 本票 n
# 到期日 l
# 時 zg
# 清償 vn
# 票面 n
# 金額 n
# 另 r
# 簽發 v
# 票號 n
# 二三 m
# 八七 m
# 八七 m
# 號 m
# 面額 n
# 十五萬元 m
# 到期日 l
# 九十四年 m
# 三月 m
# 三十一日 m
# 之 u
# 本票 n
# 一紙 m
# 擔保 v
# 於 nr
# 到期日 l
# 前 f
# 將 d
# 還清 v
# 上述 b
# 以亥 nz
# 名義 n
# 向 p
# 中國 ns
# 信託 n
# 銀行 n
# 之 u
# 貸款 n
# 被告 n
# 丙 n
# 所 c
# 申請 v
# 之 u
# 公教人員 n
# 低利 n
# 貸款 n
# 將 d
# 於九 nr
# 十一年 m
# 年底 t
# 核准 n
# 告知 v
# 被告 n
# 乙 n
# 有 v
# 計劃 n
# 以 p
# 該 r
# 低利 n
# 貸款 n
# 購屋 n
# 被告 n
# 乙 n
# 於 nr
# 九十年 m
# 五月 t
# 十五日 m
# 自 p
# 大陸 n
# 地區 n
# 返臺 v
# 後 nr
# 遂 d
# 承諾 v
# 於 nr
# 同年 t
# 六月 t
# 間會 n
# 將 d
# 先前 t
# 之 u
# 借款 n
# 返還 v
# 而 c
# 被告 n
# 乙 n
# 積欠 v
# 亥 t
# 之 u
# 欠款 n
# 於 nr
# 二紙 m
# 本票 n
# 屆期 d
# 後 f
# 仍未 d
# 清償 vn
# 亥 t
# 乃 v
# 再次 d
# 要求 v
# 被告 n
# 乙 n
# 還款 v
# 等 u
# 情 n
# 業據 n
# 被告 n
# 乙 n
# 於 nr
# 本院 n
# 調查 vn
# 審理 vn
# 時 zg
# 供稱 v
# 其 r
# 在 p
# 大陸 n
# 作 v
# 皮革 n
# 生意 v
# 丙 n
# 陸陸續續 n
# 給 p
# 伊 ns
# 超過 v
# 四百萬元 m
# 以亥 nz
# 名義 n
# 貸款 n
# 的 uj
# 十五萬元 m
# 係 y
# 丙 mg
# 在 p
# 還 d
# 伊 ns
# 目前 t
# 還 d
# 沒有 v
# 給 p
# 丙 n
# 還 d
# 貸款 n
# 的 uj
# 錢 n
# 九十年 m
# 六月 t
# 十八日 m
# 晚上 t
# 曾 d
# 向 p
# 亥 t
# 借 v
# 二 m
# 萬元 m
# 因 p
# 當時 t
# 港幣 n
# 不夠 v
# 這 r
# 二 m
# 萬元 m
# 其 r
# 帶到 v
# 香港 ns
# 換成 v
# 港幣 n
# 做 v
# 業務 n
# 上 f
# 花用 n
# 伊 ns
# 曾經 d
# 承諾 v
# 要 v
# 拿 v
# 錢 n
# 給 p
# 丙 n
# 丙 n
# 有 v
# 提到 v
# 她 r
# 是 v
# 公教人員 n
# 有 v
# 低利 n
# 貸款額度 n
# 下來 t
# 想要 v
# 用 p
# 低利 n
# 貸款 n
# 買房子 n
# 伊於 nr
# 九十年 m
# 五月 t
# 返臺 v
# 時向丙 nrfg
# 承諾 v
# 在 p
# 九十年 m
# 六月 t
# 間要 b
# 還 d
# 丙 n
# 錢 n
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 三月 m
# 六日 t
# 訊問 n
# 筆錄 n
# 本院 n
# 卷 m
# 九 m
# 十二年 m
# 一月 m
# 六日 t
# 審判 vn
# 筆錄 n
# 被告 n
# 丙 n
# 於 nr
# 警詢 vn
# 時 ng
# 並 c
# 陳稱 nr
# 乙 n
# 財務狀況 n
# 不好 d
# 常 d
# 跟 p
# 伊 ns
# 借錢 v
# 或 c
# 叫 v
# 伊 ns
# 代付 vn
# 信用卡 n
# 帳款 n
# 貸款 n
# 且 c
# 乙 n
# 平時 t
# 就 d
# 很少 m
# 拿 v
# 錢 n
# 回來 v
# 且 zg
# 這次 r
# 指 v
# 九 m
# 十一年 m
# 六月 t
# 十九日 m
# 乙 n
# 出國 v
# 後 nr
# 也 d
# 告訴 v
# 伊 j
# 要 v
# 留 v
# 一筆 m
# 錢 n
# 未 d
# 說 v
# 數目 n
# 給 p
# 伊 ns
# 當家 n
# 用 p
# 又 d
# 說 v
# 家裡 s
# 缺 v
# 多少錢 nr
# 跟 p
# 他 r
# 講 v
# 他 r
# 會 v
# 等 u
# 錢 n
# 匯到 v
# 國內 s
# 後 nr
# 留 v
# 一筆 m
# 錢 n
# 下來 t
# 因此 c
# 乙 n
# 才 d
# 叫 v
# 伊 ns
# 提款 v
# 後 f
# 留下 v
# 兩萬元 m
# 當 t
# 家庭 n
# 費用 n
# 等 u
# 語 ng
# 參 zg
# 九十年 m
# 七月 t
# 二十七日 m
# 警詢 vn
# 筆錄 n
# 於 nr
# 偵查 v
# 中 f
# 供稱 v
# 乙 n
# 做 v
# 皮件 n
# 生意 v
# 他 r
# 說 v
# 不好 d
# 作 v
# 錢 n
# 會 v
# 陸續 d
# 收 v
# 回來 v
# 他 r
# 以前 f
# 會 v
# 開口 n
# 向 p
# 家人 n
# 借錢 v
# 但 c
# 家人 n
# 都 d
# 不理 v
# 他 r
# 僅 d
# 有 v
# 一次 m
# 給 p
# 他 r
# 五十多萬 m
# 等 u
# 語 ng
# 參 zg
# 九十一 m
# 年度 n
# 偵字 n
# 第一 m
# 六 m
# 一一 m
# 七號 m
# 偵查 v
# 卷 m
# 第四十二 m
# 頁 m
# 筆錄 n
# 於 nr
# 本院 n
# 調查 vn
# 時 ng
# 陳 nr
# 稱 v
# 乙 n
# 於 nr
# 九十年 m
# 六月 t
# 十八日 m
# 晚上 t
# 向亥 nz
# 借 v
# 二 m
# 萬元 m
# 當時 t
# 伊 ns
# 在場 v
# 因怕 c
# 亥 t
# 不肯 v
# 借 v
# 乙 n
# 跟 p
# 伊 j
# 說 v
# 隔天 nz
# 領錢 n
# 後 nr
# 拿 v
# 錢 n
# 還亥 nz
# 他 r
# 同年 t
# 月 m
# 十九日 m
# 要 v
# 回大陸 nz
# 身上 s
# 錢 n
# 不夠 v
# 又 d
# 乙 n
# 說 v
# 他 r
# 到 v
# 香港 ns
# 要 v
# 買 v
# 東西 ns
# 進 v
# 大陸 n
# 他 r
# 錢 n
# 不夠 v
# 要 v
# 伊 ns
# 代繳 v
# 信用卡 n
# 帳款 n
# 才 d
# 有 v
# 額度 n
# 可以 c
# 刷卡 n
# 其 r
# 知道 v
# 乙 n
# 以亥 nz
# 名義 n
# 向 p
# 中國 ns
# 信託 n
# 銀行貸款 n
# 十五萬 m
# 之 u
# 事 n
# 現在 t
# 還 d
# 在 p
# 繳 v
# 貸款 n
# 這筆 r
# 錢 n
# 是 v
# 伊 j
# 在 p
# 還 d
# 每月 r
# 繳 v
# 三千 m
# 四百 m
# 九十一 m
# 元 m
# 乙 n
# 借 v
# 的 uj
# 錢 n
# 由 p
# 伊 j
# 繳錢 v
# 可以 c
# 說 v
# 是 v
# 因為 c
# 乙 n
# 沒有 v
# 錢 n
# 這筆 r
# 錢 n
# 是 v
# 乙 n
# 拿 v
# 去 v
# 大陸 n
# 投資 vn
# 他 r
# 沒有 v
# 錢 n
# 繳 v
# 乙 n
# 有 v
# 說 v
# 他 r
# 在 p
# 大陸 n
# 的 uj
# 生意 v
# 上 f
# 軌道 n
# 後 f
# 會 v
# 還 d
# 伊 nr
# 這些 r
# 錢 n
# 乙 n
# 借 v
# 這筆 r
# 錢 n
# 有 v
# 開 v
# 本票 n
# 給亥 nz
# 作 v
# 擔保 v
# 乙 n
# 在 p
# 大陸 n
# 的 uj
# 生意 v
# 伊 j
# 有 v
# 問 v
# 他 r
# 說 v
# 都 d
# 沒有 v
# 領 v
# 薪水 n
# 把 p
# 薪水 n
# 又 d
# 投入 v
# 公司 n
# 九十年 m
# 回來 v
# 臺灣 ns
# 乙 n
# 有 v
# 向 p
# 伊 ns
# 借錢 v
# 但 c
# 沒有 v
# 大筆 m
# 的 uj
# 都 d
# 幾千元 m
# 而已 y
# 因為 c
# 乙 n
# 身上 s
# 沒有 v
# 臺幣 n
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 三月 m
# 六日 t
# 訊問 n
# 筆錄 n
# 證人 n
# 亥 t
# 於 nr
# 本院 n
# 調查 vn
# 時 ng
# 亦 d
# 到庭 d
# 證稱 n
# 其 r
# 於 nr
# 八十八年 m
# 間 f
# 與 p
# 乙 n
# 離婚 v
# 乙 n
# 大約 d
# 是 v
# 兩年 m
# 前 f
# 剛去 t
# 大陸 n
# 乙 n
# 的 uj
# 財務狀況 n
# 不好 d
# 九十年 m
# 六月 t
# 十八日 m
# 還 d
# 向 p
# 伊 j
# 借 v
# 二 m
# 萬元 m
# 後來 t
# 這 r
# 二 m
# 萬元 m
# 他 r
# 託 y
# 我 r
# 小姑 n
# 丙 n
# 還給 v
# 伊 ns
# 乙 n
# 於 nr
# 八十九年 m
# 間 f
# 用 p
# 其 r
# 名義 n
# 在 p
# 中國 ns
# 信託 n
# 銀行貸款 n
# 十五萬 m
# 這 r
# 是 v
# 八十九年 m
# 五月份 nz
# 之前 f
# 的 uj
# 事 n
# 幫 v
# 他 r
# 貸款 n
# 是 v
# 因為 c
# 他 r
# 說 v
# 要 v
# 去 v
# 大陸 n
# 投資 vn
# 其 r
# 覺得 v
# 乙 n
# 蠻 d
# 可憐 v
# 的 uj
# 就 d
# 想 v
# 幫 v
# 他 r
# 一次 m
# 貸款 n
# 的 uj
# 錢 n
# 係 zg
# 於 nr
# 八十九年 m
# 間 f
# 交給 v
# 乙 n
# 乙 n
# 並 c
# 陸陸續續 n
# 向 p
# 伊 ns
# 借錢 v
# 每次 r
# 都 d
# 幾千元 m
# 九十年 m
# 六月 t
# 中旬 t
# 向 p
# 伊 j
# 借 v
# 二 m
# 萬元 m
# 說 v
# 要 v
# 買 v
# 機票 n
# 去 v
# 大陸 n
# 乙 n
# 於 nr
# 離婚 v
# 後 f
# 陸陸續續 n
# 向 p
# 伊 ns
# 借款 n
# 因其 c
# 需 v
# 扶養 v
# 小孩 n
# 每次 r
# 乙 n
# 都 d
# 說 v
# 回臺 v
# 會 v
# 還款 v
# 但 c
# 都 d
# 沒有 v
# 所以 c
# 八十九年 m
# 三月 m
# 二十日 m
# 其 r
# 強制 v
# 要求 v
# 乙 n
# 開 v
# 本票 n
# 乙 n
# 就 d
# 簽發 v
# 面額 n
# 十五萬元 m
# 五萬五千 m
# 及 c
# 五萬 m
# 七千 m
# 之 u
# 本票 n
# 各 r
# 一張 m
# 其中 r
# 面額 n
# 十五萬元 m
# 之 u
# 本票 n
# 係 zg
# 清償 vn
# 中國 ns
# 信託 n
# 銀行 n
# 之 u
# 貸款 n
# 到期日 l
# 在 p
# 九十四年 m
# 三月 m
# 三十一日 m
# 他 r
# 是 v
# 說 v
# 在 p
# 九十四年 m
# 三月 m
# 三十一日 m
# 要 v
# 還 d
# 伊 j
# 錢 n
# 另外 c
# 面額 n
# 五萬 m
# 七千元 m
# 之 u
# 本票 n
# 到期日 l
# 係 zg
# 八十九年 m
# 十月 t
# 三十一日 m
# 及 c
# 面額 n
# 五萬五千 m
# 元 m
# 之 f
# 本票 n
# 到期日 l
# 係 zg
# 九十年 m
# 三月 m
# 三十一日 m
# 此 zg
# 二筆 m
# 是 v
# 離婚 v
# 後 nr
# 乙 n
# 陸陸續續 n
# 向 p
# 伊 j
# 借 v
# 的 uj
# 款項 n
# 到期日 l
# 是 v
# 約定 v
# 在 p
# 這 r
# 日期 t
# 以前 f
# 要 v
# 分期 vn
# 還 d
# 伊 nr
# 借款 n
# 等 u
# 語 ng
# 參 zg
# 九十年 m
# 八月 t
# 三日 t
# 警詢 vn
# 筆錄 n
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 三月 m
# 六日 t
# 訊問 n
# 筆錄 n
# 復 yg
# 有 v
# 票號 n
# 二三 m
# 八七 m
# 九 m
# 號 m
# 面額 n
# 五萬 m
# 七千元 m
# 到期日 l
# 八十九年 m
# 十月 t
# 三十一日 m
# 之 u
# 本票 n
# 票號 n
# 二三 m
# 八七 m
# 八九 m
# 號 m
# 面額 n
# 五萬五千 m
# 元 m
# 到期日 l
# 九十年 m
# 三月 m
# 三十一日 m
# 之 u
# 本票 n
# 及 c
# 票號 n
# 二三 m
# 八七 m
# 八七 m
# 號 m
# 面額 n
# 十五萬元 m
# 到期日 l
# 九十四年 m
# 三月 m
# 三十一日 m
# 之 u
# 本票 n
# 影本 n
# 各 r
# 一紙 m
# 在 p
# 卷足憑 i
# 參以 v
# 被告 n
# 丙 n
# 與 zg
# 被告 n
# 乙 n
# 係 zg
# 同胞 n
# 兄妹 n
# 誼 ng
# 屬 v
# 至親 n
# 又 d
# 證人 n
# 亥 t
# 與 zg
# 被告 n
# 乙 n
# 雖 c
# 已 d
# 離婚 v
# 然 r
# 並 c
# 無怨 v
# 隙 ng
# 被告 n
# 於 nr
# 本院 n
# 審理 vn
# 時 ng
# 亦 d
# 稱 v
# 證人 n
# 亥 t
# 非常 d
# 耿直 nr
# 斤斤計較 i
# 但 c
# 不會 v
# 占 v
# 人 n
# 便宜 a
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十二年 m
# 一月 m
# 六日 t
# 審判 vn
# 筆錄 n
# 且 zg
# 被告 n
# 丙 n
# 與 zg
# 證人 n
# 亥 t
# 所 u
# 陳 nr
# 情節 n
# 大部分 m
# 與 zg
# 被告 n
# 乙 n
# 所 u
# 陳者 n
# 相符 v
# 其 r
# 等 u
# 所言 c
# 上情 n
# 應堪 v
# 採信 v
# 是 v
# 由 p
# 被告 n
# 丙 n
# 之 u
# 陳述 nr
# 及 c
# 證人 n
# 亥 t
# 之 u
# 證詞 n
# 足 a
# 徵 g
# 被告 n
# 丙 n
# 陸續 d
# 交予 v
# 被告 n
# 乙 n
# 之 u
# 四百餘萬 m
# 元 m
# 顯 v
# 係 zg
# 借款 n
# 性質 n
# 並非 c
# 被告 n
# 丙 n
# 對於 i
# 被告 n
# 乙 n
# 大陸 n
# 事業 n
# 之 u
# 投資 vn
# 款 m
# 且 zg
# 被告 n
# 乙 n
# 因 p
# 經濟 n
# 困窘 a
# 除 p
# 上 f
# 開 v
# 四百餘 m
# 元 m
# 萬元 m
# 借款 n
# 外 f
# 尚 d
# 經常 d
# 向 p
# 被告 n
# 丙 n
# 借貸 n
# 小額 n
# 款項 n
# 亦 d
# 陸續 d
# 向 p
# 證人 n
# 亥 t
# 借款 n
# 被告 n
# 乙 n
# 於 nr
# 九十年 m
# 五月 t
# 十五日 m
# 返臺 v
# 後 f
# 已 d
# 承諾 v
# 被告 n
# 丙 n
# 會 v
# 在 p
# 九十年 m
# 六月 t
# 間 f
# 將 d
# 借款 n
# 返還 v
# 其 r
# 簽發 v
# 予 vg
# 亥 t
# 之 u
# 本票 n
# 其中 r
# 二紙 m
# 面額 n
# 共 d
# 十一萬 m
# 二千元 m
# 者 k
# 又 d
# 分別 d
# 於 nr
# 八十九年 m
# 十月 t
# 三十一日 m
# 及 c
# 九十年 m
# 三月 m
# 三十一日 m
# 已 d
# 屆期 d
# 未 d
# 清償 vn
# 其 r
# 顯然 ad
# 對於 i
# 被告 n
# 丙 n
# 及 c
# 證人 n
# 亥 t
# 負擔 v
# 極大 a
# 的 uj
# 還款 v
# 壓力 n
# 從而 c
# 被告 n
# 辯稱 v
# 其 r
# 在 p
# 大陸 n
# 的 uj
# 事業 n
# 是 v
# 與 p
# 妹妹 n
# 丙 n
# 一起 m
# 做 v
# 的 uj
# 丙 n
# 陸陸續續 n
# 給 p
# 伊 ns
# 四百餘萬 m
# 元 m
# 名義 n
# 上 f
# 她 r
# 沒有 v
# 股份 n
# 其 r
# 向 p
# 亥 t
# 借 v
# 的 uj
# 錢 n
# 有 v
# 陸續 d
# 在 p
# 還 d
# 云云 nr
# 不足 a
# 採信 v
# 而 c
# 被告 n
# 乙 n
# 因 p
# 不願 v
# 對 p
# 被告 n
# 丙 n
# 及 c
# 證人 n
# 亥 t
# 食言 n
# 遂 d
# 急需 n
# 籌款 n
# 還 d
# 錢 n
# 被告 n
# 乙 n
# 乃 v
# 於 nr
# 九十年 m
# 六月 t
# 上旬 t
# 邀約 v
# 其 r
# 於 nr
# 二 m
# 春 tg
# 聯誼 nz
# 認識 v
# 之 u
# 女子 n
# 天 q
# 投資 vn
# 一百萬元 m
# 在 p
# 其 r
# 大陸 n
# 之 u
# 皮革 n
# 生意 v
# 惟經 b
# 天 n
# 拒絕 v
# 等 u
# 情 n
# 亦 d
# 經 p
# 證人 n
# 天 q
# 於 nr
# 本院 n
# 調查 vn
# 時 ng
# 結證 v
# 甚 dg
# 詳 ag
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十二年 m
# 二月 m
# 二十六日 m
# 訊問 n
# 筆錄 n
# 被告 n
# 乙 n
# 與 zg
# 被害人 n
# 子 ng
# 結識 n
# 過程 n
# 被告 n
# 乙 n
# 於 nr
# 八十八年 m
# 年底 t
# 透過 v
# 卯 t
# 介紹 v
# 而 c
# 結識 n
# 被害人 n
# 子 ng
# 女 b
# 五十年 m
# 六月 t
# 二十日 m
# 生 vn
# 身分證 n
# 統一 vn
# 編號 n
# 000000000 m
# 號 m
# 初時 t
# 並未 d
# 深入 v
# 交往 v
# 其自 r
# 九十年 m
# 五月 t
# 十五日 m
# 從 zg
# 大陸 n
# 地區 n
# 返臺 v
# 後 f
# 至 p
# 同年 t
# 六月 t
# 上旬 t
# 開始 v
# 與 p
# 子 ng
# 展開 v
# 密切聯繫 l
# 等 u
# 情 n
# 業據 n
# 被告 n
# 乙 n
# 於 nr
# 本院 n
# 調查 vn
# 時 zg
# 供稱 v
# 其 r
# 與 p
# 子 ng
# 在 p
# 八十八年 m
# 秋末冬 t
# 初經卯 l
# 介紹 v
# 認識 v
# 九十年 m
# 五月 t
# 中旬 t
# 伊從 nr
# 大陸 n
# 回來 v
# 才 d
# 與 p
# 子 ng
# 談及 v
# 感情 n
# 的 uj
# 事 n
# 自 p
# 同年 t
# 六月 t
# 初 f
# 開始 v
# 直到 v
# 六月 t
# 十九日 m
# 回大陸 nz
# 一直 d
# 有 v
# 密集 n
# 的 uj
# 約會 n
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 一月 m
# 十一日 m
# 訊問 n
# 筆錄 n
# 證人 n
# 卯 t
# 於 nr
# 警詢 vn
# 及 c
# 本院 n
# 調查 vn
# 時 ng
# 亦 d
# 證稱 v
# 其 r
# 於 nr
# 八十八年 m
# 年底 t
# 介紹 v
# 乙 n
# 與 p
# 子 ng
# 認識 v
# 子 ng
# 於 nr
# 九十年 m
# 六月 t
# 十三日 m
# 與 p
# 伊 ns
# 一起 m
# 吃晚飯 l
# 時說 n
# 乙 n
# 正在 t
# 追求 v
# 她 r
# 她 r
# 說 v
# 乙 n
# 九十年 m
# 五月 t
# 那次 r
# 回來 v
# 打電話 l
# 比較 d
# 勤 a
# 想 v
# 追 v
# 她 r
# 等 u
# 語 ng
# 參 zg
# 九十年 m
# 七月 t
# 二十四日 m
# 警詢 vn
# 筆錄 n
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 五月 t
# 二十七日 m
# 訊問 n
# 筆錄 n
# 而 c
# 子 n
# 於 nr
# 九十年 m
# 五月 t
# 間 f
# 已有 v
# 交往 v
# 約 d
# 二年 m
# 之 u
# 男友 n
# 甲 n
# 乙節 n
# 復 yg
# 經 p
# 證人 n
# 即 v
# 被害人 n
# 之 u
# 友人 n
# 卯 t
# 午 t
# 甲 n
# 分別 d
# 於 nr
# 警訊 n
# 偵查 v
# 及 c
# 本院 n
# 調查 vn
# 時 ng
# 證述 v
# 在 p
# 卷 m
# 被告 n
# 乙 n
# 對於 i
# 子 ng
# 處理 v
# 與 p
# 甲 n
# 間 f
# 關係 n
# 之 u
# 態度 n
# 曾 d
# 有 v
# 質疑 v
# 之 u
# 事實 n
# 亦 d
# 經 p
# 被告 n
# 乙 n
# 於 nr
# 本院 n
# 調查 vn
# 時 zg
# 供稱 v
# 九十年 m
# 六月 t
# 十二日 m
# 下午 t
# 其 r
# 與 p
# 子 ng
# 為了 p
# 感情 n
# 的 uj
# 事 n
# 有點 n
# 僵持 v
# 九十六 m
# 月 m
# 十三日 m
# 中午 t
# 其 r
# 與 p
# 子 ng
# 午餐 n
# 時 zg
# 談到 v
# 感情 n
# 的 uj
# 問題 n
# 伊曾 nr
# 以 p
# 甲 n
# 之 u
# 問題 n
# 質問 n
# 子 ng
# 之 u
# 態度 n
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 一月 m
# 十一日 m
# 訊問 n
# 筆錄 n
# 證人 n
# 卯 t
# 於 nr
# 警詢 vn
# 時 ng
# 且 c
# 證稱 n
# 乙 n
# 於 nr
# 九十年 m
# 七月 t
# 十五日 m
# 下午 t
# 八時 t
# 許 m
# 打電話 l
# 向 p
# 伊 ns
# 詢問 v
# 子 ng
# 找到 v
# 沒有 v
# 伊 ns
# 當時 t
# 有 v
# 問 v
# 乙 n
# 為 zg
# 何不 d
# 至 p
# 大安 nz
# 分局 n
# 說明 v
# 因為 c
# 乙 n
# 接獲 v
# 分局 n
# 電話 n
# 後 nr
# 有 v
# 問 v
# 我 r
# 發生 v
# 何事 r
# 並 c
# 有 v
# 答應 v
# 我 r
# 要 v
# 至 p
# 分局 n
# 說明 v
# 但 c
# 他 r
# 沒有 v
# 前往 t
# 乙 n
# 說 v
# 因為 c
# 他 r
# 當時 t
# 心情 n
# 很亂 a
# 他 r
# 真 d
# 心想 n
# 追求 v
# 子 ng
# 他 r
# 覺得 v
# 子 ng
# 好像 v
# 在 p
# 玩弄 v
# 他 r
# 等 u
# 語 ng
# 參 zg
# 九十年 m
# 七月 t
# 二十四日 m
# 警詢 vn
# 筆錄 n
# 於 nr
# 本院 n
# 調查 vn
# 時 ng
# 結證 v
# 稱 v
# 子 ng
# 沒有 v
# 說 v
# 乙 n
# 是 v
# 她 r
# 的 uj
# 男朋友 n
# 因為 c
# 那時 r
# 甲 n
# 才 d
# 是 v
# 她 r
# 的 uj
# 男友 n
# 乙 n
# 只是 c
# 要 v
# 追求 v
# 她 r
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 五月 t
# 二十七日 m
# 訊問 n
# 筆錄 n
# 證人 n
# 午 t
# 於 nr
# 警詢 vn
# 及 c
# 本院 n
# 調查 vn
# 時 ng
# 亦 d
# 證稱 v
# 伊 ns
# 知道 v
# 子 ng
# 現 tg
# 較 d
# 要 v
# 好 a
# 的 uj
# 男友 n
# 是 v
# 甲 n
# 其 r
# 於 nr
# 九十年 m
# 六月 t
# 二日 t
# 與 p
# 子 ng
# 一起 m
# 參加 v
# 登山 ns
# 聯誼 nz
# 子 ng
# 當天 t
# 晚上 t
# 打電話 l
# 說 v
# 有 v
# 一位 m
# 剛 d
# 從 p
# 大陸 n
# 回來 v
# 的 uj
# 乙 n
# 很 zg
# 熱烈 a
# 在 p
# 追求 v
# 她 r
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 五月 t
# 二十七日 m
# 訊問 n
# 筆錄 n
# 足見 v
# 當時 t
# 被告 n
# 乙 n
# 與 zg
# 被害人 n
# 子 ng
# 開始 v
# 有 v
# 密切聯繫 l
# 之 u
# 期間 f
# 僅 zg
# 將近 t
# 二週 m
# 二人 nrt
# 係 zg
# 正在 t
# 嘗試 vn
# 交往 v
# 之 u
# 朋友 n
# 並非 c
# 已 d
# 交往 v
# 之 u
# 男女朋友 n
# 可明 v
# 至 p
# 被告 n
# 乙 n
# 雖 zg
# 辯稱 v
# 子 ng
# 說 v
# 已 d
# 與 p
# 前男友 n
# 分手 v
# 其 r
# 二人 nrt
# 一直 d
# 在 p
# 交往 v
# 並 c
# 有 v
# 親密關係 n
# 云云 nr
# 然 c
# 被害人 n
# 子 ng
# 之 u
# 男友 n
# 係 yg
# 甲 v
# 業據 n
# 與 p
# 被害人 n
# 之 u
# 摯友 n
# 卯 t
# 午 t
# 證述 v
# 如前 t
# 並經 d
# 證人 n
# 甲 n
# 結證 v
# 屬實 v
# 而 c
# 被告 n
# 乙 n
# 所辯者 n
# 則 d
# 無 v
# 實據 n
# 尚難 d
# 遽 a
# 信 n
# 被害人 n
# 子 ng
# 經濟 n
# 狀況 n
# 優渥 a
# 素有 v
# 出國 v
# 旅遊 vn
# 之 u
# 習慣 n
# 然 c
# 對於 i
# 男性 n
# 友人 n
# 提及 v
# 金錢 n
# 往來 t
# 之事 r
# 極 d
# 為 p
# 排斥 v
# 對 p
# 與 p
# 他人 r
# 金錢 n
# 往來 t
# 亦 d
# 十分 m
# 計較 v
# 謹慎 a
# 證人 n
# 即 v
# 元 m
# 大 a
# 京華 nz
# 證券 n
# 股份 n
# 有限公司 n
# 下稱 v
# 元 m
# 大 a
# 京華 nz
# 證券公司 n
# 業務經理 n
# 申 v
# 於 nr
# 本院 n
# 調查 vn
# 時 zg
# 到庭 d
# 結證 v
# 稱 v
# 子 ng
# 自 p
# 八十四 m
# 五年 t
# 迄今 d
# 為 p
# 元 m
# 大 a
# 京華 nz
# 證券公司 n
# 客戶 n
# 其 r
# 係 y
# 子 ng
# 之 u
# 營業員 n
# 子 ng
# 的 uj
# 投資 vn
# 有 v
# 證券 n
# 債券 n
# 基金 n
# 關於 p
# 股票 n
# 市值 n
# 大約 d
# 八百多 m
# 萬元 m
# 美元 q
# 債券 n
# 大約 d
# 有 v
# 四十七 m
# 萬美元 m
# 並有 c
# 跟 p
# 保誠 a
# 投信 vn
# 作 n
# 債券 n
# 基金 n
# 金額 n
# 約 d
# 四百多萬 m
# 臺幣 n
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 九 m
# 十二年 m
# 二月 m
# 二十六日 m
# 訊問 n
# 筆錄 n
# 並 c
# 有 v
# 中國 ns
# 信託 n
# 商業銀行 nt
# 九 m
# 十一年 m
# 六月 t
# 十日 t
# 中信 nz
# 銀九一 nr
# 一二 m
# 二四 m
# 五 m
# 號 m
# 函覆 v
# 子 ng
# 於 nr
# 該行 r
# 所有 b
# 帳戶 n
# 之 u
# 往來 t
# 明細 ad
# 及 c
# 股東 n
# 持有 v
# 股份 n
# 資料 n
# 表 v
# 參 zg
# 本院 n
# 卷 m
# 財政部 nt
# 財稅 n
# 資料 n
# 中心 n
# 九 m
# 十一年 m
# 三月 m
# 二十二 m
# 日資 n
# 五字 nz
# 第九 m
# 一 m
# 四六 m
# 三五七 m
# 號 m
# 函覆 v
# 子 ng
# 個人財產 j
# 資料 n
# 明細表 n
# 參 zg
# 本院 n
# 卷 m
# 保誠 nr
# 證券 n
# 投資信託 n
# 股份 n
# 有限公司 n
# 九 m
# 十二年 m
# 三月 m
# 二十日 m
# 保 v
# 函 n
# 字 n
# 第九 m
# 二 m
# 五四 m
# 號 m
# 函 n
# 附 v
# 保誠 a
# 系列 q
# 基金 n
# 受益 v
# 憑證 n
# 對 p
# 帳單 n
# 參 zg
# 本院 n
# 卷 m
# 各 r
# 一件 m
# 元 m
# 大 a
# 京華 nz
# 證券 n
# 股份 n
# 有限公司 n
# 九 m
# 十二年 m
# 四月 m
# 三十日 m
# 函 n
# 附子 n
# 股票 n
# 往來 t
# 明細 ad
# 一冊 m
# 參 zg
# 本院 n
# 卷 m
# 證人 n
# 申 v
# 提供 v
# 之 u
# 子 ng
# 持股 v
# 明細表 n
# 匯出 v
# 匯款 n
# 申請書 nr
# 保誠 nr
# 系列 q
# 基金 n
# 受益 v
# 憑證 n
# 對 p
# 帳單 n
# 各 r
# 一紙 m
# 參 zg
# 本院 n
# 卷 m
# 在 p
# 卷 m
# 可 v
# 資 n
# 佐證 n
# 被害人 n
# 子 ng
# 素有 v
# 出國 v
# 旅遊 vn
# 之 u
# 習慣 n
# 且 zg
# 入出境 n
# 次數 n
# 甚為 d
# 頻繁 a
# 其 r
# 於 nr
# 八十九年 m
# 間 f
# 分別 d
# 於 nr
# 四月 m
# 二十三日 m
# 出境 n
# 同月 t
# 二十八日 m
# 入境 n
# 又 d
# 於 nr
# 六月 t
# 十九日 m
# 出境 n
# 七月 t
# 五日 t
# 入境 n
# 復 yg
# 於 nr
# 八月 t
# 三日 t
# 出境 n
# 同月 t
# 六日 t
# 入境 n
# 其 r
# 於 nr
# 九十 m
# 年間 t
# 亦 d
# 分別 d
# 於 nr
# 一月 m
# 二十一日 m
# 出境 n
# 同月 t
# 二十五日 m
# 入境 n
# 又 d
# 於 nr
# 二月 m
# 二十二日 m
# 出境 n
# 同月 t
# 二十五日 m
# 入境 n
# 再於 c
# 五月 t
# 十一日 m
# 出境 n
# 同月 t
# 十六日 m
# 入境 n
# 此 r
# 有 v
# 內政部 nt
# 警政署 n
# 入出境 n
# 管理局 n
# 九 m
# 十二年 m
# 五月 t
# 八日 t
# 境 ng
# 信昌字 nz
# 第 m
# 九二 m
# 四五 m
# 六六 m
# 二號 m
# 函 n
# 附子 n
# 入出境 n
# 紀錄 n
# 一件 m
# 存卷 v
# 可稽 a
# 參 zg
# 本院 n
# 卷 m
# 被害人 n
# 子 ng
# 前 f
# 於 nr
# 七十七 m
# 年間 t
# 至 p
# 八十年 m
# 間 f
# 曾 d
# 提供 v
# 其 r
# 所有 b
# 坐落 v
# 臺北市 ns
# 區 n
# 段 q
# 一小 d
# 段 q
# 一六 m
# 之一 r
# 三 m
# 地號 n
# 暨 c
# 其 r
# 上 v
# 建物 n
# 門牌號碼 n
# 臺北市 ns
# 路 n
# 段 q
# 三十五 m
# 巷 ng
# 七 m
# 弄 v
# 五十三 m
# 號 m
# 一樓 n
# 先後 t
# 向 p
# 臺灣 ns
# 中小企業 j
# 銀行 n
# 美商 n
# 花旗銀行 nt
# 及 c
# 臺北區 ns
# 中小企業 j
# 銀行 n
# 設定 v
# 抵押權 n
# 前後 f
# 貸款 n
# 共計 v
# 一千餘萬元 m
# 供 v
# 前男友 n
# 清償債務 n
# 然其 c
# 前男友 n
# 均 d
# 未 d
# 向 p
# 被害人 n
# 子 ng
# 還款 v
# 被害人 n
# 子 ng
# 因此 c
# 需 v
# 自行 r
# 負擔 v
# 高額 n
# 貸款 n
# 故 n
# 對於 i
# 男性 n
# 友人 n
# 提及 v
# 金錢 n
# 往來 t
# 之事 r
# 極 d
# 為 p
# 排斥 v
# 對 p
# 與 p
# 他人 r
# 金錢 n
# 往來 t
# 亦 d
# 十分 m
# 計較 v
# 謹慎 a
# 等 u
# 情 n
# 業據 n
# 證人 n
# 即 v
# 被害人 n
# 之 u
# 胞姊 n
# 癸 zg
# 於 nr
# 本院 n
# 調查 vn
# 時證 n
# 稱 v
# 子 ng
# 經濟 n
# 狀況 n
# 很 d
# 好 a
# 很 zg
# 獨立 v
# 因為 c
# 她 r
# 教書 n
# 的 uj
# 收入 v
# 很 zg
# 輕鬆 a
# 其 r
# 知道 v
# 她 r
# 有 v
# 存款 n
# 投資 vn
# 股票 n
# 債券 n
# 她 r
# 對 p
# 自己 r
# 財務 n
# 很 zg
# 謹慎 a
# 辛 nr
# 有 v
# 開給 v
# 子 ng
# 一張 m
# 支票 n
# 已經 d
# 到期 d
# 子 ng
# 都 d
# 沒有 v
# 去 v
# 領 n
# 很 zg
# 奇怪 v
# 其 r
# 知道 v
# 子 ng
# 對 p
# 金錢 n
# 很 zg
# 計較 v
# 不會 v
# 隨便 d
# 把 p
# 錢 n
# 借給 v
# 別人 r
# 也 d
# 不會 v
# 逾期 t
# 而 c
# 不 d
# 領錢 n
# 子 ng
# 曾經 d
# 上當 v
# 被騙 v
# 即 v
# 有 v
# 一次 m
# 幫 v
# 人家 n
# 作保 v
# 在 p
# 基隆 nz
# 路 n
# 的 uj
# 房子 n
# 被 p
# 拍賣 v
# 損失 n
# 大概 d
# 一千萬 m
# 子 ng
# 有養 v
# 一隻 m
# 狗 n
# 她 r
# 對 p
# 這 r
# 隻 y
# 狗 n
# 看 v
# 得 ud
# 很 d
# 重 m
# 她 r
# 要 v
# 出去 v
# 一定 d
# 會 v
# 把 p
# 狗 n
# 交代 n
# 好 a
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 三月 m
# 二十日 m
# 訊問 n
# 筆錄 n
# 本院 n
# 卷 m
# 九 m
# 十二年 m
# 二月 m
# 十二日 m
# 訊問 n
# 筆錄 n
# 又 d
# 證人 n
# 即 v
# 被害人 n
# 之 u
# 好友 n
# 辛 nr
# 亦 d
# 於 nr
# 本院 n
# 調查 vn
# 時 ng
# 結證 v
# 稱 v
# 其 r
# 與 p
# 子 ng
# 認識 v
# 三 m
# 四年 m
# 且 zg
# 認識 v
# 子 ng
# 大部分 m
# 的 uj
# 朋友 n
# 知道 v
# 子 ng
# 經濟 n
# 狀況 n
# 不錯 a
# 應有 v
# 上 f
# 千萬 m
# 的 uj
# 財產 n
# 其 r
# 與 p
# 子 ng
# 原為 d
# 男女朋友 n
# 後來 t
# 做好 v
# 朋友 n
# 從 zg
# 認識 v
# 子 ng
# 大約 d
# 半年 m
# 後 f
# 開始 v
# 幾乎 d
# 每天 r
# 都 d
# 會 v
# 幫子 n
# 溜 v
# 狗 n
# 其 r
# 於 nr
# 案發前 n
# 兩 m
# 三年 m
# 前 f
# 曾向子 nr
# 借過 p
# 十萬元 m
# 是 v
# 伊 ns
# 開支票 n
# 給 p
# 子 ng
# 子 ng
# 才 d
# 借錢 v
# 子 ng
# 曾 d
# 交 v
# 存摺 v
# 給 p
# 伊 ns
# 叫 v
# 伊 ns
# 幫忙 v
# 刷 zg
# 存摺 v
# 因為 c
# 金融 n
# 卡 n
# 次數 n
# 提滿 v
# 登錄 v
# 後 nr
# 她 r
# 才能 v
# 繼續 v
# 提 v
# 但 c
# 次數 n
# 很少 m
# 伊 ns
# 認識 v
# 子 ng
# 這麼久 r
# 只有 c
# 一 m
# 二次 m
# 子 ng
# 從未 d
# 交 v
# 存摺 v
# 給 p
# 伊 j
# 去 v
# 提款 v
# 子 ng
# 曾 d
# 說 v
# 有 v
# 兩個 m
# 男朋友 n
# 都 d
# 做生意 v
# 失敗 v
# 子 ng
# 都 d
# 有 v
# 受 v
# 他們 r
# 的 uj
# 影響 vn
# 有 v
# 幫 v
# 他們 r
# 背債 n
# 第一個 m
# 男朋友 n
# 有 v
# 倒 v
# 了 ul
# 很多 m
# 錢 n
# 拿 v
# 她 r
# 的 uj
# 房子 n
# 去 v
# 貸款 n
# 她 r
# 就 d
# 一直 d
# 還 d
# 這些 r
# 債 n
# 約 d
# 有 v
# 一 m
# 二千萬 m
# 第二個 m
# 從事 v
# 航空 n
# 貨運 n
# 也 d
# 有 v
# 倒 v
# 人家 n
# 兩 m
# 三百萬 m
# 也 d
# 是 v
# 子 ng
# 幫忙 v
# 處理 v
# 其 r
# 與 p
# 子 ng
# 相處 d
# 期間 f
# 子 ng
# 有 v
# 跟 p
# 伊 ns
# 特別 d
# 表明 v
# 不准 v
# 借錢 v
# 因為 c
# 當時 t
# 伊 ns
# 剛好 d
# 週轉 nr
# 不 d
# 過來 t
# 差 a
# 六萬元 m
# 伊 j
# 就 d
# 直接 ad
# 開 v
# 一張 m
# 面額 n
# 六萬元 m
# 支票 n
# 跟 p
# 子 ng
# 調借 v
# 六萬元 m
# 她 r
# 才 d
# 肯借 v
# 借 v
# 的 uj
# 錢 n
# 是 v
# 子 ng
# 領款 n
# 給 p
# 伊 ns
# 子 ng
# 不曾 d
# 交 v
# 金融 n
# 卡 n
# 給 p
# 去 v
# 領錢 n
# 其 r
# 亦 d
# 不知 v
# 子 ng
# 金融 n
# 卡之 nr
# 密碼 n
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 四月 m
# 二十九日 m
# 同年 t
# 十一月 m
# 四日 t
# 九 m
# 十二年 m
# 二月 m
# 十二日 m
# 訊問 n
# 筆錄 n
# 證人 n
# 午 t
# 於 nr
# 本院 n
# 調查 vn
# 時 ng
# 亦 d
# 證稱 v
# 伊 ns
# 知道 v
# 子 ng
# 投資 vn
# 很多 m
# 海外基金 nz
# 認識 v
# 她 r
# 的 uj
# 人 n
# 都 d
# 知道 v
# 她 r
# 會 v
# 講 v
# 出來 v
# 她 r
# 收入 v
# 不錯 a
# 每 zg
# 小時 n
# 鐘點 n
# 多少 m
# 也 d
# 都 d
# 會 v
# 提 v
# 子 ng
# 曾 d
# 說 v
# 男女朋友 n
# 不要 df
# 談到 v
# 金錢 n
# 的 uj
# 問題 n
# 並 c
# 強調 v
# 男女朋友 n
# 最好 a
# 不要 df
# 有 v
# 金錢 n
# 糾紛 n
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 五月 t
# 二十七日 m
# 訊問 n
# 筆錄 n
# 再 d
# 證人 n
# 即 v
# 被害人 n
# 之 u
# 友人 n
# 許仁精 nr
# 即 v
# 丑 a
# 於 nr
# 本院 n
# 調查 vn
# 時 ng
# 結證 v
# 稱 v
# 子 ng
# 跟 p
# 伊 j
# 說 v
# 過 ug
# 只要 c
# 是 v
# 錢 n
# 的 uj
# 問題 n
# 打死 v
# 她 r
# 都 d
# 不 d
# 會談 v
# 錢 n
# 的 uj
# 問題 n
# 不要 df
# 跟 p
# 她 r
# 講 v
# 她 r
# 不會 v
# 因 p
# 錢 n
# 的 uj
# 問題 n
# 跟 p
# 人家 n
# 有 v
# 任何 r
# 瓜葛 n
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 七月 t
# 十五日 m
# 訊問 n
# 筆錄 n
# 此外 c
# 並 c
# 有 v
# 臺北市 ns
# 松山 ns
# 地政事務 n
# 所 u
# 九 m
# 十二年 m
# 四月 m
# 一日 m
# 北市 ns
# 松地 ns
# 三字 nz
# 第 m
# 九 m
# 二三 m
# 四 m
# 八一 m
# 號 m
# 函 n
# 附 f
# 土地 n
# 暨 nt
# 建築 n
# 改良 v
# 物 zg
# 登記簿 n
# 謄本 n
# 各 r
# 一冊 m
# 參 zg
# 本院 n
# 卷 m
# 抵押權 n
# 設定 v
# 契約書 n
# 一件 m
# 參 n
# 九 m
# 十二年 m
# 三月 m
# 十二日 m
# 證據 n
# 清冊 n
# 在 p
# 卷足憑 i
# 被害人 n
# 子 ng
# 業遭 n
# 被告 n
# 乙 n
# 殺害 v
# 有 v
# 下列 v
# 事證 n
# 可佐 v
# 被害人 n
# 子 ng
# 於 nr
# 九十年 m
# 六月 t
# 十四日 m
# 上午 t
# 十一時 d
# 許 m
# 與 p
# 被告 n
# 乙 n
# 通話 n
# 後 f
# 即告 v
# 失蹤 v
# 被害人 n
# 子 ng
# 於 nr
# 九十年 m
# 六月 t
# 十三日 m
# 晚間 t
# 曾 d
# 與 p
# 卯 t
# 甲 n
# 共同 d
# 晚餐 n
# 乙節 n
# 業據 n
# 證人 n
# 卯 t
# 於 nr
# 本院 n
# 調查 vn
# 時 ng
# 結證 v
# 稱 v
# 其 r
# 與 p
# 子 ng
# 於 nr
# 九十年 m
# 六月 t
# 十三日 m
# 在 p
# 臺北市 ns
# 路 n
# 南昌 ns
# 街口 s
# 蔡萬興 nr
# 吃飯 v
# 子 ng
# 說 v
# 有 v
# 叫 v
# 甲 n
# 早 a
# 中 f
# 晚照 n
# 三餐 m
# 打電話 l
# 給 p
# 她 r
# 當日 t
# 近 a
# 下午 t
# 八時 t
# 甲 n
# 亦 d
# 到 v
# 餐館 n
# 用餐 n
# 同日 t
# 晚上 t
# 十一時 d
# 許 m
# 子 ng
# 有 v
# 打電話 l
# 給 p
# 伊等語 nz
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十一年 m
# 五月 t
# 二十七日 m
# 訊問 n
# 筆錄 n
# 證人 n
# 甲 n
# 於 nr
# 警詢 vn
# 偵查 v
# 及 c
# 本院 n
# 調查 vn
# 時 ng
# 亦 d
# 證稱 v
# 其 r
# 於 nr
# 九十年 m
# 六月 t
# 十三日 m
# 晚間 t
# 與 p
# 子 ng
# 卯 t
# 在 p
# 蔡萬興 nr
# 吃飯 v
# 後 f
# 留宿 v
# 在 p
# 子 ng
# 上址 n
# 住處 n
# 迄 l
# 翌日 t
# 即 v
# 同年 t
# 月 m
# 十四日 m
# 上午 t
# 九時 t
# 三十分 m
# 許 m
# 離開 v
# 後 f
# 子 ng
# 曾 d
# 抱怨 v
# 說 v
# 伊太忙 nr
# 不理 v
# 她 r
# 要 v
# 伊 ns
# 一天 m
# 打 v
# 三次 m
# 電話 n
# 給 p
# 她 r
# 九十年 m
# 六月 t
# 十四日 m
# 中午 t
# 十二點 m
# 左右 m
# 有 v
# 打 v
# 沒有 v
# 人 n
# 接 v
# 當時 t
# 伊想子 nr
# 大概 d
# 出去 v
# 吃飯 v
# 之後 f
# 伊 j
# 不 d
# 定時 d
# 打電話 l
# 給 p
# 她 r
# 都 d
# 沒有 v
# 人 n
# 接 v
# 當天 t
# 晚上 t
# 十一點多 m
# 伊 j
# 去 v
# 換 v
# 完 v
# 機器 n
# 已經 d
# 快 a
# 晚上 t
# 十二點 m
# 了 ul
# 打給 v
# 子 ng
# 還是 c
# 沒有 v
# 人 n
# 接 v
# 子 ng
# 有 v
# 養 v
# 狗 n
# 習慣 n
# 上 f
# 不會 v
# 不 d
# 回家 n
# 伊聽 nr
# 答錄機 n
# 嘟嘟 o
# 的 uj
# 聲音 n
# 非常 d
# 多聲 m
# 表示 v
# 有 v
# 很多 m
# 通 v
# 留言 v
# 表示 v
# 中間 f
# 她 r
# 從未 d
# 回過 v
# 家 q
# 因為 c
# 她 r
# 回家 n
# 會 v
# 聽 v
# 再 d
# 把 p
# 錄音 n
# 洗掉 v
# 伊 ns
# 判斷 v
# 子 ng
# 還 d
# 沒 v
# 回家 n
# 其 r
# 就 d
# 往 p
# 回家路上 l
# 走 v
# 回到 v
# 家 q
# 睡 v
# 前 f
# 又 d
# 打電話 l
# 給 p
# 子 ng
# 還是 c
# 答錄機 n
# 接 v
# 其 r
# 覺得 v
# 有 v
# 問題 n
# 第二天 m
# 早上 t
# 起床 v
# 又 d
# 打電話 l
# 還是 c
# 一樣 r
# 情形 n
# 伊遂 nr
# 打給 v
# 子 ng
# 之 u
# 朋友 n
# 汪治華 nr
# 把 p
# 這 r
# 狀況 n
# 告訴 v
# 她 r
# 她 r
# 也 d
# 覺得 v
# 有 v
# 異樣 d
# 幫 v
# 伊 ns
# 找到 v
# 子 ng
# 大姐 n
# 癸 zg
# 後來 t
# 是 v
# 她 r
# 姐姐 n
# 打 v
# 一一 m
# 報警 n
# 好像 v
# 救護車 n
# 消防車 n
# 有 v
# 來 v
# 消防人員 n
# 從 zg
# 二樓 n
# 很 zg
# 輕易 a
# 的 uj
# 把 p
# 窗戶 n
# 推開 v
# 進入 v
# 就 d
# 把 p
# 大門 n
# 打開 v
# 子 ng
# 是 v
# 很 d
# 小心 n
# 的 uj
# 女孩子 n
# 到 v
# 附近 f
# 吃飯 v
# 也 d
# 會 v
# 上鎖 v
# 她 r
# 的 uj
# 門 n
# 是 v
# 三段 m
# 鎖 v
# 但 c
# 當 t
# 天門 ns
# 很 zg
# 輕易 a
# 就 d
# 被 p
# 打開 v
# 門 zg
# 根本 a
# 沒有 v
# 鎖 v
# 只是 c
# 帶上 v
# 其 r
# 等 u
# 跟著 v
# 消防人員 n
# 進入 v
# 看到 v
# 臥室 n
# 客廳 n
# 到處 d
# 整整齊齊 z
# 沒有 v
# 特別 d
# 異樣 d
# 伊 ns
# 常常 d
# 住子 n
# 住處 n
# 一個 m
# 禮拜 ns
# 至少 d
# 一次 m
# 感覺 n
# 到 v
# 四週 m
# 雖然 c
# 整齊 d
# 但有 c
# 被 p
# 異動 a
# 但 c
# 一下子 m
# 也 d
# 無法 n
# 判斷 v
# 哪裡 r
# 異動 a
# 管區 n
# 就 d
# 叫 v
# 伊 j
# 到 v
# 派出所 n
# 報 n
# 失蹤人口 i
# 做 v
# 筆錄 n
# 後來 t
# 又 d
# 返回 v
# 她 r
# 住處 n
# 拿子 n
# 照片 n
# 去 v
# 派出所 n
# 回去 v
# 住所 n
# 時 zg
# 兩位 m
# 姐姐 n
# 去 v
# 書房 n
# 聽 v
# 答錄機 n
# 伊 j
# 去 v
# 臥室 n
# 一樣 r
# 一樣 r
# 看 v
# 發現 v
# 很多 m
# 異常 d
# 情形 n
# 浴室 n
# 有 v
# 一個 m
# 體重計 n
# 被 p
# 移到 v
# 臥室 n
# 浴簾 n
# 不見 v
# 了 ul
# 浴缸 n
# 上 f
# 的 uj
# 洗髮精 nz
# 沐浴乳 nz
# 都 d
# 不見 v
# 還 d
# 清洗 v
# 過 ug
# 有 v
# 兩條 m
# 白色 n
# 毛巾 nr
# 還有 v
# 白色 n
# 踏腳 v
# 布都 ns
# 不見 v
# 浴室 n
# 垃圾桶 n
# 塑膠袋 n
# 都 d
# 不見 v
# 平常 a
# 子 ng
# 她 r
# 只 d
# 會 v
# 把 p
# 垃圾桶 n
# 內 f
# 的 uj
# 東西 ns
# 倒掉 v
# 袋子 n
# 會 v
# 保留 v
# 包括 v
# 公用 n
# 的 uj
# 浴室 n
# 的 uj
# 塑膠袋 n
# 也 d
# 不見 v
# 另 r
# 浴缸 n
# 阻水 n
# 塑膠 n
# 蓋 v
# 未 t
# 蓋住 v
# ...
# 就 d
# 給 p
# 警員 n
# 他 r
# 的 uj
# 行動 vn
# 電話號碼 n
# 但 c
# 之後 f
# 大安 nz
# 分局 n
# 警員 n
# 就 d
# 沒有 v
# 找 v
# 伊 ns
# 第二 m
# 次於 v
# 同年 t
# 七月 t
# 二十七日 m
# 凌晨 t
# 大安 nz
# 分局 n
# 警員 n
# 到 v
# 其 r
# 住處 n
# 搜索 v
# 並 c
# 查扣 v
# 其 r
# 所有 b
# 車牌號碼 n
# 二 m
# 七 m
# 一九三 m
# 號 m
# 自用 v
# 小客車 n
# 採證 v
# 鑑定 v
# 翌日 t
# 即 v
# 二十八日 m
# 其 r
# 打電話 l
# 告訴 v
# 乙 n
# 車子 n
# 被 p
# 扣押 v
# 之 u
# 事 n
# 其 r
# 問 v
# 乙 n
# 究竟 d
# 什麼 r
# 事情 n
# 警察 v
# 為何 r
# 會 v
# 傳 v
# 伊 j
# 去 v
# 問話 n
# 請 v
# 乙 n
# 趕快 d
# 回 v
# 臺灣 ns
# 同年 t
# 八月 t
# 一日 m
# 大安 nz
# 分局 n
# 傳喚 v
# 伊 ns
# 到場 d
# 採取 v
# 其 r
# 頭髮 n
# 口腔 n
# 細胞 n
# 並 c
# 告知 v
# 鑑定 v
# 報告 n
# 已經 d
# 出來 v
# 請 v
# 伊 ns
# 打電話 l
# 叫 v
# 乙 n
# 回臺 v
# 其 r
# 在 p
# 大安 nz
# 分局 n
# 打電話 l
# 給 p
# 乙 n
# 告知 v
# 乙 n
# 警員 n
# 說 zg
# 車子 n
# 有 v
# 鑑定 v
# 出來 v
# 子 ng
# 的 uj
# 血跡 n
# 乙 n
# 說不 l
# 可能 v
# 另 r
# 告知 v
# 乙 n
# 大安 nz
# 分局 n
# 請 v
# 他 r
# 在 p
# 八月 t
# 十五日 m
# 以前 f
# 一定 d
# 要 v
# 回臺 v
# 乙 n
# 說不 l
# 可能 v
# 這麼 r
# 短時間 n
# 需要 v
# 把 p
# 大陸 n
# 事情 n
# 處理 v
# 一下 m
# 之後 f
# 於 nr
# 同月 t
# 間 f
# 大安 nz
# 分局 n
# 警員 n
# 又 d
# 來 v
# 找 v
# 伊 ns
# 其 r
# 又 d
# 打電話 l
# 給 p
# 乙 n
# 告知 v
# 大安 nz
# 分局 n
# 有 v
# 寄送 v
# 傳票 n
# 傳喚 v
# 乙 n
# 請 v
# 乙 n
# 趕快 d
# 回臺 v
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十二年 m
# 二月 m
# 十二日 m
# 訊問 n
# 筆錄 n
# 被告 n
# 乙 n
# 於 nr
# 本院 n
# 審理 vn
# 時 zg
# 供稱 v
# 九十年 m
# 六月 t
# 十九日 m
# 伊從 nr
# 香港 ns
# 進 v
# 大陸 n
# 打電話 l
# 給 p
# 丙 n
# 丙 n
# 告訴 v
# 我 r
# 她 r
# 把 p
# 款項 n
# 提完 v
# 其 r
# 知道 v
# 大安 nz
# 分局 n
# 曾經 d
# 到 v
# 中正路 nz
# 一 m
# 五一 m
# 巷 ng
# 查訪 v
# 伊 ns
# 伊 ns
# 當時 t
# 意識 n
# 到 v
# 應 v
# 把 p
# 金融 n
# 卡 n
# 剪掉 v
# 就 d
# 叫 v
# 丙 n
# 把 p
# 卡 nr
# 剪掉 v
# 丙 n
# 交保 j
# 後 f
# 打電話 l
# 跟 p
# 伊 j
# 說 v
# 她 r
# 被 p
# 檢方 n
# 搜索 v
# 移送 v
# 檢方 n
# 要 v
# 以 p
# 強盜 n
# 殺人 n
# 起訴 v
# 她 r
# 並 c
# 哭 v
# 訴說 v
# 她 r
# 那麼 r
# 信任 n
# 伊 ns
# 責備 n
# 伊為何 nr
# 要害 v
# 她 r
# 其 r
# 當時 t
# 判斷 v
# 伊 ns
# 已經 d
# 害丙 n
# 捲入 v
# 這個 r
# 官司 n
# 另 r
# 一次 m
# 丙 n
# 在 p
# 大安 nz
# 分局 n
# 打電話 l
# 給 p
# 伊 ns
# 其 r
# 告訴 v
# 丙 n
# 會 v
# 在 p
# 八月 t
# 底 f
# 九月初 t
# 回臺 v
# 因為 c
# 當時 t
# 傳喚 v
# 單 n
# 已經 d
# 開出 v
# 第二張 m
# 同年 t
# 八月 t
# 底 f
# 九月初 t
# 其 r
# 又 d
# 打電話 l
# 給 p
# 丙 n
# 告知 v
# 沒有 v
# 辦法 n
# 按 p
# 原來 d
# 的 uj
# 時間 n
# 回臺 v
# 回臺 v
# 日期 t
# 確定 v
# 要 v
# 延後 nr
# 到 v
# 九月 t
# 十一日 m
# 才 d
# 會 v
# 回來 v
# 一直 d
# 到 v
# 子 ng
# 確實 ad
# 失蹤 v
# 以後 f
# 其 r
# 意識 n
# 到 v
# 會 v
# 帶給 v
# 丙 n
# 怎樣 r
# 的 uj
# 麻煩 an
# 就 d
# 沒有 v
# 主動 b
# 跟 p
# 家人 n
# 及 c
# 所有 b
# 的 uj
# 朋友 n
# 聯絡 n
# 丙 n
# 從 zg
# 高中畢業 nr
# 到 v
# 現在 t
# 幾乎 d
# 都 d
# 從事 v
# 兩個 m
# 工作 vn
# 丙 n
# 幫 v
# 伊 ns
# 處理 v
# 問題 n
# 結果 n
# 其 r
# 帶給 v
# 丙 n
# 這樣 r
# 的 uj
# 麻煩 an
# 其 r
# 回臺 v
# 是 v
# 要 v
# 喚回 v
# 丙 n
# 對 p
# 其 r
# 的 uj
# 信任 n
# 等 u
# 語 ng
# 參 zg
# 本院 n
# 卷 m
# 九 m
# 十二年 m
# 二月 m
# 十二日 m
# 訊問 n
# 筆錄 n
# 同年 t
# 一月 m
# 六日 t
# 審判 vn
# 筆錄 n
# 復 yg
# 有 v
# 本院 n
# 九十 m
# 年度 n
# 聲 q
# 搜字 nz
# 第五 m
# 一號 m
# 搜索 v
# 票 n
# 影本 n
# 二紙 m
# 大安 nz
# 分局 n
# 九十年 m
# 八月 t
# 一日 m
# 及 c
# 同年 t
# 八月 t
# 九日 t
# 通知書 nr
# 與 zg
# 送達 v
# 證書 n
# 各 r
# 一件 m
# 在 p
# 卷足憑 i
# 是 v
# 被告 n
# 丙 n
# 於 nr
# 九十年 m
# 六月 t
# 十九日 m
# 被告 n
# 乙 n
# 出境 n
# 後 f
# 數度 n
# 歷經 d
# 大安 nz
# 分局 n
# 執行 v
# 之 u
# 搜索 v
# 扣押 v
# 及 c
# 訊問 n
# 心情 n
# 甚為 d
# 緊張 a
# 驚慌 a
# 大安 nz
# 分局 n
# 於 nr
# 九十年 m
# 八月 t
# 一日 m
# 及 c
# 同月 t
# 九日 t
# 並 c
# 二度 n
# 通知 v
# 被告 n
# 乙 n
# 到場 d
# 說明 v
# 分別 d
# 由 p
# 被告 n
# 丙 n
# 被告 n
# 乙 n
# 之父 r
# 戊 l
# 代為 v
# 收受 v
# 通知書 nr
# 此 zg
# 造成 v
# 被告 n
# 丙 n
# 極大 a
# 心理壓力 n
# 並 c
# 因此 c
# 數次 m
# 打電話 l
# 哭訴 v
# 催促 v
# 被告 n
# 乙 n
# 趕快 d
# 回臺 v
# 說明 v
# 被告 n
# 乙 n
# 為 zg
# 避免 v
# 不知情 i
# 之 u
# 丙 n
# 因 p
# 提款 v
# 及 c
# 丙 n
# 所有 b
# 二 m
# 七 m
# 一九三 m
# 號 m
# 自小 d
# 客車 n
# 內 f
# 被 p
# 採驗 vn
# 到 v
# 多處 m
# 子 ng
# 血跡 n
# 之 u
# 事 n
# 無法解釋 n
# 受 v
# 牽 v
# 採連 v
# 遂 d
# 於 nr
# 同年 t
# 九月 t
# 十一日 m
# 返臺 v
# 接受 v
# 調查 vn
# 至 p
# 被告 n
# 乙 n
# 聲 q
# 請 v
# 傳喚 v
# 鄭庭岳 nr
# 以 p
# 證明 n
# 其 r
# 於 nr
# 九十年 m
# 六月 t
# 十五日 m
# 晚間 t
# 與 p
# 鄭庭岳 nr
# 共同 d
# 用餐 n
# 又 d
# 聲請 v
# 傳喚 v
# 李 nr
# 菁菁 nz
# 李素 nr
# 月 m
# 李 nr
# 嫌 v
# 嬅 zg
# 李 nr
# 純如 v
# 以 p
# 證明 n
# 被告 n
# 丙 n
# 平日 t
# 以上 f
# 開 v
# 自用 v
# 小客車 n
# 搭載 v
# 其 r
# 等 u
# 上下班 v
# 惟查 v
# 該 r
# 等待 v
# 證 zg
# 事實 n
# 與 zg
# 本案 r
# 構成 v
# 要件 n
# 事實 n
# 並 c
# 無 v
# 關聯性 n
# 核無 l
# 調查 vn
# 之 u
# 必要 d
# 其次 r
# 被告 n
# 乙 n
# 聲 q
# 請 v
# 傳喚 v
# 遠東 ns
# 百貨公司 n
# 店員 n
# 以 p
# 證明 n
# 持子 n
# 信用卡 n
# 刷卡 n
# 之 u
# 人 n
# 然 c
# 本院 n
# 依據 p
# 右 f
# 開 v
# 理由 n
# 已足 d
# 認定 v
# 於 nr
# 右 f
# 揭 v
# 時 ng
# 地 uv
# 冒名 v
# 刷用 v
# 子 ng
# 信用卡 n
# 之 u
# 人 n
# 係 zg
# 被告 n
# 乙 n
# 核 n
# 無再 d
# 傳喚 v
# 該 r
# 店員 n
# 重複 d
# 調查 vn
# 本院 n
# 卷 m
# 證 n
# 已明 d
# 事項 n
# 之 u
# 必要 d
# 綜上 n
# 本件 n
# 雖 c
# 無 v
# 被告 n
# 乙 n
# 自白 v
# 又 d
# 尋 v
# 無 v
# 被害人 n
# 子 ng
# 屍體 n
# 惟 b
# 本院 n
# 綜合 vn
# 被害人 n
# 子 ng
# 主 b
# 臥房 n
# 浴室 n
# 內 f
# 之 u
# 牆壁 s
# 柱子 n
# 門板 n
# 地板 n
# 洗臉 v
# 檯 zg
# 浴缸 n
# 馬桶 n
# 等 u
# 處 n
# 均 d
# 附著 v
# 有 v
# 大量 n
# 子 ng
# 血液 n
# 另於 c
# 九十年 m
# 六月 t
# 十四日 m
# 晚間 t
# 被告 n
# 乙 n
# 向 p
# 其 r
# 妹丙 n
# 借用 v
# 自小 d
# 客車 n
# 嗣 ng
# 該 r
# 自小 d
# 客車 n
# 之 u
# 駕駛座 nz
# 後座 n
# 及 c
# 後 nr
# 車廂 n
# 均 d
# 經 p
# 檢驗 vn
# 出 v
# 留有 v
# 被害人 n
# 子 ng
# 血跡 n
# 衡之 nr
# 社會 n
# 常情 n
# 活人 n
# 不 d
# 可能 v
# 在 p
# 後 nr
# 車廂 n
# 活動 vn
# 僅 zg
# 屍體 n
# 始 d
# 可能 v
# 置於 v
# 後 f
# 車廂 n
# 暨 nt
# 被害人 n
# 子 ng
# 於 nr
# 九十年 m
# 六月 t
# 十四日 m
# 上午 t
# 十一時 d
# 許 m
# 與 p
# 被告 n
# 乙 n
# 通話 n
# 後 f
# 即告 v
# 失蹤 v
# 亦 d
# 即 v
# 自 r
# 九十年 m
# 六月 t
# 十四日 m
# 以後 f
# 子 ng
# 即 v
# 毫無 v
# 任何 r
# 社會 n
# 經濟 n
# 活動 vn
# 另 r
# 本院 n
# 參酌 v
# 被告 n
# 乙 n
# 於 nr
# 九十年 m
# 六月 t
# 十四日 m
# 前 f
# 財務 n
# 困難 an
# 需款 n
# 恐急 a
# 及 c
# 被告 n
# 乙 n
# 無法 n
# 合理 vn
# 說明 v
# 其 r
# 為何 r
# 持有 v
# 子 ng
# 財物 n
# 含持子 n
# 存摺 v
# 刻印 v
# 章 q
# 背書 n
# 存入 v
# 子 ng
# 所有 b
# 之 u
# 支票 n
# 以 p
# 子 ng
# 金融 n
# 卡 n
# 輸入 v
# 密碼 n
# 提款 v
# 十二 m
# 萬元 m
# 以 p
# 子 ng
# 信用卡 n
# 刷卡 n
# 等 u
# 事 n
# 證 n
# 因 p
# 認 v
# 被告 n
# 乙 n
# 矢口否認 i
# 犯行 vn
# 飾詞 n
# 矯 nr
# 辯 vg
# 均 d
# 不足 a
# 採信 v
# 是 v
# 被告 n
# 乙 n
# 右 f
# 揭 v
# 所犯 n
# 強盜 n
# 而 c
# 故意 d
# 殺人 n
# 行使 n
# 偽造 v
# 私 n
# 文書 n
# 詐欺 v
# 取財 v
# 及以 c
# 不正 d
# 方法 n
# 自動 vn
# 付款 v
# 設備 vn
# 取得 v
# 他人 r
# 之 u
# 物 ng
# 之 u
# 犯行 v
# 均 d
# 堪 v
# 認定 v
# 應 v
# 依法 n
# 論科 nz
# 三 m
# 核 n
# 被告 n
# 乙 n
# 所為 c
# 係 yg
# 犯 v
# 修正 nr
# 後 f
# 刑法 n
# 第三 m
# 百 n
# 三十二條 m
# 第一項 m
# 強盜 n
# 而 c
# 故意殺人罪 i
# 同法 n
# 第二百 m
# 十六條 m
# 第二 m
# 百十條 m
# 之 u
# 行使 n
# 偽造 v
# 私 n
# 文書 n
# 罪 zg
# 同法 n
# 第三 m
# 百 n
# 三十 m
# 九條 m
# 第一項 m
# 之 u
# 詐欺 v
# 取財 v
# 罪 n
# 及 c
# 同法 n
# 第三 m
# 百 n
# 三十 m
# 九條 m
# 之二 r
# 第一項 m
# 以 p
# 不正 d
# 方法 n
# 由 p
# 自動 vn
# 付款 v
# 設備 vn
# 取得 v
# 他人 r
# 之 u
# 物 ng
# 罪 n
# 起訴書 n
# 誤載 v
# 被告 n
# 乙 n
# 涉犯 v
# 刑法 n
# 第三 m
# 百 n
# 三十 m
# 九條 m
# 第一項 m
# 詐欺 v
# 取財 v
# 罪 n
# 經 p
# 蒞 vg
# 庭 ng
# 檢察官 n
# 當庭 n
# 更正 d
# 為 p
# 同法 n
# 第三 m
# 百 n
# 三十 m
# 九條 m
# 之二 r
# 第一項 m
# 之 u
# 罪 n
# 併 y
# 予 vg
# 敘 v
# 明 d
# 按行 v
# 為 p
# 後 nr
# 法律 n
# 有 v
# 變更 v
# 者 k
# 適用 v
# 裁判 vn
# 時 ng
# 之 u
# 法律 n
# 但 c
# 裁判 vn
# 前 f
# 之 u
# 法律 n
# 有利於 v
# 行為 v
# 人者 n
# 適用 v
# 最 d
# 有利於 v
# 行 v
# 為 p
# 人 n
# 之 u
# 法律 n
# 刑法 n
# 第二條 m
# 第一項 m
# 定 v
# 有 v
# 明定 a
# 經查 vn
# 被告 n
# 乙 n
# 於 nr
# 九十年 m
# 六月 t
# 十四日 m
# 行 v
# 為 p
# 後 nr
# 立法院 l
# 已於 d
# 九 m
# 十一年 m
# 一月 m
# 八日 t
# 修正 nr
# 廢止 v
# 懲治 v
# 盜匪 n
# 條例 n
# 第二條 m
# 第一項 m
# 第六款 m
# 強盜 n
# 殺人罪 i
# 並 c
# 將 d
# 刑法 n
# 第三 m
# 百 n
# 三十二條 m
# 修正 nr
# 同年 t
# 月 m
# 三十 m
# 日經 d
# 總統 n
# 公布 v
# 於 nr
# 二月 m
# 一日 m
# 生效 n
# 施行 v
# 被告 n
# 盜匪 n
# 行為 v
# 在 p
# 懲治 v
# 盜匪 n
# 條例 n
# 未 d
# 公布 v
# 廢止 v
# 前 f
# 依 d
# 被告 n
# 行為 v
# 時 ng
# 所 u
# 適用 v
# 之 u
# 法律 n
# 而言 c
# 該 r
# 條例 n
# 乃 v
# 修正 nr
# 前 f
# 刑法 n
# 指 v
# 九 m
# 十一年 m
# 一月 m
# 三十日 m
# 修正 nr
# 增訂 v
# 前 f
# 之 u
# 刑法 n
# 之 u
# 特別法 n
# 依 d
# 特別法 n
# 優於 v
# 普通法 n
# 之 u
# 法律 n
# 適用 v
# 原則 n
# 自應 v
# 適用 v
# 懲治 v
# 盜匪 n
# 條例 n
# 論處 n
# 無 v
# 適用 v
# 修正 nr
# 前 f
# 刑法 n
# 之 u
# 餘地 n
# 而 c
# 懲治 v
# 盜匪 n
# 條例 n
# 之 u
# 廢止 v
# 與 zg
# 刑法 n
# 強盜 n
# 擄 vg
# 人 n
# 勒 v
# 贖 v
# 及其 c
# 結合 v
# 犯 v
# 等 u
# 相關 v
# 條文 n
# 之 u
# 修正 nr
# 及 c
# 增訂 v
# 係 yg
# 經 p
# 立法院 l
# 於 nr
# 同日 t
# 三讀通過 n
# 並經 d
# 總統 n
# 於九 nr
# 十一年 m
# 一月 m
# 三十日 m
# 同日 t
# 公布 v
# 施行 v
# 考 v
# 其 r
# 立法 d
# 之 u
# 目的 n
# 在 p
# 以 f
# 修正 nr
# 後 nr
# 之 u
# 刑法 n
# 取代 v
# 上開 v
# 條例 n
# 避免 v
# 修正 nr
# 前 f
# 之 u
# 刑法 n
# 發生 v
# 中間 f
# 法 j
# 之 u
# 效力 n
# 故 n
# 懲治 v
# 盜匪 n
# 條例 n
# 雖曰 c
# 廢止 v
# 然因 c
# 廢止 v
# 前後 f
# 被告 n
# 行為 v
# 在 p
# 行為 v
# 時 ng
# 至 p
# 裁判 vn
# 時 zg
# 均 d
# 有 v
# 刑罰 n
# 規定 n
# 該 r
# 條例 n
# 之 u
# 廢止 v
# 自屬 n
# 刑法 n
# 第二條 m
# 第一項 m
# 之行 r
# 為 p
# 後 nr
# 法律 n
# 有 v
# 變更 v
# 而 c
# 非 h
# 刑事訴訟法 n
# 第三 m
# 百零 m
# 二條 m
# 第四款 m
# 第三 m
# 百八十 m
# 一條 m
# 第三 m
# 百 n
# 九十 m
# 三條 m
# 第四款 m
# 所稱 v
# 之 u
# 刑法 n
# 廢止 v
# 亦 d
# 無所謂 l
# 因 p
# 該 r
# 條例 n
# 之 u
# 廢止 v
# 而 c
# 應 v
# 回 v
# 復 zg
# 適用 v
# 修正 nr
# 前 f
# 刑法 n
# 相關 v
# 條文 n
# 之 u
# 餘地 n
# 依上 d
# 說明 v
# 被告 n
# 乙 n
# 之 u
# 盜匪 n
# 行為 v
# 法院 n
# 於九 nr
# 十一年 m
# 二月 m
# 一日 m
# 以後 f
# 裁判 vn
# 時 zg
# 依 d
# 刑法 n
# 第二條 m
# 第一項 m
# 規定 n
# 並 c
# 參酌 v
# 最高法院 nt
# 二十五年 m
# 上 f
# 字 n
# 第二 m
# 六七 m
# 號 m
# 二十八年 m
# 上 f
# 字 n
# 第二 m
# 三九 m
# 七號 m
# 五十一年 m
# 臺上 s
# 字 n
# 第二 m
# 一七 m
# 九號 m
# 諸 r
# 判例 n
# 意旨 n
# 自應 v
# 就 d
# 被告 n
# 行為 v
# 時 n
# 有效 a
# 之 u
# 懲治 v
# 盜匪 n
# 條例 n
# 與 zg
# 裁判 vn
# 時 ng
# 已 d
# 修正 nr
# 之 u
# 刑法 n
# 予以 v
# 比較 d
# 適用 v
# 至 p
# 被告 n
# 行為 v
# 時 n
# 修正 nr
# 前 f
# 之 u
# 刑法 n
# 相關 v
# 條文 n
# 既 c
# 不 d
# 因 p
# 上 f
# 開 v
# 條例 n
# 廢止 v
# 而 c
# 回 v
# 復 zg
# 又 d
# 非 d
# 中間 f
# 法 j
# 即 v
# 無所謂 l
# 比較 d
# 適用 v
# 問題 n
# 而 c
# 原 n
# 懲治 v
# 盜匪 n
# 條例 n
# 第二條 m
# 第一項 m
# 第六款 m
# 強劫 v
# 殺人罪 i
# 之 u
# 法定 n
# 刑 n
# 為 p
# 死刑 v
# 新 a
# 修正 nr
# 之 u
# 刑法 n
# 第三 m
# 百 n
# 三十二條 m
# 第一項 m
# 強盜 n
# 而 c
# 故意殺人罪 i
# 之 u
# 法定 n
# 刑 n
# 為 p
# 死刑 v
# 或 c
# 無期徒刑 l
# 比較 d
# 新舊 ns
# 法 j
# 自 p
# 以 p
# 修正 nr
# 後 nr
# 之 u
# 刑法 n
# 第三 m
# 百 n
# 三十二條 m
# 第一項 m
# 有利於 v
# 行為 v
# 人 n
# 又 d
# 被告 n
# 乙 n
# 於 nr
# 簽 v
# 帳單 n
# 上偽 j
# 造子 n
# 中英文 nz
# 署押 v
# 及 c
# 偽造子 n
# 印章 n
# 蓋 v
# 在 p
# 上 f
# 開支票 n
# 背面 f
# 偽造 v
# 印文 nz
# 以為 c
# 背書 n
# 之 u
# 行為均 nr
# 係 zg
# 偽 j
# 造 v
# 私 ag
# 文書 n
# 之 u
# 部分 n
# 行為 v
# 又 d
# 偽造 v
# 私 n
# 文書 n
# 後 f
# 進而 c
# 行使 n
# 偽造 v
# 之 u
# 低度 n
# 行為 v
# 應為 v
# 行使 n
# 之 u
# 高度 n
# 行為 n
# 所 u
# 吸收 v
# 均 d
# 不 d
# 另 r
# 論罪 vn
# 被告 n
# 乙 n
# 利用 n
# 不知情 i
# 之 u
# 丙 n
# 領款 n
# 及 c
# 利用 n
# 不知情 i
# 之 u
# 刻印 v
# 店 n
# 人員 n
# 偽刻子 n
# 印章 n
# 均 d
# 為 p
# 間接 b
# 正犯 v
# 被告 n
# 乙 n
# 如 v
# 附表 n
# 一 m
# 編號 n
# 四 m
# 所示 v
# 之行 r
# 為 p
# 因 p
# 其 r
# 存入 v
# 面額 n
# 六萬元 m
# 支票 n
# 尚未 d
# 交換 v
# 完畢 v
# 致 v
# 存款 n
# 不足 a
# 未領 v
# 得 ud
# 款項 n
# 是 v
# 其 r
# 該次 r
# 犯行 v
# 尚屬 n
# 未遂 v
# 被告 n
# 乙 n
# 所犯 n
# 以 p
# 不正 d
# 方法 n
# 自動 vn
# 付款 v
# 設備 vn
# 取得 v
# 他人 r
# 之 u
# 物 ng
# 罪 n
# 包括 v
# 既 c
# 遂 d
# 及 c
# 未遂 v
# 部分 n
# 上開 v
# 行使 n
# 偽造 v
# 私 n
# 文書 n
# 罪 n
# 及 c
# 詐欺 v
# 取財 v
# 罪 n
# 均 d
# 有 v
# 多次 m
# 犯行 vn
# 各 r
# 犯 v
# 行間 n
# 均 d
# 時間 n
# 緊接 ad
# 觸犯 v
# 構成 v
# 要件 n
# 相同 d
# 之 u
# 罪名 n
# 顯均 nr
# 係 zg
# 基於 p
# 概括 v
# 犯意 v
# 而為 c
# 之 r
# 均 d
# 為 p
# 連續犯 n
# 應 v
# 分別 d
# 論 v
# 以 p
# 一 m
# 連續 a
# 行使 n
# 偽造 v
# 私 n
# 文書 n
# 罪 n
# 及 c
# 連續 a
# 詐欺 v
# 取財 v
# 罪 n
# 又 d
# 被告 n
# 所犯 n
# 前 f
# 開 v
# 強盜 n
# 而 c
# 故意殺人罪 i
# 行使 n
# 偽造 v
# 私 n
# 文書 n
# 罪 zg
# 詐欺 v
# 取財 v
# 罪 n
# 及以 c
# 不正 d
# 方法 n
# 由 p
# 自動 vn
# 付款 v
# 設備 vn
# 取得 v
# 他人 r
# 之物 r
# 罪間 n
# 有 v
# 方法 n
# 結果 n
# 之 u
# 牽連 v
# 關係 n
# 應依 nr
# 刑法 n
# 第五 m
# 十五條 m
# 牽連 v
# 犯 v
# 之 u
# 規定 n
# 從 zg
# 較重 a
# 之 u
# 強盜 n
# 而 c
# 故意殺人罪 i
# 處斷 v
# 爰 g
# 審酌 v
# 被告 n
# 乙 n
# 與 zg
# 被害人 n
# 子 ng
# 並 c
# 無 v
# 深仇大恨 i
# 竟 d
# 因 p
# 需款 n
# 恐急 a
# 在 p
# 邀約 v
# 被害人 n
# 子 ng
# 投資 vn
# 遭致 v
# 嚴 a
# 拒 vg
# 為 p
# 謀奪 v
# 被害人 n
# 財物 n
# 而 c
# 遽 d
# 下毒手 v
# 事後 t
# 逐步 d
# 提領 v
# 被害人 n
# 帳戶 n
# 之 u
# 現款 n
# 花 v
# 用 p
# 並 c
# 冒名 v
# 刷用 v
# 被害人 n
# 之 u
# 信用卡 n
# 消費 vn
# 以圖 v
# 一己 r
# 私利 a
# 迄 l
# 本院 n
# 辯論 n
# 終結 v
# 時 zg
# 猶 d
# 矢口否認 i
# 犯行 vn
# 拒不 l
# 供出 v
# 被害人 n
# 屍體 n
# 之 u
# 下落 v
# 飾詞 n
# 狡卸 v
# 毫無悔意 l
# 所為 c
# 造成 v
# 被害人 n
# 家屬 n
# 身心 n
# 受 v
# 有 v
# 永久 d
# 難以 d
# 抹滅 v
# 之 u
# 哀痛 a
# 衡諸 nr
# 社會 n
# 一般 a
# 人 n
# 客觀 n
# 標準 n
# 難 a
# 邀 v
# 憫 g
# 恕 vg
# 惟念 v
# 及其 c
# 潛逃 v
# 大陸 n
# 地區 n
# 後 f
# 受 v
# 胞妹 n
# 丙 n
# 之 u
# 勸說 v
# 為 zg
# 避免 v
# 丙 n
# 因 p
# 提款 v
# 及 c
# 丙 n
# 所有 b
# 二 m
# 七 m
# 一九三 m
# 號 m
# 自小 d
# 客車 n
# 被 p
# 採驗 vn
# 到 v
# 多處 m
# 子 ng
# 血跡 n
# 無法解釋 n
# 而 c
# 受 v
# 牽連 v
# 尚能 v
# 回臺 v
# 接受 v
# 調查 vn
# 良知 n
# 尚未 d
# 完全 ad
# 泯滅 v
# 及其 c
# 犯罪 vn
# 之 u
# 手段 n
# 智識 n
# 程度 n
# 犯罪 vn
# 後 nr
# 之 u
# 態度 n
# 等 u
# 一切 r
# 情狀 n
# 量 n
# 處 n
# 如 v
# 主文 n
# 所示 v
# 之 u
# 刑 n
# 並 c
# 依法 n
# 宣告 n
# 褫奪公權 vn
# 終身 d
# 以昭炯戒 i
# 末 f
# 查 v
# 如 v
# 附表 n
# 二 m
# 編號 n
# 一至 d
# 十 m
# 所示 v
# 商店 n
# 消 v
# 費時 n
# 被告 n
# 乙 n
# 所 u
# 偽造 v
# 如 c
# 附件 n
# 一至 d
# 附件 n
# 十 m
# 所示 v
# 子 ng
# 名義 n
# 之 u
# 簽 v
# 帳單 n
# 顧客 nr
# 存根聯 nz
# 為 zg
# 被告 n
# 乙 n
# 所有 b
# 因 p
# 犯罪 vn
# 所得 v
# 之物 r
# 無法 n
# 證明 n
# 已 d
# 滅失 v
# 而 c
# 不 d
# 存在 v
# 均依 nz
# 刑法 n
# 第三十八條 m
# 第一項 m
# 第三款 m
# 規定 n
# 宣告 n
# 沒收 v
# 另如 c
# 附件 n
# 一至 d
# 附件 n
# 十 m
# 所示 v
# 簽 zg
# 帳單 n
# 之 u
# 特約商店 nt
# 存根聯 nz
# 均 d
# 已 d
# 交付 v
# 各 r
# 特約商店 nt
# 已 d
# 非 h
# 被告 n
# 乙 n
# 所有 b
# 然其 c
# 上偽 j
# 造子 n
# 之中 r
# 英文 nz
# 署押 v
# 及如 c
# 附表 n
# 三 m
# 所示 v
# 被告 n
# 偽刻 n
# 之 u
# 子 ng
# 印章 n
# 與 p
# 在 p
# 上 f
# 開支票 n
# 上 f
# 偽造 v
# 之 u
# 子 ng
# 印文 nz
# 各 r
# 一枚 m
# 均 d
# 應 v
# 依 d
# 刑法 n
# 第二 m
# 百十 m
# 九條 m
# 宣告 n
# 沒收 v
# 至 p
# 被告 n
# 乙 n
# 雖 c
# 將 d
# 被害人 n
# 子 ng
# 之 u
# 屍體 n
# 攜至 v
# 不詳 v
# 處所 v
# 湮滅 v
# 然 r
# 無 v
# 積極 ad
# 證據 n
# 證明 n
# 其 r
# 係 y
# 以 p
# 掩埋 v
# 抑或 c
# 任意 v
# 棄置 v
# 之 u
# 方式 n
# 為 p
# 之 f
# 尚難 d
# 遽以 d
# 遺棄 v
# 屍體 n
# 罪相 n
# 繩 n
# 附此 d
# 敘明 v
# 貳 m
# 丙 n
# 部分 n
# 一 m
# 公訴 v
# 意旨 n
# 略以 v
# 被告 n
# 丙 n
# 明知 v
# 乙 n
# 交付 v
# 之 u
# 金融 n
# 卡 n
# 帳戶 n
# 存款 n
# 來源不明 v
# 竟 d
# 基於 p
# 不法 n
# 所有 b
# 之 u
# 意圖 n
# 受 v
# 被告 n
# 乙 n
# 囑託 v
# 持 v
# 被害人 n
# 子 ng
# 之 u
# 金融 n
# 卡於 nr
# 附表 n
# 一 m
# 編號 n
# 五 m
# 所示 v
# 之時 r
# 地盜 n
# 領子 n
# 之 u
# 存款 n
# 共計 v
# 六萬元 m
# 其中 r
# 二 m
# 萬元 m
# 依 d
# 被告 n
# 乙 n
# 之 u
# 指示 v
# 償還 v
# 被告 n
# 乙 n
# 之前 f
# 妻亥 nz
# 二萬 m
# 元代 t
# 被告 n
# 乙 n
# 清償 vn
# 信用卡 n
# 債務 n
# 所餘 b
# 兩萬元 m
# 則 d
# 留 v
# 為己 r
# 用 p
# 因 p
# 認 v
# 被告 n
# 丙 n
# 涉犯 v
# 刑法 n
# 第三 m
# 百 n
# 四十 m
# 九條 m
# 第一項 m
# 收受 v
# 贓物罪 n
# 嫌 v
# 第三 m
# 百 n
# 三十 m
# 九條 m
# 之二 r
# 以 p
# 不正 d
# 方法 n
# 由 p
# 自動 vn
# 付款 v
# 設備 vn
# 取得 v
# 他人 r
# 之物 r
# 罪嫌 n
# 起訴書 n
# 誤載 v
# 為 p
# 刑法 n
# 第三 m
# 百 n
# 三十 m
# 九條 m
# 之 u
# 詐欺罪 vn
# 嫌 v
# 經 p
# 蒞 vg
# 庭 ng
# 檢察官 n
# 當庭 n
# 更正 d
# 等 u
# 語 ng
# 二 m
# 公訴人 n
# 認 v
# 被告 n
# 丙 n
# 涉犯 v
# 右 f
# 揭犯 v
# 行 n
# 無非 c
# 以 p
# 被告 n
# 乙 n
# 之 u
# 陳述 nr
# 被告 n
# 告 v
# 丙 n
# 自白 v
# 通聯 j
# 紀錄 n
# 及 c
# 錄影帶 n
# 翻拍 v
# 照片 n
# 且 zg
# 被告 n
# 乙 n
# 曾 d
# 告知 v
# 以 p
# 金融 n
# 卡 n
# 提款 v
# 後 f
# 應 v
# 即將 d
# 金融 n
# 卡 n
# 丟棄 v
# 因 p
# 認 v
# 被告 n
# 丙 n
# 對於 i
# 該 r
# 提款卡 n
# 來源不明 v
# 係 zg
# 非法 b
# 取得 v
# 之物 r
# 應有 v
# 預見 v
# 竟 d
# 仍 d
# 持 v
# 之 u
# 提領 v
# 他 r
# 人財物 nt
# 其 r
# 主觀 n
# 上 f
# 應有 v
# 贓物罪 n
# 及 c
# 詐欺罪 vn
# 之 u
# 不 d
# 確定 v
# 故意 d
# 資為 n
# 論據 n
# 被告 n
# 丙 n
# 固 j
# 坦承 v
# 持上 v
# 開 v
# 金融 n
# 卡於 nr
# 附表 n
# 一 m
# 編號 n
# 五 m
# 所示 v
# 之時 r
# 地由 n
# 自動 vn
# 付款 v
# 設備 vn
# 之 u
# 提款機 n
# 分 v
# 三次 m
# 提領 v
# 共 d
# 六萬元 m
# 之 u
# 事實 n
# 惟 d
# 堅詞 v
# 否認 v
# 右 f
# 揭犯 v
# 行 n
# 辯稱 v
# 乙 n
# 將 d
# 上開 v
# 金融 n
# 卡 n
# 交付 v
# 伊 ns
# 委託 n
# 伊 ns
# 領款 n
# 六萬元 m
# 金融 n
# 卡 n
# 上 f
# 沒有 v
# 姓名 n
# 伊 j
# 並 c
# 不知 v
# 金融 n
# 卡 v
# 係 zg
# 何人 r
# 所有 b
# 乙 n
# 僅 zg
# 告知 v
# 是 v
# 人頭 n
# 戶 q
# 的 uj
# 錢 n
# 等 u
# 語 ng
# 三 m
# 按 p
# 犯罪事實 n
# 應依 nr
# 證據 n
# 認定 v
# 無證據 n
# 不得 v
# 推定 v
# 其 r
# 犯罪事實 n
# 又 d
# 不能 v
# 證明 n
# 被告 n
# 犯罪者 n
# 應 v
# 諭知 n
# 無罪 v
# 之 u
# 判決 v
# 刑事訴訟法 n
# 第一百五十四條 m
# 第三 m
# 百零 m
# 一條 m
# 第一項 m
# 分別 d
# 定 v
# 有 v
# 明文 nr
# 次 m
# 按 p
# 被告 n
# 之 u
# 自白 v
# 不得 v
# 作為 v
# 有罪 vn
# 判決 v
# 之 u
# 唯一 b
# 證據 n
# 仍 d
# 應 v
# 調查 vn
# 其他 r
# 必要 d
# 之 u
# 證據 n
# 以察 v
# 其 r
# 是否 v
# 與 zg
# 事實 n
# 相符 v
# 刑事訴訟法 n
# 第一百五十 m
# 六條 m
# 第二項 m
# 亦 d
# 有 v
# 明文 nr
# 第 m
# 按 p
# 認定 v
# 不利於 v
# 被告 n
# 之 u
# 事實 n
# 須依 nr
# 積極 ad
# 證據 n
# 苟 nr
# 積極 ad
# 證據不足 v
# 為 zg
# 不利於 v
# 被告 n
# 事實 n
# 之 u
# 認 v
# 定時 d
# 即 v
# 應為 v
# 有利於 v
# 被告 n
# 之 u
# 認定 v
# 最高法院 nt
# 三十年 m
# 臺上 s
# 字 n
# 第八 m
# 一 m
# 六號 m
# 判例 n
# 參照 v
# 又 d
# 事實 n
# 之 u
# 認定 v
# 應 v
# 憑 p
# 證據 n
# 如 v
# 未能 v
# 發現 v
# 相當 d
# 證據 n
# 或 c
# 證據 n
# 不足以 v
# 證明 n
# 自 p
# 不能 v
# 以 p
# 推測 v
# 或 c
# 擬制 v
# 之 u
# 方法 n
# 以為 c
# 裁判 vn
# 基礎 n
# 最高法院 nt
# 四十年 m
# 臺上 s
# 八 m
# 六號 m
# 判例 n
# 參照 v
# 又 d
# 認定 v
# 犯罪事實 n
# 所 u
# 憑 p
# 之 f
# 證據 n
# 雖不以 c
# 直接 ad
# 證據 n
# 為 p
# 限 v
# 間接 b
# 證據 n
# 亦 d
# 包括 v
# 在內 u
# 然而 c
# 無論 c
# 直接 ad
# 或 c
# 間接 b
# 證據 n
# 其 r
# 為 p
# 訴訟 vn
# 上 f
# 之 u
# 證明 n
# 須於 nr
# 通常 d
# 一般 a
# 之 u
# 人均 j
# 不致 c
# 有所 n
# 懷疑 v
# 而 c
# 得 ud
# 確信 v
# 其 r
# 為 p
# 真實 d
# 之 u
# 程度 n
# 者 k
# 始得 v
# 據為 v
# 有罪 vn
# 之 u
# 認定 v
# 最高法院 nt
# 七 m
# 十六年 m
# 臺上 s
# 字 n
# 第四 m
# 九八 m
# 六號 m
# 判例 n
# 參照 v
# 四 m
# 經查 vn
# 被告 n
# 丙 n
# 於 nr
# 警詢 vn
# 時 ng
# 曾 d
# 供稱 v
# 上開 v
# 金融 n
# 卡 n
# 是 v
# 乙 n
# 於 nr
# 九十年 m
# 六月 t
# 十八日 m
# 晚間 t
# 十一時 d
# 許 m
# 拿 v
# 至 p
# 臺北縣 ns
# 永和市 ns
# 路 n
# 一 m
# 五一 m
# 巷五 n
# 弄 v
# 五號 m
# 其 r
# 住處 n
# 交給 v
# 伊 j
# 的 uj
# 乙 n
# 將 d
# 該 r
# 金融 n
# 卡 n
# 交給 v
# 伊時 nr
# 特別 d
# 叮嚀 v
# 說 v
# 提完 v
# 錢 n
# 後 nr
# 即將 d
# 該 r
# 金融 n
# 卡 n
# 剪掉 v
# 丟棄 v
# 其 r
# 詢問 v
# 乙 n
# 為何 r
# 要 v
# 如此 c
# 做 v
# 乙 n
# 即 v
# 告知 v
# 該 r
# 金融 n
# 卡 n
# 是 v
# 人頭 n
# 戶 q
# 申請 v
# 的 uj
# 所以 c
# 不宜 a
# 留在 v
# 身上 s
# 伊領 nr
# 完 v
# 錢 n
# 後 nr
# 即 v
# 依 v
# 乙 n
# 的 uj
# 指示 v
# 將 zg
# 該卡 r
# 用 p
# 手 s
# 折斷 v
# 後 f
# 丟棄 v
# 在 p
# 陽明醫院 nt
# 的 uj
# 垃圾桶 n
# 內 n
# 所領 n
# 的 uj
# 款項 n
# 依乙 nr
# 指示 v
# 二 m
# 萬元 m
# 還給 v
# 亥 t
# 二 m
# 萬元 m
# 繳付 v
# 乙 n
# 信用卡 n
# 帳款 n
# 另 r
# 二 m
# 萬元 m
# 留 v
# 作家 n
# 用 p
# 等 u
# 語 ng
# 參 zg
# 大安 nz
# 分局 n
# 刑事 b
# 卷宗 nz
# 第三 m
# 六 m
# 三頁 m
# 於 nr
# 偵查 v
# 中 f
# 供稱 v
# 乙 n
# 於 nr
# 六月 t
# 十八日 m
# 晚間 t
# 來 v
# 找 v
# 伊 ns
# 說 v
# 他 r
# 向 p
# 前妻 n
# 借 v
# 兩萬元 m
# 請 v
# 其 r
# 去 v
# 領錢 n
# 還 d
# 他 r
# 前妻 n
# 乙 n
# 於 nr
# 六月 t
# 十八日 m
# 晚上 t
# 在 p
# 自己 r
# 住處 n
# 將 zg
# 金融 n
# 卡 n
# 給 p
# 伊 ns
# 乙 n
# 不 d
# 自己 r
# 去 v
# 領 n
# 是 v
# 因為 c
# 一張 m
# 票 n
# 要 v
# 交換 v
# 來不及 v
# 領 v
# 故 n
# 託 zg
# 伊 j
# 幫忙 v
# 領 v
# 六萬元 m
# 其中 r
# 兩萬元 m
# 留 v
# 作家 n
# 用 p
# 乙 n
# 沒有 v
# 告訴 v
# 伊 ns
# 金融 n
# 卡 n
# 是 v
# 誰 r
# 的 uj
# 只 d
# 說 v
# 金融 n
# 卡 n
# 是 v
# 人頭 n
# 戶 q
# 的 uj
# 叫 v
# 伊 ns
# 丟掉 v
# 伊將 nr
# 提款卡 n
# 丟 v
# 在 p
# 陽明醫院 nt
# 之 u
# 垃圾桶 n
# 內 f
# 等 u
# 語 ng
# 參 zg
# 九十一 m
# 年度 n
# 偵字 n
# 第一 m
# 六 m
# 一一 m
# 七號 m
# 卷 m
# 第五十三 m
# 頁 m
# 觀 vg
# 諸 r
# 被告 n
# 丙 n
# 上開 v
# 供述 vn
# 被告 n
# 丙 n
# 雖 zg
# 坦承 v
# 持上 v
# 開 v
# 金融 n
# 卡 n
# 領款 n
# 之 u
# 事實 n
# 且 c
# 與 p
# 被告 n
# 乙 n
# 所供 v
# 交付 v
# 上開 v
# 金融 n
# 卡予 nr
# 被告 n
# 丙 n
# 指示 v
# 被告 n
# 丙 n
# 提款 v
# 之 u
# 情節 n
# 一致 d
# 然 c
# 被告 n
# 丙 n
# 始終 d
# 辯稱 v
# 上開 v
# 金融 n
# 卡 v
# 係 zg
# 被告 n
# 乙 n
# 交付 v
# 經乙 n
# 告知 v
# 係 zg
# 人頭 n
# 之 u
# 金融 n
# 卡等語 nz
# 則 zg
# 被告 n
# 丙 n
# 於 nr
# 警詢 vn
# 及 c
# 偵查 v
# 中 f
# 對於 i
# 公訴人 n
# 起訴 v
# 之 u
# 犯罪事實 n
# 顯未 i
# 自白 v
# 按 p
# 刑法 n
# 第十三條 m
# 第一項 m
# 明定 a
# 行為 v
# 人 n
# 對於 i
# 構成犯罪 l
# 之 u
# 事實 n
# 明知 v
# 並 c
# 有意 v
# 使 v
# 其 r
# 發生 v
# 者 k
# 為 p
# 故意 d
# 同 p
# 條 n
# 第二項 m
# 明定 a
# 行為 v
# 人 n
# 對於 i
# 犯罪 vn
# 之 u
# 事實 n
# 預見 v
# 其 r
# 發生 v
# 而 c
# 其 r
# 發生 v
# 並 c
# 不 d
# 違背 v
# 其 r
# 本意 d
# 者 k
# 以 p
# 故意 d
# 論 zg
# 前者 n
# 學理 n
# 上謂 v
# 為 p
# 意欲 n
# 主義 n
# 後者 n
# 謂 v
# 為容 v
# 認 v
# 主義 n
# 但 c
# 不論 c
# 其 r
# 為 p
# 明知 v
# 或 c
# 預見 v
# 皆 d
# 為 p
# 故意 d
# 犯 v
# 主觀 n
# 上 f
# 之 u
# 認識 v
# 只是 c
# 程度 n
# 強弱 a
# 有別 d
# 行 v
# 為 p
# 人 n
# 有 v
# 此 r
# 認識 v
# 進而 c
# 有 v
# 使 v
# 其 r
# 發生 v
# 或 c
# 任 v
# 其 r
# 發生 v
# 之 u
# 意 ng
# 則 zg
# 形成 v
# 犯意 v
# 前者 n
# 為 zg
# 確定 v
# 故意 d
# 直接 ad
# 故意 d
# 後者 n
# 為 p
# 不 v
# 確定 v
# 故意 d
# 間接 b
# 故意 d
# 刑法 n
# 關於 p
# 犯罪 vn
# 之 u
# 故意 d
# 係 yg
# 採 v
# 希望 v
# 主義 n
# 不但 c
# 直接 ad
# 故意 d
# 須 d
# 犯人 n
# 對於 i
# 構成犯罪 l
# 之 u
# 事實 n
# 具備 v
# 明知 v
# 及 c
# 有意 v
# 使 v
# 其 r
# 發生 v
# 之 u
# 兩個 m
# 要件 n
# 即 v
# 間接 b
# 故意 d
# 亦須 v
# 犯人 n
# 對於 i
# 構成犯罪 l
# 之 u
# 事實 n
# 預見 v
# 其 r
# 發生 v
# 且其 c
# 發生 v
# 不 d
# 違背 v
# 犯人 n
# 本意 d
# 始 d
# 成立 v
# 最高法院 nt
# 九十年 m
# 台上 s
# 字 n
# 第七 m
# 九六 m
# 四號 m
# 判決 v
# 二十二年 m
# 上 f
# 字 n
# 第四 m
# 二二 m
# 九號 m
# 判例 n
# 意旨 n
# 可資 l
# 參照 v
# 經查 vn
# 被告 n
# 乙 n
# 與 p
# 丙 n
# 係 zg
# 親兄妹 n
# 感情 n
# 深厚 a
# 九十年 m
# 九月 t
# 十一日 m
# 乙 n
# 返臺 v
# 接受 v
# 調查 vn
# 亦 d
# 因 p
# 避免 v
# 丙 n
# 受 v
# 牽連 v
# 被告 n
# 乙 n
# 前往 t
# 大陸 n
# 地區 n
# 經商 n
# 後 f
# 財務狀況 n
# 未見好轉 i
# 其他 r
# 親友 n
# 均 d
# 不 d
# 願 v
# 借款 n
# 此 r
# 據 p
# 被告 n
# 丙 n
# 陳明 nr
# 在 p
# 卷 m
# 被告 n
# 丙 n
# 除 p
# 繼續 v
# 與 p
# 之 f
# 往來 t
# 外 f
# 並 c
# 陸續 d
# 借款 n
# 數百萬元 m
# 予 vg
# 被告 n
# 乙 n
# 被告 n
# 乙 n
# 因所 c
# 存入 v
# 上開 v
# 六萬元 m
# 支票 n
# 須 d
# 透過 v
# 交換 v
# 始能 v
# 兌領 v
# 惟其 c
# 於 nr
# 九十年 m
# 六月 t
# 十九日 m
# 早上 t
# 急於 d
# 出境 n
# 故 c
# 將 d
# 上開 v
# 金融 n
# 卡 n
# 交付 v
# 並 c
# 告知 v
# 密碼 n
# 委由 n
# 丙 n
# 代為 v
# 領款 n
# 與 zg
# 日常生活 i
# 經驗 n
# 尚無 v
# 違背 v
# 次 m
# 查 v
# 本件 n
# 並 c
# 無 v
# 積極 ad
# 證據 n
# 證明 n
# 被告 n
# 乙 n
# 持交 v
# 該 r
# 金融 n
# 卡予 nr
# 被告 n
# 丙 n
# 時 zg
# 曾 d
# 告知 v
# 該 r
# 金融 n
# 卡 v
# 係 zg
# 強盜 n
# 所得 v
# 之 u
# 贓物 n
# 且 c
# 衡 nr
# 之 u
# 常情 n
# 被告 n
# 乙 n
# 與 p
# 丙 n
# 係 zg
# 親兄妹 n
# 被告 n
# 乙 n
# 在 p
# 臺灣地區 ns
# 之 u
# 財物 n
# 均 d
# 由 p
# 被告 n
# 丙 n
# 處理 v
# 其 r
# 持交 v
# 金融 n
# 卡 n
# 委託 n
# 丙 n
# 代為 v
# 領款 n
# 原 n
# 無須 d
# 告知 v
# 被告 n
# 丙 n
# 該 r
# 金融 n
# 卡 n
# 款項 n
# 之 u
# 來源 n
# 至 p
# 被告 n
# 乙 n
# 雖 zg
# 告知 v
# 丙 n
# 該 r
# 金融 n
# 卡屬 nz
# 人頭 n
# 戶 q
# 開立 v
# 然 c
# 取得 v
# 人頭 n
# 戶 q
# 開立 v
# 之 u
# 金融 n
# 卡 n
# 並不等於 l
# 取得 v
# 強盜 n
# 所得 v
# 之 u
# 贓物 n
# 況 c
# 現今 t
# 社會 n
# 尚 d
# 不乏 v
# 徵得 v
# 他人 r
# 同意 d
# 以 p
# 他人 r
# 名義 n
# 開立 v
# 帳戶 n
# 供 v
# 己 r
# 使用 v
# 之 u
# 例 n
# 再 d
# 查 v
# 被告 n
# 丙 n
# 於 nr
# 主觀 n
# 上 f
# 既 c
# 認為 v
# 該 r
# 金融 n
# 卡為 nr
# 被告 n
# 乙 n
# 以 p
# 人頭 n
# 申請 v
# 開設 v
# 之 u
# 帳戶 n
# 則 zg
# 被告 n
# 丙 n
# 主觀 n
# 上 f
# 對於 i
# 被告 n
# 乙 n
# 所 c
# 交付 v
# 之上 f
# 開 v
# 金融 n
# 卡 v
# 係 zg
# 強盜 n
# 所得 v
# 之 u
# 贓物 n
# 乙節 n
# 即 v
# 無 v
# 認識 v
# 或 c
# 預見 v
# 亦 d
# 即 v
# 被告 n
# 丙 n
# 僅 zg
# 認知 v
# 被告 n
# 乙 n
# 交付 v
# 之 u
# 金融 n
# 卡 v
# 係 yg
# 以 p
# 人頭 n
# 戶 q
# 開設 v
# 未 d
# 具體 a
# 認知 v
# 被告 n
# 乙 n
# 交付 v
# 之 u
# 金融 n
# 卡 v
# 係 zg
# 強盜 n
# 所得 v
# 之 u
# 贓物 n
# 其 r
# 收受 v
# 該 r
# 金融 n
# 卡 n
# 進而 c
# 提款 v
# 之行 r
# 為 p
# 尚難 d
# 遽 a
# 認 v
# 有 v
# 何 r
# 收受 v
# 贓物 n
# 及以 c
# 不正 d
# 方法 n
# 由 p
# 自動 vn
# 付款 v
# 設備 vn
# 取得 v
# 他人 r
# 之 u
# 物 ng
# 之 u
# 不 d
# 確定 v
# 故意 d
# 故 n
# 被告 n
# 丙 n
# 辯稱 v
# 上開 v
# 金融 n
# 卡 v
# 係 zg
# 被告 n
# 乙 n
# 交付 v
# 經乙 n
# 告知 v
# 係 zg
# 人頭 n
# 戶 q
# 之 f
# 金融 n
# 卡等語 nz
# 尚非 d
# 不可 v
# 採信 v
# 綜上所述 c
# 公訴人 n
# 所舉 v
# 之 u
# 證據 n
# 既 c
# 不足以 v
# 證明 n
# 被告 n
# 丙 n
# 有 v
# 本件 n
# 收受 v
# 贓物 n
# 以 p
# 不正 d
# 方法 n
# 由 p
# 自動 vn
# 付款 v
# 設備 vn
# 取得 v
# 他人 r
# 之 u
# 物 ng
# 之 u
# 犯行 v
# 本院 n
# 依 d
# 職權 n
# 調查 vn
# 全部 n
# 證據 n
# 後 f
# 亦 d
# 查 v
# 無證據 n
# 足 a
# 認 v
# 被告 n
# 丙 n
# 有 v
# 公訴人 n
# 所指 n
# 之 u
# 右 f
# 揭犯 v
# 行 n
# 此外 c
# 復 v
# 查無 v
# 其他 r
# 積極 ad
# 事 n
# 證足 v
# 認 v
# 被告 n
# 丙 n
# 有何 r
# 收受 v
# 贓物 n
# 以 p
# 不正 d
# 方法 n
# 由 p
# 自動 vn
# 付款 v
# 設備 vn
# 取得 v
# 他人 r
# 之 u
# 物 ng
# 之 u
# 犯行 v
# 揆 g
# 諸 r
# 前 f
# 揭 v
# 判例 n
# 意旨 n
# 及 c
# 說明 v
# 其 r
# 罪嫌 n
# 即 v
# 屬 v
# 未 d
# 足 a
# 自應 v
# 為 zg
# 無罪 v
# 之 u
# 諭知 n
# 據 p
# 上 f
# 論斷 v
# 應依 nr
# 刑事訴訟法 n
# 第二百 m
# 九十九條 m
# 第一項 m
# 前段 n
# 第三 m
# 百零 m
# 一條 m
# 第一項 m
# 刑法 n
# 第二條 m
# 第一項 m
# 前段 n
# 修正 nr
# 後 f
# 刑法 n
# 第三 m
# 百 n
# 三十二條 m
# 第一項 m
# 第三 m
# 百 n
# 三十 m
# 九條 m
# 之二 r
# 第一項 m
# 第二百 m
# 十六條 m
# 第二 m
# 百十條 m
# 第三 m
# 百 n
# 三十 m
# 九條 m
# 第一項 m
# 第五 m
# 十五條 m
# 第三十七條 m
# 第一項 m
# 第三十八條 m
# 第一項 m
# 第二款 m
# 第二 m
# 百十 m
# 九條 m
# 判決 v
# 如 v
# 主文 n
# 本案 r
# 經 zg
# 檢察官 n
# 俞秀端 nr
# 柯宜 nr
# 汾 ns
# 到庭 d
# 執行 v
# 職務 n

# %%
jieba.analyse.extract_tags(sample_df[2][0], topK=50, withWeight=True, allowPOS=('v','a'))
# Out:
# [('上開', 0.2395677371453288),
#  ('沒有', 0.22944515670256843),
#  ('發現', 0.1923290284124471),
#  ('存摺', 0.15521290012232572),
#  ('購買', 0.12147096531312447),
#  ('進入', 0.10459999790852385),
#  ('所示', 0.09697025515094836),
#  ('說明', 0.09110322398484336),
#  ('辯稱', 0.08772903050392322),
#  ('告知', 0.08228685651663563),
#  ('分行', 0.08143674996396275),
#  ('提領', 0.07760645006116286),
#  ('認識', 0.07760645006116286),
#  ('交付', 0.07566291186495061),
#  ('處理', 0.0708580630993226),
#  ('供稱', 0.0708580630993226),
#  ('接觸', 0.06748386961840248),
#  ('認定', 0.06410967613748236),
#  ('提款', 0.06078996262926898),
#  ('殺害', 0.060735482656562235),
#  ('返臺', 0.060735482656562235),
#  ('回來', 0.060735482656562235),
#  ('鑑識', 0.05736128917564211),
#  ('結證', 0.05736128917564211),
#  ('偽造', 0.05398709569472199),
#  ('存入', 0.05336144366142253),
#  ('失蹤', 0.050612902213801866),
#  ('指認', 0.050612902213801866),
#  ('復興', 0.050612902213801866),
#  ('沾有', 0.05058676688856901),
#  ('付款', 0.047328414591605986),
#  ('採獲', 0.04723870873288174),
#  ('發生', 0.04723870873288174),
#  ('還款', 0.04723870873288174),
#  ('開始', 0.04386451525196161),
#  ('行為', 0.04386451525196161),
#  ('採證', 0.04386451525196161),
#  ('採取', 0.04386451525196161),
#  ('洗臉', 0.04049032177104149),
#  ('擦抹', 0.039639129803895),
#  ('使用', 0.039516031111061244),
#  ('出來', 0.03711612829012137),
#  ('承諾', 0.03711612829012137),
#  ('證述', 0.03711612829012137),
#  ('回臺', 0.03711612829012137),
#  ('證稱', 0.03711612829012137),
#  ('出國', 0.03711612829012137),
#  ('代為', 0.03711612829012137),
#  ('自用', 0.03557657505603726),
#  ('參照', 0.03374193480920124)]

# %%
jieba.analyse.textrank(sample_df[2][0], topK=50, withWeight=True, allowPOS=('v','a'))
# Out:
# [('上開', 1.0),
#  ('沒有', 0.8143837485846172),
#  ('存摺', 0.6331342062966022),
#  ('發現', 0.5814715796302379),
#  ('是否', 0.3804114239050804),
#  ('認定', 0.3762440947186687),
#  ('表示', 0.3653339867651316),
#  ('告知', 0.3648748823045899),
#  ('進入', 0.36436491208205996),
#  ('存入', 0.3590650619734624),
#  ('處理', 0.356982494489273),
#  ('可能', 0.346414613053619),
#  ('使用', 0.33147148088178147),
#  ('交付', 0.3073085630023027),
#  ('提領', 0.2847309367109612),
#  ('行為', 0.26741314296913227),
#  ('造成', 0.26537226349559395),
#  ('接觸', 0.26182890336544773),
#  ('取得', 0.2613279662337348),
#  ('可疑', 0.25684018139802556),
#  ('還款', 0.254946731980686),
#  ('適用', 0.2520183583345624),
#  ('避免', 0.2497715703682698),
#  ('擦抹', 0.24360951039897794),
#  ('說明', 0.23908063270742383),
#  ('提款', 0.2384713838347836),
#  ('清洗', 0.23846693768821167),
#  ('採證', 0.22871104429956526),
#  ('付款', 0.2286090035637319),
#  ('打開', 0.22625490721379424),
#  ('分行', 0.22197249976732425),
#  ('自用', 0.22137392397499103),
#  ('無從', 0.21506178107449928),
#  ('返臺', 0.21077953353153348),
#  ('鑑定', 0.2104100309962039),
#  ('辯稱', 0.20813923912482943),
#  ('發生', 0.20286056638416888),
#  ('出來', 0.2020909193545488),
#  ('回來', 0.1975634430166327),
#  ('出國', 0.19287755183346306),
#  ('屬實', 0.19122407239395914),
#  ('回臺', 0.1892772040228712),
#  ('平常', 0.18571376955300017),
#  ('噴水', 0.1855178025412326),
#  ('採獲', 0.18419854442917472),
#  ('不能', 0.18264584607898196),
#  ('購買', 0.18234628026018668),
#  ('認識', 0.18181799129085086),
#  ('不足', 0.17839186839727342),
#  ('出門', 0.17714297470058415)]
